# %% [markdown]
# # Descargas de diferentes fuentes de la web

# %%
# Importamos librerias
import requests
import zipfile
import pandas as pd
import numpy as np
import json

# %%
#%pip install requests

# %% [markdown]
# ## Primera petición

# %%
url = "https://m.media-amazon.com/images/M/MV5BZGUzYTI3M2EtZmM0Yy00NGUyLWI4ODEtN2Q3ZGJlYzhhZjU3XkEyXkFqcGdeQXVyNTM0OTY1OQ@@._V1_.jpg"

image = requests.get(url)

# %%
image
# Out:
# <Response [200]>

# %%
type(image)
# Out:
# requests.models.Response

# %%
with open("data/thelast.png", "wb") as f: # write binary
    f.write(image.content)

# %% [markdown]
# ## Bajar datos de inflación mediante url

# %%
df_inflaction = pd.read_csv("https://datahub.io/core/inflation/r/inflation-gdp.csv")
df_inflaction.head()
# Out:
#       Country Country Code  Year  Inflation
# 0  Arab World          ARB  1969   1.303790
# 1  Arab World          ARB  1970   2.602241
# 2  Arab World          ARB  1971   6.884719
# 3  Arab World          ARB  1972   2.496081
# 4  Arab World          ARB  1973  11.555281

# %%
df_inflaction[df_inflaction["Country"] == "Spain"]
# Out:
#      Country Country Code  Year  Inflation
# 9432   Spain          ESP  1961   2.466390
# 9433   Spain          ESP  1962   6.095842
# 9434   Spain          ESP  1963   7.845375
# 9435   Spain          ESP  1964   6.254320
# 9436   Spain          ESP  1965   9.164867
# 9437   Spain          ESP  1966   8.173743
# 9438   Spain          ESP  1967   8.537719
# 9439   Spain          ESP  1968   5.911130
# 9440   Spain          ESP  1969   5.133251
# 9441   Spain          ESP  1970   8.768999
# 9442   Spain          ESP  1971   7.846021
# 9443   Spain          ESP  1972   8.517925
# 9444   Spain          ESP  1973  11.849595
# 9445   Spain          ESP  1974  15.945109
# 9446   Spain          ESP  1975  16.781782
# 9447   Spain          ESP  1976  16.489922
# 9448   Spain          ESP  1977  23.383070
# 9449   Spain          ESP  1978  20.631042
# 9450   Spain          ESP  1979  16.931632
# 9451   Spain          ESP  1980  13.354827
# 9452   Spain          ESP  1981  12.351192
# 9453   Spain          ESP  1982  13.582323
# 9454   Spain          ESP  1983  11.884246
# 9455   Spain          ESP  1984  10.864734
# 9456   Spain          ESP  1985   8.595479
# 9457   Spain          ESP  1986  10.878816
# 9458   Spain          ESP  1987   5.944198
# 9459   Spain          ESP  1988   5.936126
# 9460   Spain          ESP  1989   6.896194
# 9461   Spain          ESP  1990   7.326251
# 9462   Spain          ESP  1991   6.935139
# 9463   Spain          ESP  1992   6.710771
# 9464   Spain          ESP  1993   4.537241
# 9465   Spain          ESP  1994   3.879842
# 9466   Spain          ESP  1995   4.933130
# 9467   Spain          ESP  1996   3.470721
# 9468   Spain          ESP  1997   2.381828
# 9469   Spain          ESP  1998   2.532760
# 9470   Spain          ESP  1999   2.664838
# 9471   Spain          ESP  2000   3.276074
# 9472   Spain          ESP  2001   4.079866
# 9473   Spain          ESP  2002   4.114985
# 9474   Spain          ESP  2003   3.918909
# 9475   Spain          ESP  2004   3.921276
# 9476   Spain          ESP  2005   4.149491
# 9477   Spain          ESP  2006   3.978200
# 9478   Spain          ESP  2007   3.331140
# 9479   Spain          ESP  2008   2.135441
# 9480   Spain          ESP  2009   0.252534
# 9481   Spain          ESP  2010   0.160419
# 9482   Spain          ESP  2011   0.028968
# 9483   Spain          ESP  2012   0.067950
# 9484   Spain          ESP  2013   0.353610
# 9485   Spain          ESP  2014  -0.194984
# 9486   Spain          ESP  2015   0.610876
# 9487   Spain          ESP  2016   0.283304

# %%
df_inflaction.to_csv("data/inflaction.csv")

# %% [markdown]
# ## Bajar datos de Bicimad

# %%
url = "https://opendata.emtmadrid.es/getattachment/c3383795-121b-4ebf-98b4-c7b05e902eaf/202106_movements.aspx"
r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
# Guardamos el zip
filename = "data/bicis.zip"
with open(filename, "wb") as f:
    f.write(r.content)

# %%
# Extraemos lo que hay dentro
with zipfile.ZipFile(filename, "r") as zip_ref:
    zip_ref.extractall("data/")

# %%
# Leemos los datos
datos_bicis = pd.read_json("data/202106_movements.json", lines=True, encoding="latin-1", nrows=10000)

# %%
# Vemos qué pinta tienen
datos_bicis.head()
# Out:
#                                     _id  \
# 0  {'$oid': '60bbf3f21b91311d90d568ad'}
# 1  {'$oid': '60bbf3f21b91311d90d568b2'}
# 2  {'$oid': '60bbf3f21b91311d90d568b3'}
# 3  {'$oid': '60bbf3f21b91311d90d568b4'}
# 4  {'$oid': '60bbf3f21b91311d90d568b5'}
#
#                                        user_day_code  idplug_base  user_type  \
# 0  b67ea824acf706087d5818ebc6f90821a5abaab17a0868...           15          1
# 1  364b1b99f1f9a1748f7abf1134c8d6a46197b583649308...            7          1
# 2  5cc17031cba02835dda4b6c153b56572beaade54d8ab91...           14          1
# 3  6e855acaaa17d6d14236598c0f1172c783e16950e39c01...            8          1
# 4  e93417502d55208995a61f4177956ab9289aba39044ce3...            1          1
#
#    idunplug_base  travel_time  idunplug_station  ageRange  idplug_station  \
# 0             13          319                38         0              54
# 1              1          386               185         0             126
# 2             10          465                15         0              91
# 3             22          613                84         0             236
# 4              4          751               131         5              94
#
#         unplug_hourTime zip_code
# 0  2021-06-01T00:00:00Z
# 1  2021-06-01T00:00:00Z
# 2  2021-06-01T00:00:00Z
# 3  2021-06-01T00:00:00Z
# 4  2021-06-01T00:00:00Z    28006

# %%
datos_bicis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               10000 non-null  object
#  1   user_day_code     10000 non-null  object
#  2   idplug_base       10000 non-null  int64
#  3   user_type         10000 non-null  int64
#  4   idunplug_base     10000 non-null  int64
#  5   travel_time       10000 non-null  int64
#  6   idunplug_station  10000 non-null  int64
#  7   ageRange          10000 non-null  int64
#  8   idplug_station    10000 non-null  int64
#  9   unplug_hourTime   10000 non-null  object
#  10  zip_code          10000 non-null  object
# dtypes: int64(7), object(4)
# memory usage: 859.5+ KB

# %%
datos_bicis["zip_code"].unique()
# Out:
# array(['', '28006', '28004', '28045', '28028', '28009', '28007', '28005',
#        '28010', '28034', '28012', '28001', '28008', '28015', '28002',
#        '28105', 'CODIGO_POSTAL_NOT_DEF', '28013', '39724', '28100',
#        '28800', '28027', '28020', '28011', '28014', '28850', '15002',
#        '28003', '45007', '28046', '28039', '28043', '28038', '28934',
#        '28016', '28945', '28221', '28033', '28030', '28029', '28048',
#        '28054', '28035', '35572', '28049', '28004 ', '28019', '28040',
#        '28941', '28523', '28380', '28933', '28026', '45600', '28938',
#        '28220', '28935', '28760', '28863', '28018', '28250', '28053',
#        '28017', '28024', '28823', '28021', '28922', '28210', '28022',
#        '28036', '28047', '28430', '28041', '46009', '28770', '28031',
#        '28200', '46026', '20540', '28232', '28042', '28071', '18006',
#        '28400', '62973', '2', '28521', '28822', '28411', '28229', '48520',
#        '29039', '28260', '28055', '28942', '28815', '28037', '28702',
#        '28707', '28701', '28290', '28691', '28460', '28936', '28915',
#        '28025', '28750', '28905', '28223', '75014', '28891', '28903',
#        '23009', '28023', '28660', '28006 ', '28924', '28911', '28032',
#        '28801', '10318', '28803', '29740', '28051', '28342', '28912',
#        '28064', '28299', '33206', '28791', '28028 ', '09006', '28917',
#        '19160', '28923', '28350', '29045', '23012', '28670', '28044',
#        '28909', '28450', '28906', '28231'], dtype=object)

# %% [markdown]
# # Acceso a archivos de la pagina de datos.gob.es
# Uno de los mayores catálogos de información pública descargable en España

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio datos.gob.es</h3>
#
# Descarga con pandas un dataset de la página https://datos.gob.es/es/catalogo acerca del empleo y guárdalo en un csv en la carpeta data.
#
#  </td></tr>
# </table>

# %%
url = "https://dadesobertes.gva.es/dataset/f706e6d9-fd44-4d45-988f-9b79010bc219/resource/9ae4e50e-09b0-401d-91e9-640905275749/download/datos-erte-solicitados-por-covid-19-2020-11-30.csv"
datos_empleo = pd.read_csv(url, sep=";")
datos_empleo.head()
# Out:
#   AUTORIDAD_LABORAL       SECTOR  NUM_EXPEDIENTES  NUM_TRABAJADORES_AFECTADOS  \
# 0              D.G.  AGRICULTURA                3                          64
# 1              D.G.  CONSTRUCIÓN               32                        1431
# 2              D.G.    INDUSTRIA              223                       56791
# 3              D.G.    SERVICIOS              664                       38105
# 4       DT VALENCIA  AGRICULTURA               68                         264
#
#    HOMBRES  MUJERES  PERS_GENERO_SIN_DETERMINAR
# 0       50       14                           0
# 1     1189      242                           0
# 2    42703    10146                        3942
# 3    18003    18170                        1932
# 4      200       64                           0

# %%
url = "https://datos.madrid.es/egob/catalogo/206974-0-agenda-eventos-culturales-100.json"
datos = pd.read_json(url, typ = "series")
#datos_empleo.head()
datos.head()


#df = pd.DataFrame(data["result"])
# Out:
# @context    {'c': 'http://www.w3.org/2002/12/cal#', 'dcter...
# @graph      [{'@id': 'https://datos.madrid.es/egob/catalog...
# dtype: object

# %%
# Out:
#    ANYO  MES  COD_PROV  NOM_PROV  COD_MUN       NOM_MUN COD_SECTOR  \
# 0  2018    1        46  VALENCIA       22       ALFAFAR         S
# 1  2018    1        46  VALENCIA      163  MASSALFASSAR         C
# 2  2018    1        46  VALENCIA      186      PAIPORTA         I
# 3  2018    1        46  VALENCIA       15      ALCASSER         S
# 4  2018    1        46  VALENCIA      250      VALENCIA         S
#
#     DESC_SECTOR  COD_GRUPO                                         DESC_GRUPO  \
# 0     Servicios          5  Trabajadores de los servicios de restauración,...
# 1  Construccion          4  Empleados contables, administrativos y otros e...
# 2     Industria          9                            Ocupaciones elementales
# 3     Servicios          3                   Técnicos, profesionales de apoyo
# 4     Servicios          1                              Directores y gerentes
#
#   COD_GENERO DESC_GENERO RANGO_EDAD  NUM_CONTRATOS
# 0          M       Mujer      25-44              2
# 1          M       Mujer      >44                1
# 2          H      Hombre      25-44              1
# 3          M       Mujer      25-44              1
# 4          M       Mujer      25-44              1

# %% [markdown]
# # OpenStreetMap

# %%
# Amenities
# https://wiki.openstreetmap.org/wiki/Key:amenity

overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
node["amenity"="cafe"]
  (40.420801, -3.694702,40.423754, -3.688167); 
out;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
print(response)
data = response.json()
# Out:
# <Response [200]>

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.61.5 4133829e',
#  'osm3s': {'timestamp_osm_base': '2023-12-21T11:34:11Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 2977298934,
#    'lat': 40.4210523,
#    'lon': -3.689841,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:street': 'Calle de Villalar',
#     'amenity': 'cafe',
#     'cuisine': 'regional',
#     'internet_access': 'yes',
#     'name': 'Café Villalar',
#     'phone': '+34 914358937',
#     'website': 'https://cafeteriavillalar.eatbu.com/'}},
#   {'type': 'node',
#    'id': 3426617375,
#    'lat': 40.4221948,
#    'lon': -3.6923421,
#    'tags': {'amenity': 'cafe',
#     'name': 'Gran Café Gijón',
#     'phone': '+34 915 215 425',
#     'website': 'https://cafegijon.com/',
#     'wikidata': 'Q1025608',
#     'wikipedia': 'es:Café Gijón'}},
#   {'type': 'node',
#    'id': 4703448419,
#    'lat': 40.4229908,
#    'lon': -3.6936524,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Marqués de Monasterio',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://www.facebook.com/hermanasae',
#     'contact:instagram': 'https://www.instagram.com/hermanasarce/',
#     'cuisine': 'cake',
#     'disused:amenity': 'restaurant',
#     'name': 'Hermanas Arce',
#     'old_name': 'Noteolvides',
#     'opening_hours': 'Tu-Fr 09:00-17:00; Sa 09:30-17:30'}},
#   {'type': 'node',
#    'id': 4778747544,
#    'lat': 40.4223247,
#    'lon': -3.6909735,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '1',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Recoletos',
#     'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'contact:phone': '+34 914319000',
#     'contact:website': 'https://www.santagloria.com',
#     'name': 'Santagloria',
#     'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 9207850217,
#    'lat': 40.4218751,
#    'lon': -3.6901227,
#    'tags': {'amenity': 'cafe', 'name': 'masticar'}}]}

# %%
data.keys()
# Out:
# dict_keys(['version', 'generator', 'osm3s', 'elements'])

# %%
data["osm3s"]
# Out:
# {'timestamp_osm_base': '2023-12-21T11:34:11Z',
#  'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'}

# %%
data.get("osm3s")
# Out:
# {'timestamp_osm_base': '2023-12-21T11:34:11Z',
#  'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'}

# %%
data["osm3s"]["copyright"]
# Out:
# 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'

# %%
data["elements"][0]
# Out:
# {'type': 'node',
#  'id': 2977298934,
#  'lat': 40.4210523,
#  'lon': -3.689841,
#  'tags': {'addr:city': 'Madrid',
#   'addr:housenumber': '4',
#   'addr:street': 'Calle de Villalar',
#   'amenity': 'cafe',
#   'cuisine': 'regional',
#   'internet_access': 'yes',
#   'name': 'Café Villalar',
#   'phone': '+34 914358937',
#   'website': 'https://cafeteriavillalar.eatbu.com/'}}

# %%
# Acceder a los valores del diccionario para guardarlos en variables para luego crear un Dataframe
dict_cafes = {"lat":[], "lon":[], "street":[], "number_street":[]}
for i in data["elements"]:
    lat = i["lat"]
    lon = i["lon"]
    street = i["tags"].get("addr:street", "Sin Calle")
    number_street = i["tags"].get("addr:housenumber", 0)

    dict_cafes["lat"].append(lat)
    dict_cafes["lon"].append(lon)
    dict_cafes["street"].append(street)
    dict_cafes["number_street"].append(number_street)

df_cafe = pd.DataFrame(dict_cafes)
df_cafe
# Out:
#          lat       lon                           street number_street
# 0  40.421052 -3.689841                Calle de Villalar             4
# 1  40.422195 -3.692342                        Sin Calle             0
# 2  40.422991 -3.693652  Calle del Marqués de Monasterio             6
# 3  40.422325 -3.690974               Calle de Recoletos             1
# 4  40.421875 -3.690123                        Sin Calle             0

# %%
pd.DataFrame(data["elements"])
# Out:
#    type          id        lat       lon  \
# 0  node  2977298934  40.421052 -3.689841
# 1  node  3426617375  40.422195 -3.692342
# 2  node  4703448419  40.422991 -3.693652
# 3  node  4778747544  40.422325 -3.690974
# 4  node  9207850217  40.421875 -3.690123
#
#                                                 tags
# 0  {'addr:city': 'Madrid', 'addr:housenumber': '4...
# 1  {'amenity': 'cafe', 'name': 'Gran Café Gijón',...
# 2  {'addr:city': 'Madrid', 'addr:housenumber': '6...
# 3  {'addr:city': 'Madrid', 'addr:housenumber': '1...
# 4            {'amenity': 'cafe', 'name': 'masticar'}

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.61.5 4133829e',
#  'osm3s': {'timestamp_osm_base': '2023-12-21T11:34:11Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 2977298934,
#    'lat': 40.4210523,
#    'lon': -3.689841,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:street': 'Calle de Villalar',
#     'amenity': 'cafe',
#     'cuisine': 'regional',
#     'internet_access': 'yes',
#     'name': 'Café Villalar',
#     'phone': '+34 914358937',
#     'website': 'https://cafeteriavillalar.eatbu.com/'}},
#   {'type': 'node',
#    'id': 3426617375,
#    'lat': 40.4221948,
#    'lon': -3.6923421,
#    'tags': {'amenity': 'cafe',
#     'name': 'Gran Café Gijón',
#     'phone': '+34 915 215 425',
#     'website': 'https://cafegijon.com/',
#     'wikidata': 'Q1025608',
#     'wikipedia': 'es:Café Gijón'}},
#   {'type': 'node',
#    'id': 4703448419,
#    'lat': 40.4229908,
#    'lon': -3.6936524,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Marqués de Monasterio',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://www.facebook.com/hermanasae',
#     'contact:instagram': 'https://www.instagram.com/hermanasarce/',
#     'cuisine': 'cake',
#     'disused:amenity': 'restaurant',
#     'name': 'Hermanas Arce',
#     'old_name': 'Noteolvides',
#     'opening_hours': 'Tu-Fr 09:00-17:00; Sa 09:30-17:30'}},
#   {'type': 'node',
#    'id': 4778747544,
#    'lat': 40.4223247,
#    'lon': -3.6909735,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '1',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Recoletos',
#     'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'contact:phone': '+34 914319000',
#     'contact:website': 'https://www.santagloria.com',
#     'name': 'Santagloria',
#     'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 9207850217,
#    'lat': 40.4218751,
#    'lon': -3.6901227,
#    'tags': {'amenity': 'cafe', 'name': 'masticar'}}]}

# %%
def json_to_dataframe(data_entrada):
    elements = data_entrada['elements']
    places = {'lat': [], 'lon': [], 'name': [], 'address': []}

    for i in elements:
        lalitude = i['lat']
        longitude = i['lon']
        name = i['tags'].get('name')
        street = i['tags'].get('addr:street', 'Sin calle')
        number = i['tags'].get('addr:housenumber', 0)
        
        places['lat'].append(lalitude)
        places['lon'].append(longitude)
        places['name'].append(name)
        places['address'].append(str(street) + ' ' + str(number))

    df = pd.DataFrame(places)
    
    return df

# %%
df_return = json_to_dataframe(data)
df_return
# Out:
#          lat       lon             name                            address
# 0  40.421052 -3.689841    Café Villalar                Calle de Villalar 4
# 1  40.422195 -3.692342  Gran Café Gijón                        Sin calle 0
# 2  40.422991 -3.693652    Hermanas Arce  Calle del Marqués de Monasterio 6
# 3  40.422325 -3.690974      Santagloria               Calle de Recoletos 1
# 4  40.421875 -3.690123         masticar                        Sin calle 0

# %%
# lista_responses = [data1, data2, data3, data4]
# for data in lista_responses:
#     df_return = json_to_dataframe(data)
#     df_results = df_results.concat(df_return)

# %% [markdown]
# ## Datos del espacio

# %%
space_url = "http://ll.thespacedevs.com/2.2.0"

path = "/astronaut"

url_total = space_url + path

response = requests.get(url_total)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 path = "/astronaut"
#       5 url_total = space_url + path
# ----> 7 response = requests.get(url_total)
#
# NameError: name 'requests' is not defined

# %%
print(response)
response.json()
# Out:
# <Response [200]>
# {'count': 752,
#  'next': 'https://ll.thespacedevs.com/2.2.0/astronaut/?limit=10&offset=10',
#  'previous': None,
#  'results': [{'id': 1,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/1/',
#    'name': 'Thomas Pesquet',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P396DT11H33M45S',
#    'eva_time': 'P1DT15H54M',
#    'age': 45,
#    'date_of_birth': '1978-02-27',
#    'date_of_death': None,
#    'nationality': 'French',
#    'bio': 'Thomas Gautier Pesquet is a French aerospace engineer, pilot, and European Space Agency astronaut. Pesquet was selected by ESA as a candidate in May 2009, and he successfully completed his basic training in November 2010. From November 2016 to June 2017, Pesquet was part of Expeditions 50 and 51 on the International Space Station as a flight engineer.',
#    'twitter': 'https://twitter.com/Thom_astro',
#    'instagram': 'https://instagram.com/thom_astro',
#    'wiki': 'https://en.wikipedia.org/wiki/Thomas_Pesquet',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'AUT,BEL,CZE,DNK,FIN,FRA,DEU,GRC,IRE,ITA,LUZ,NLD,NOR,POL,PRT,ROU,ESP,SWE,CHE,GBR',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/logo/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/thomas2520pesquet_image_20200102120546.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/thomas_pesquet_thumbnail_20220911033657.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 6,
#    'last_flight': '2021-04-23T09:49:02Z',
#    'first_flight': '2016-11-17T20:20:13Z'},
#   {'id': 2,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/2/',
#    'name': 'Claude Nicollier',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P42DT12H3M12S',
#    'eva_time': 'PT8H10M',
#    'age': 79,
#    'date_of_birth': '1944-09-02',
#    'date_of_death': None,
#    'nationality': 'Swiss',
#    'bio': 'Claude Nicollier is the first astronaut from Switzerland. He has flown on four Space Shuttle missions. His first spaceflight (STS-46) was in 1992, and his final spaceflight (STS-103) was in 1999. He took part in two servicing missions to the Hubble Space Telescope (called STS-61 and STS-103). During his final spaceflight he participated in a spacewalk, becoming the first European Space Agency astronaut to do so during a Space Shuttle mission. In 2000 he was assigned to the Astronaut Office Extravehicular Activity Branch, while maintaining a position as Lead ESA Astronaut in Houston. Nicollier retired from ESA in April 2007.',
#    'twitter': 'https://twitter.com/Astroclaude',
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Claude_Nicollier',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'AUT,BEL,CZE,DNK,FIN,FRA,DEU,GRC,IRE,ITA,LUZ,NLD,NOR,POL,PRT,ROU,ESP,SWE,CHE,GBR',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/logo/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/claude2520nicollier_image_20181127203218.jpg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/claude_nicollie_thumbnail_20220911033747.jpeg',
#    'flights_count': 4,
#    'landings_count': 4,
#    'spacewalks_count': 1,
#    'last_flight': '1999-12-20T00:50:00Z',
#    'first_flight': '1992-07-31T13:56:48Z'},
#   {'id': 3,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/3/',
#    'name': 'Tim Peake',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P185DT22H11M51S',
#    'eva_time': 'PT4H43M',
#    'age': 51,
#    'date_of_birth': '1972-04-07',
#    'date_of_death': None,
#    'nationality': 'British',
#    'bio': "Major Timothy Nigel Peake CMG is a British Army Air Corps officer, former European Space Agency astronaut and International Space Station (ISS) crew member.  He is the first British ESA astronaut, the second astronaut to bear a flag of the United Kingdom patch, the sixth person born in the United Kingdom to go on board the International Space Station and the seventh UK-born person in space. He began the ESA's intensive astronaut basic training course in September 2009 and graduated on 22 November 2010",
#    'twitter': 'https://twitter.com/astro_timpeake',
#    'instagram': 'https://www.instagram.com/astro_timpeake/',
#    'wiki': 'https://en.wikipedia.org/wiki/Tim_Peake',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'AUT,BEL,CZE,DNK,FIN,FRA,DEU,GRC,IRE,ITA,LUZ,NLD,NOR,POL,PRT,ROU,ESP,SWE,CHE,GBR',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/logo/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/tim_peake_image_20230120154350.jpg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/tim_peake_thumbnail_20230120154351.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 1,
#    'last_flight': '2015-12-15T11:03:09Z',
#    'first_flight': '2015-12-15T11:03:09Z'},
#   {'id': 4,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/4/',
#    'name': 'Buzz Aldrin',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P12DT1H52M27S',
#    'eva_time': 'PT8H1M40S',
#    'age': 93,
#    'date_of_birth': '1930-01-20',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Buzz Aldrin; born Edwin Eugene Aldrin Jr.; is an American engineer, former astronaut, and fighter pilot.\r\nAs Lunar Module Pilot on the Apollo 11 mission, he and mission commander Neil Armstrong were the first two humans to land on the Moon.',
#    'twitter': 'https://twitter.com/TheRealBuzz',
#    'instagram': 'https://www.instagram.com/drbuzzaldrin/',
#    'wiki': 'https://en.wikipedia.org/wiki/Buzz_Aldrin',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Administrator: Bill Nelson',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/agency_images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/logo/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/buzz_aldrin_image_20220911034547.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/buzz_aldrin_thumbnail_20220911034547.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 4,
#    'last_flight': '1969-07-16T13:32:00Z',
#    'first_flight': '1966-11-11T20:46:33Z'},
#   {'id': 5,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/5/',
#    'name': 'Chris Hadfield',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P165DT16H19M',
#    'eva_time': 'PT14H50M',
#    'age': 64,
#    'date_of_birth': '1959-08-29',
#    'date_of_death': None,
#    'nationality': 'Canadian',
#    'bio': 'Chris Austin Hadfield is a Canadian retired astronaut, engineer, and former Royal Canadian Air Force fighter pilot.\r\nThe first Canadian to walk in space, Hadfield has flown two space shuttle missions and served as commander of the International Space Station.',
#    'twitter': 'https://twitter.com/Cmdr_Hadfield',
#    'instagram': 'https://www.instagram.com/colchrishadfield/',
#    'wiki': 'https://en.wikipedia.org/wiki/Chris_Hadfield',
#    'agency': {'id': 16,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/16/',
#     'name': 'Canadian Space Agency',
#     'featured': False,
#     'type': 'Government',
#     'country_code': 'CAN',
#     'abbrev': 'CSA',
#     'description': 'The Canadian Space Agency was established by the Canadian Space Agency Act which received Royal Assent on May 10, 1990. \r\n\r\nThe Canadian space program is administered by the Canadian Space Agency. Canada has contributed technology, expertise and personnel to the world space effort, especially in collaboration with ESA and NASA. In addition to its astronauts and satellites, some of the most notable Canadian technological contributions to space exploration include the Canadarm on the Space Shuttle and Canadarm2 on the International Space Station.',
#     'administrator': 'President: Lisa Campbell',
#     'founding_year': '1990',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/logo/canadian2520space2520agency_logo_20231122160211.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/chris_hadfield_image_20220911034200.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/chris_hadfield_thumbnail_20220911034200.jpeg',
#    'flights_count': 3,
#    'landings_count': 3,
#    'spacewalks_count': 2,
#    'last_flight': '2012-12-19T12:12:35Z',
#    'first_flight': '1995-11-12T12:30:43Z'},
#   {'id': 6,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/6/',
#    'name': 'David Saint-Jacques',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P203DT12H28M8S',
#    'eva_time': 'PT6H29M',
#    'age': 53,
#    'date_of_birth': '1970-01-06',
#    'date_of_death': None,
#    'nationality': 'Canadian',
#    'bio': 'David Saint-Jacques is a Canadian astronaut with the Canadian Space Agency (CSA).\r\nHe was also an engineer, an astrophysicist, and a physician prior to joining the CSA.\r\nHe was selected to join the CSA in the 2009 CSA selection along with Jeremy Hansen.',
#    'twitter': 'https://twitter.com/Astro_DavidS',
#    'instagram': 'https://www.instagram.com/astrodavids/',
#    'wiki': 'https://en.wikipedia.org/wiki/David_Saint-Jacques',
#    'agency': {'id': 16,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/16/',
#     'name': 'Canadian Space Agency',
#     'featured': False,
#     'type': 'Government',
#     'country_code': 'CAN',
#     'abbrev': 'CSA',
#     'description': 'The Canadian Space Agency was established by the Canadian Space Agency Act which received Royal Assent on May 10, 1990. \r\n\r\nThe Canadian space program is administered by the Canadian Space Agency. Canada has contributed technology, expertise and personnel to the world space effort, especially in collaboration with ESA and NASA. In addition to its astronauts and satellites, some of the most notable Canadian technological contributions to space exploration include the Canadarm on the Space Shuttle and Canadarm2 on the International Space Station.',
#     'administrator': 'President: Lisa Campbell',
#     'founding_year': '1990',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/logo/canadian2520space2520agency_logo_20231122160211.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/david_saint-jac_image_20220911034207.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/david_saint-jac_thumbnail_20220911034208.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 1,
#    'last_flight': '2018-12-03T11:31:52Z',
#    'first_flight': '2018-12-03T11:31:52Z'},
#   {'id': 7,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/7/',
#    'name': 'Anne McClain',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P203DT12H28M8S',
#    'eva_time': 'PT13H8M',
#    'age': 44,
#    'date_of_birth': '1979-06-07',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Anne Charlotte McClain is a lieutenant colonel in the U.S. Army currently assigned to NASA Astronaut Group 21.',
#    'twitter': 'https://twitter.com/AstroAnnimal',
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Anne_McClain',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Administrator: Bill Nelson',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/agency_images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/logo/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/anne2520mcclain_image_20181127210625.jpg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/anne_mcclain_thumbnail_20220911034153.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 2,
#    'last_flight': '2018-12-03T11:31:52Z',
#    'first_flight': '2018-12-03T11:31:52Z'},
#   {'id': 8,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/8/',
#    'name': 'Andrew R. Morgan',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P271DT12H48M22S',
#    'eva_time': 'P1DT21H48M',
#    'age': 47,
#    'date_of_birth': '1976-02-05',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Andrew Richard "Drew" Morgan is a NASA astronaut from the class of 2013.',
#    'twitter': 'https://twitter.com/AstroDrewMorgan',
#    'instagram': 'https://www.instagram.com/astrodrewmorgan/',
#    'wiki': 'https://en.wikipedia.org/wiki/Andrew_R._Morgan',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Administrator: Bill Nelson',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/agency_images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/logo/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/andrew_r._morga_image_20220911034204.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/andrew_r._morga_thumbnail_20220911034204.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 7,
#    'last_flight': '2019-07-20T16:28:21Z',
#    'first_flight': '2019-07-20T16:28:21Z'},
#   {'id': 9,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/9/',
#    'name': 'Nick Hague',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P202DT16H3M37S',
#    'eva_time': 'PT19H56M',
#    'age': 48,
#    'date_of_birth': '1975-09-24',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Tyler Nicklaus Hague is an American Flight Test Engineer and a NASA astronaut of the class of 2013.\r\nSelected to be a flight engineer of Expedition 57 / 58 to the International Space Station, he launched on board Soyuz MS-10, which aborted shortly after launch on October 11, 2018.',
#    'twitter': 'https://twitter.com/AstroHague',
#    'instagram': 'https://www.instagram.com/astrohague/',
#    'wiki': 'https://en.wikipedia.org/wiki/Nick_Hague',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Administrator: Bill Nelson',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/agency_images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/logo/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/nick_hague_image_20220911034312.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/nick_hague_thumbnail_20220911034312.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 3,
#    'last_flight': '2019-03-14T19:14:08Z',
#    'first_flight': '2018-10-11T08:40:15Z'},
#   {'id': 10,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/10/',
#    'name': 'Terry W. Virts',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P213DT10H50M46S',
#    'eva_time': 'PT19H2M',
#    'age': 56,
#    'date_of_birth': '1967-12-01',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Terry W. Virts Jr. is a former NASA astronaut, and Colonel in the United States Air Force.',
#    'twitter': 'https://twitter.com/AstroTerry',
#    'instagram': 'https://www.instagram.com/astro_terry/',
#    'wiki': 'https://en.wikipedia.org/wiki/Terry_W._Virts',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Administrator: Bill Nelson',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/agency_images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/logo/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/terry_w._virts_image_20220911033815.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/terry_w._virts_thumbnail_20220911033815.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 3,
#    'last_flight': '2014-11-23T21:01:14Z',
#    'first_flight': '2010-02-08T09:14:00Z'}]}

# %%
url_total
# Out:
# 'http://ll.thespacedevs.com/2.2.0/astronaut'

# %%
url_total = space_url + path + "/?search=armstrong"
responder = requests.get(url_total)

# %%
url_total
# Out:
# 'http://ll.thespacedevs.com/2.2.0/astronaut/?search=armstrong'

# %%
responder.json()
# Out:
# {'count': 1,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 30,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/30/',
#    'name': 'Neil Armstrong',
#    'status': {'id': 11, 'name': 'Deceased'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P8DT13H58M58S',
#    'eva_time': 'PT2H31M40S',
#    'age': 82,
#    'date_of_birth': '1930-08-05',
#    'date_of_death': '2012-08-25',
#    'nationality': 'American',
#    'bio': 'Neil Alden Armstrong was an American astronaut and aeronautical engineer who was the first person to walk on the Moon. He was also a naval aviator, test pilot, and university professor.',
#    'twitter': None,
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Neil_Armstrong',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Administrator: Bill Nelson',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/agency_images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/logo/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/neil2520armstrong_image_20190426143653.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/astronaut_images/neil_armstrong_thumbnail_20220911034208.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 1,
#    'last_flight': '1969-07-16T13:32:00Z',
#    'first_flight': '1966-03-16T16:41:02Z'}]}

# %% [markdown]
# ## Accediendo a datos de themoviedb

# %%
# https://developers.themoviedb.org/3/getting-started/introduction

# %%
#!pip install tmdbv3api
# Out:
# GoodFellas
# The true story of Henry Hill, a half-Irish, half-Sicilian Brooklyn kid who is adopted by neighbourhood gangsters at an early age and climbs the ranks of a Mafia family under the guidance of Jimmy Conway.
# The Godfather Part II
# In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.
# Taxi Driver
# A mentally unstable Vietnam War veteran works as a night-time taxi driver in New York City where the perceived decadence and sleaze feed his urge for violent action.
# Reservoir Dogs
# A botched robbery indicates a police informant, and the pressure mounts in the aftermath at a warehouse. Crime begets violence as the survivors -- veteran Mr. White, newcomer Mr. Orange, psychopathic parolee Mr. Blonde, bickering weasel Mr. Pink and Nice Guy Eddie -- unravel.
# The Godfather Part III
# In the midst of trying to legitimize his business dealings in 1979 New York and Italy, aging mafia don, Michael Corleone seeks forgiveness for his sins while taking a young protege under his wing.
# The Godfather
# Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.
# Heat
# Obsessive master thief Neil McCauley leads a top-notch crew on various daring heists throughout Los Angeles while determined detective Vincent Hanna pursues him without rest. Each man recognizes and respects the ability and the dedication of the other even though they are aware their cat-and-mouse game may end in violence.
# Full Metal Jacket
# A pragmatic U.S. Marine observes the dehumanizing effects the U.S.-Vietnam War has on his fellow recruits from their brutal boot camp training to the bloody street fighting in Hue.
# Pulp Fiction
# A burger-loving hit man, his philosophical partner, a drug-addled gangster's moll and a washed-up boxer converge in this sprawling, comedic crime caper. Their adventures unfurl in three stories that ingeniously trip back and forth in time.
# Casino
# In early-1970s Las Vegas, Sam "Ace" Rothstein gets tapped by his bosses to head the Tangiers Casino. At first, he's a great success in the job, but over the years, problems with his loose-cannon enforcer Nicky Santoro, his ex-hustler wife Ginger, her con-artist ex Lester Diamond and a handful of corrupt politicians put Sam in ever-increasing danger.
# The Usual Suspects
# Held in an L.A. interrogation room, Verbal Kint attempts to convince the feds that a mythic crime lord, Keyser Soze, not only exists, but was also responsible for drawing him and his four partners into a multi-million dollar heist that ended with an explosion in San Pedro harbor – leaving few survivors. Verbal lures his interrogators with an incredible story of the crime lord's almost supernatural prowess.
# Se7en
# Two homicide detectives are on a desperate hunt for a serial killer whose crimes are based on the "seven deadly sins" in this dark and haunting film that takes viewers from the tortured remains of one victim to the next. The seasoned Det. Sommerset researches each sin in an effort to get inside the killer's mind, while his novice partner, Mills, scoffs at his efforts to unravel the case.
# The Departed
# To take down South Boston's Irish Mafia, the police send in one of their own to infiltrate the underworld, not realizing the syndicate has done likewise. While an undercover cop curries favor with the mob kingpin, a career criminal rises through the police ranks. But both sides soon discover there's a mole among them.
# Carlito's Way
# A Puerto-Rican ex-con, just released from prison, pledges to stay away from drugs and violence despite the pressure around him, and lead a better life outside NYC.
# The Untouchables
# Young Treasury Agent Eliot Ness arrives in Chicago and is determined to take down Al Capone, but it's not going to be easy because Capone has the police in his pocket. Ness meets Jim Malone, a veteran patrolman and probably the most honorable one on the force. He asks Malone to help him get Capone, but Malone warns him that if he goes after Capone, he is going to war.
# One Flew Over the Cuckoo's Nest
# A petty criminal fakes insanity to serve his sentence in a mental ward rather than prison. He soon finds himself as a leader to the other patients—and an enemy to the cruel, domineering nurse who runs the ward.
# The Silence of the Lambs
# Clarice Starling is a top student at the FBI's training academy.  Jack Crawford wants Clarice to interview Dr. Hannibal Lecter, a brilliant psychiatrist who is also a violent psychopath, serving life behind bars for various acts of murder and cannibalism.  Crawford believes that Lecter may have insight into a case and that Starling, as an attractive young woman, may be just the bait to draw him out.
# Donnie Brasco
# An FBI undercover agent infilitrates the mob and finds himself identifying more with the mafia life at the expense of his regular one.
# A Clockwork Orange
# In a near-future Britain, young Alexander DeLarge and his pals get their kicks beating and raping anyone they please. When not destroying the lives of others, Alex swoons to the music of Beethoven. The state, eager to crack down on juvenile crime, gives an incarcerated Alex the option to undergo an invasive procedure that'll rob him of all personal agency. In a time when conscience is a commodity, can Alex change his tune?
# Apocalypse Now
# At the height of the Vietnam war, Captain Benjamin Willard is sent on a dangerous mission that, officially, "does not exist, nor will it ever exist." His goal is to locate - and eliminate - a mysterious Green Beret Colonel named Walter Kurtz, who has been leading his personal army on illegal guerrilla missions into enemy territory.
# Inglourious Basterds
# In Nazi-occupied France during World War II, a group of Jewish-American soldiers known as "The Basterds" are chosen specifically to spread fear throughout the Third Reich by scalping and brutally killing Nazis. The Basterds, lead by Lt. Aldo Raine soon cross paths with a French-Jewish teenage girl who runs a movie theater in Paris which is targeted by the soldiers.

# %%
# https://developers.themoviedb.org/3/getting-started/introduction
from tmdbv3api import TMDb
tmdb = TMDb()
tmdb.api_key = "xxx"

# %%
#https://github.com/AnthonyBloomer/tmdbv3api

from tmdbv3api import Movie
movie = Movie()

recommendations = movie.recommendations(movie_id=111)

for recommendation in recommendations:
    print(recommendation.title)
    print(recommendation.overview)
# Out:
# GoodFellas
# The true story of Henry Hill, a half-Irish, half-Sicilian Brooklyn kid who is adopted by neighbourhood gangsters at an early age and climbs the ranks of a Mafia family under the guidance of Jimmy Conway.
# Taxi Driver
# A mentally unstable Vietnam War veteran works as a night-time taxi driver in New York City where the perceived decadence and sleaze feed his urge for violent action.
# The Godfather Part II
# In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.
# Reservoir Dogs
# A botched robbery indicates a police informant, and the pressure mounts in the aftermath at a warehouse. Crime begets violence as the survivors -- veteran Mr. White, newcomer Mr. Orange, psychopathic parolee Mr. Blonde, bickering weasel Mr. Pink and Nice Guy Eddie -- unravel.
# The Godfather Part III
# In the midst of trying to legitimize his business dealings in 1979 New York and Italy, aging mafia don, Michael Corleone seeks forgiveness for his sins while taking a young protege under his wing.
# The Godfather
# Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.
# Full Metal Jacket
# A pragmatic U.S. Marine observes the dehumanizing effects the U.S.-Vietnam War has on his fellow recruits from their brutal boot camp training to the bloody street fighting in Hue.
# Heat
# Obsessive master thief Neil McCauley leads a top-notch crew on various daring heists throughout Los Angeles while determined detective Vincent Hanna pursues him without rest. Each man recognizes and respects the ability and the dedication of the other even though they are aware their cat-and-mouse game may end in violence.
# Casino
# In early-1970s Las Vegas, Sam "Ace" Rothstein gets tapped by his bosses to head the Tangiers Casino. At first, he's a great success in the job, but over the years, problems with his loose-cannon enforcer Nicky Santoro, his ex-hustler wife Ginger, her con-artist ex Lester Diamond and a handful of corrupt politicians put Sam in ever-increasing danger.
# Pulp Fiction
# A burger-loving hit man, his philosophical partner, a drug-addled gangster's moll and a washed-up boxer converge in this sprawling, comedic crime caper. Their adventures unfurl in three stories that ingeniously trip back and forth in time.
# The Usual Suspects
# Held in an L.A. interrogation room, Verbal Kint attempts to convince the feds that a mythic crime lord, Keyser Soze, not only exists, but was also responsible for drawing him and his four partners into a multi-million dollar heist that ended with an explosion in San Pedro harbor – leaving few survivors. Verbal lures his interrogators with an incredible story of the crime lord's almost supernatural prowess.
# The Departed
# To take down South Boston's Irish Mafia, the police send in one of their own to infiltrate the underworld, not realizing the syndicate has done likewise. While an undercover cop curries favor with the mob kingpin, a career criminal rises through the police ranks. But both sides soon discover there's a mole among them.
# One Flew Over the Cuckoo's Nest
# A petty criminal fakes insanity to serve his sentence in a mental ward rather than prison. He soon finds himself as a leader to the other patients—and an enemy to the cruel, domineering nurse who runs the ward.
# Se7en
# Two homicide detectives are on a desperate hunt for a serial killer whose crimes are based on the "seven deadly sins" in this dark and haunting film that takes viewers from the tortured remains of one victim to the next. The seasoned Det. Sommerset researches each sin in an effort to get inside the killer's mind, while his novice partner, Mills, scoffs at his efforts to unravel the case.
# Apocalypse Now
# At the height of the Vietnam war, Captain Benjamin Willard is sent on a dangerous mission that, officially, "does not exist, nor will it ever exist." His goal is to locate - and eliminate - a mysterious Green Beret Colonel named Walter Kurtz, who has been leading his personal army on illegal guerrilla missions into enemy territory.
# A Clockwork Orange
# In a near-future Britain, young Alexander DeLarge and his pals get their kicks beating and raping anyone they please. When not destroying the lives of others, Alex swoons to the music of Beethoven. The state, eager to crack down on juvenile crime, gives an incarcerated Alex the option to undergo an invasive procedure that'll rob him of all personal agency. In a time when conscience is a commodity, can Alex change his tune?
# The Shining
# Jack Torrance accepts a caretaker job at the Overlook Hotel, where he, along with his wife Wendy and their son Danny, must live isolated from the rest of the world for the winter. But they aren't prepared for the madness that lurks within.
# Carlito's Way
# A Puerto-Rican ex-con, just released from prison, pledges to stay away from drugs and violence despite the pressure around him, and lead a better life outside NYC.
# The Silence of the Lambs
# Clarice Starling is a top student at the FBI's training academy.  Jack Crawford wants Clarice to interview Dr. Hannibal Lecter, a brilliant psychiatrist who is also a violent psychopath, serving life behind bars for various acts of murder and cannibalism.  Crawford believes that Lecter may have insight into a case and that Starling, as an attractive young woman, may be just the bait to draw him out.
# The Untouchables
# Young Treasury Agent Eliot Ness arrives in Chicago and is determined to take down Al Capone, but it's not going to be easy because Capone has the police in his pocket. Ness meets Jim Malone, a veteran patrolman and probably the most honorable one on the force. He asks Malone to help him get Capone, but Malone warns him that if he goes after Capone, he is going to war.
# Inglourious Basterds
# In Nazi-occupied France during World War II, a group of Jewish-American soldiers known as "The Basterds" are chosen specifically to spread fear throughout the Third Reich by scalping and brutally killing Nazis. The Basterds, lead by Lt. Aldo Raine soon cross paths with a French-Jewish teenage girl who runs a movie theater in Paris which is targeted by the soldiers.

# %%
movie = Movie()
popular = movie.popular()

for p in popular:
    print(p.id)
    print(p.title)
    print(p.overview)
    print(p.poster_path)
# Out:
# 787699
# Wonka
# Willy Wonka – chock-full of ideas and determined to change the world one delectable bite at a time – is proof that the best things in life begin with a dream, and if you’re lucky enough to meet Willy Wonka, anything is possible.
# /qhb1qOilapbapxWQn9jtRCMwXJF.jpg
# 466420
# Killers of the Flower Moon
# When oil is discovered in 1920s Oklahoma under Osage Nation land, the Osage people are murdered one by one—until the FBI steps in to unravel the mystery.
# /dB6Krk806zeqd0YNp2ngQ9zXteH.jpg
# 572802
# Aquaman and the Lost Kingdom
# Black Manta, still driven by the need to avenge his father's death and wielding the power of the mythic Black Trident, will stop at nothing to take Aquaman down once and for all. To defeat him, Aquaman must turn to his imprisoned brother Orm, the former King of Atlantis, to forge an unlikely alliance in order to save the world from irreversible destruction.
# /8xV47NDrjdZDpkVcCFqkdHa3T0C.jpg
# 897087
# Freelance
# An ex-special forces operative takes a job to provide security for a journalist as she interviews a dictator, but a military coup breaks out in the middle of the interview, they are forced to escape into the jungle where they must survive.
# /7Bd4EUOqQDKZXA6Od5gkfzRNb0.jpg
# 695721
# The Hunger Games: The Ballad of Songbirds & Snakes
# 64 years before he becomes the tyrannical president of Panem, Coriolanus Snow sees a chance for a change in fortunes when he mentors Lucy Gray Baird, the female tribute from District 12.
# /mBaXZ95R2OxueZhvQbcEWy2DqyO.jpg
# 901362
# Trolls Band Together
# When Branch's brother, Floyd, is kidnapped for his musical talents by a pair of nefarious pop-star villains, Branch and Poppy embark on a harrowing and emotional journey to reunite the other brothers and rescue Floyd from a fate even worse than pop-culture obscurity.
# /bkpPTZUdq31UGDovmszsg2CchiI.jpg
# 726209
# Leave the World Behind
# A family's getaway to a luxurious rental home takes an ominous turn when a cyberattack knocks out their devices—and two strangers appear at their door.
# /29rhl1xopxA7JlGVVsf1UHfYPvN.jpg
# 1029575
# The Family Plan
# Dan Morgan is many things: a devoted husband, a loving father, a celebrated car salesman. He's also a former assassin. And when his past catches up to his present, he's forced to take his unsuspecting family on a road trip unlike any other.
# /jLLtx3nTRSLGPAKl4RoIv1FbEBr.jpg
# 872585
# Oppenheimer
# The story of J. Robert Oppenheimer's role in the development of the atomic bomb during World War II.
# /8Gxv8gSFCU0XGDykEGv7zR1n2ua.jpg
# 1075794
# Leo
# Jaded 74-year-old lizard Leo has been stuck in the same Florida classroom for decades with his terrarium-mate turtle. When he learns he only has one year left to live, he plans to escape to experience life on the outside but instead gets caught up in the problems of his anxious students — including an impossibly mean substitute teacher.
# /pD6sL4vntUOXHmuvJPPZAgvyfd9.jpg
# 385687
# Fast X
# Over many missions and against impossible odds, Dom Toretto and his family have outsmarted, out-nerved and outdriven every foe in their path. Now, they confront the most lethal opponent they've ever faced: A terrifying threat emerging from the shadows of the past who's fueled by blood revenge, and who is determined to shatter this family and destroy everything—and everyone—that Dom loves, forever.
# /fiVW06jE7z9YnO4trhaMEdclSiC.jpg
# 520758
# Chicken Run: Dawn of the Nugget
# A band of fearless chickens flock together to save poultry-kind from an unsettling new threat: a nearby farm that's cooking up something suspicious.
# /exNtEY8QUuQh9e23wSQjkPxKIU3.jpg
# 507089
# Five Nights at Freddy's
# Recently fired and desperate for work, a troubled young man named Mike agrees to take a position as a night security guard at an abandoned theme restaurant: Freddy Fazbear's Pizzeria. But he soon discovers that nothing at Freddy's is what it seems.
# /7BpNtNfxuocYEVREzVMO75hso1l.jpg
# 670292
# The Creator
# Amid a future war between the human race and the forces of artificial intelligence, a hardened ex-special forces agent grieving the disappearance of his wife, is recruited to hunt down and kill the Creator, the elusive architect of advanced AI who has developed a mysterious weapon with the power to end the war—and mankind itself.
# /vBZ0qvaRxqEhZwl6LWmruJqWE8Z.jpg
# 983507
# Good Boy
# Christian - a millionaire heir, meets Sigrid - a young student, on a dating app. They hit it off quickly, but there's only one problem: Christian lives with Frank, a man who dresses up and constantly acts like a dog.
# /9DPG1gxLwV2oyFdHq3SnISsWbse.jpg
# 656156
# A Man of Reason
# After 10 years of incarceration on behalf of his employer, all Su-hyuk wants is a normal life - one he hopes will include his former girlfriend, Min-seo, and their daughter, In-bi. But once you've penetrated the upper echelons of the underworld, normal can prove hard to come by. Sometime in the past decade, meanwhile, Su-hyuk's employer has adopted an air of legitimacy. These days, the old gang steal and murder in the name of urban development. And they want the reluctant Su-hyuk on board.
# /ePwZs1oOh4pg8UZP8DuVZZeIn89.jpg
# 1146225
# Escaping Paradise
# When a young couple vacations on an exotic island, they encounter a dangerous fugitive who is determined to keep them from leaving.
# /3UCTls0hVKMCwWtkTmwKcCOzlgu.jpg
# 844416
# Rumble Through the Dark
# Set in the dark landscape of the Mississippi Delta, where a former bare-knuckle fighter must win one last fight to pay off his debts to the local mob boss and save his childhood home—the stakes nothing less than life or death.
# /19UbYIT9WEQS5qSD3BREDxVXk8g.jpg
# 299054
# Expend4bles
# Armed with every weapon they can get their hands on and the skills to use them, The Expendables are the world’s last line of defense and the team that gets called when all other options are off the table. But new team members with new styles and tactics are going to give “new blood” a whole new meaning.
# /iwsMu0ehRPbtaSxqiaUDQB9qMWT.jpg
# 945937
# Fast Charlie
# When his aging mob boss is whacked, Charlie Swift, a loyal friend and hired gun, will stop at nothing to destroy the upcoming crew that took him out.
# /3y72ffwYRUPOj4yOQbiTaN897Tm.jpg

# %%
import requests
response = requests.get("https://api.themoviedb.org/3/discover/movie?api_key=bde7aaed15f664fa80f11f3ea353eb92&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&page=2&primary_release_year=2010")

# %%
response.json()
# Out:
# {'page': 2,
#  'results': [{'adult': False,
#    'backdrop_path': '/zWhEhVvswpKolTp1rmUdK30mMov.jpg',
#    'genre_ids': [878, 28, 53],
#    'id': 34851,
#    'original_language': 'en',
#    'original_title': 'Predators',
#    'overview': 'A group of cold-blooded killers find themselves trapped on an alien planet to be hunted by extraterrestrial Predators.',
#    'popularity': 57.728,
#    'poster_path': '/sx5EuckP7SBQrlMlxg0PLt282WS.jpg',
#    'release_date': '2010-07-03',
#    'title': 'Predators',
#    'video': False,
#    'vote_average': 6.2,
#    'vote_count': 3654},
#   {'adult': False,
#    'backdrop_path': '/mcSQa6hyBY3kLj0Eaey2K1Ev852.jpg',
#    'genre_ids': [18, 35, 10749],
#    'id': 43347,
#    'original_language': 'en',
#    'original_title': 'Love & Other Drugs',
#    'overview': "Maggie is an alluring free spirit who won't let anyone – or anything – tie her down. But she meets her match in Jamie, whose relentless and nearly infallible charm serves him well with the ladies and the cutthroat world of pharmaceutical sales. Maggie and Jamie's evolving relationship takes them both by surprise, as they find themselves under the influence of the ultimate drug: love.",
#    'popularity': 54.178,
#    'poster_path': '/wZLM2uKJRYNchLmiCIjosX0rXy8.jpg',
#    'release_date': '2010-11-22',
#    'title': 'Love & Other Drugs',
#    'video': False,
#    'vote_average': 7,
#    'vote_count': 4625},
#   {'adult': False,
#    'backdrop_path': '/tMpeVt7T2S2NaeEaNCUunCm7laX.jpg',
#    'genre_ids': [53, 12, 28],
#    'id': 27578,
#    'original_language': 'en',
#    'original_title': 'The Expendables',
#    'overview': 'Barney Ross leads a band of highly skilled mercenaries including knife enthusiast Lee Christmas, a martial arts expert Yin Yang, heavy weapons specialist Hale Caesar, demolitionist Toll Road, and a loose-cannon sniper Gunner Jensen. When the group is commissioned by the mysterious Mr. Church to assassinate the dictator of a small South American island, Barney and Lee visit the remote locale to scout out their opposition and discover the true nature of the conflict engulfing the city.',
#    'popularity': 61.223,
#    'poster_path': '/tDynwDj3pvexrEQ8wb0uy8EdcGQ.jpg',
#    'release_date': '2010-08-03',
#    'title': 'The Expendables',
#    'video': False,
#    'vote_average': 6.2,
#    'vote_count': 7071},
#   {'adult': False,
#    'backdrop_path': '/9Cip74Gl1xOkRP0e4OAiPZp8C4k.jpg',
#    'genre_ids': [28, 12, 18, 10751],
#    'id': 38575,
#    'original_language': 'en',
#    'original_title': 'The Karate Kid',
#    'overview': "Twelve-year-old Dre Parker could have been the most popular kid in Detroit, but his mother's latest career move has landed him in China. Dre immediately falls for his classmate Mei Ying but the cultural differences make such a friendship impossible. Even worse, Dre's feelings make him an enemy of the class bully, Cheng. With no friends in a strange land, Dre has nowhere to turn but maintenance man Mr. Han, who is a kung fu master. As Han teaches Dre that kung fu is not about punches and parries, but maturity and calm, Dre realizes that facing down the bullies will be the fight of his life.",
#    'popularity': 53.254,
#    'poster_path': '/o4gwFcm6qRgnC9Gff4giy0POHdF.jpg',
#    'release_date': '2010-06-10',
#    'title': 'The Karate Kid',
#    'video': False,
#    'vote_average': 6.5,
#    'vote_count': 5454},
#   {'adult': False,
#    'backdrop_path': '/msU3F9DVNFvCsQVxhxliyWSO03D.jpg',
#    'genre_ids': [28, 12, 14],
#    'id': 10196,
#    'original_language': 'en',
#    'original_title': 'The Last Airbender',
#    'overview': 'The story follows the adventures of Aang, a young successor to a long line of Avatars, who must put his childhood ways aside and stop the Fire Nation from enslaving the Water, Earth and Air nations.',
#    'popularity': 45.447,
#    'poster_path': '/zgwRTYWEEPivTwjB9S03HtmMcbM.jpg',
#    'release_date': '2010-06-30',
#    'title': 'The Last Airbender',
#    'video': False,
#    'vote_average': 4.7,
#    'vote_count': 3620},
#   {'adult': False,
#    'backdrop_path': '/zK7wNuUQ4w0QQp9FF20YTPVgpyN.jpg',
#    'genre_ids': [12, 28, 878],
#    'id': 20526,
#    'original_language': 'en',
#    'original_title': 'TRON: Legacy',
#    'overview': "Sam Flynn, the tech-savvy and daring son of Kevin Flynn, investigates his father's disappearance and is pulled into The Grid. With the help of a mysterious program named Quorra, Sam quests to stop evil dictator Clu from crossing into the real world.",
#    'popularity': 50.375,
#    'poster_path': '/vuifSABRpSnxCAOxEnWpNbZSXpp.jpg',
#    'release_date': '2010-12-14',
#    'title': 'TRON: Legacy',
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 6521},
#   {'adult': False,
#    'backdrop_path': '/8LSl2BPsRmookhO0UITB6PStZJX.jpg',
#    'genre_ids': [12, 10751, 14],
#    'id': 10140,
#    'original_language': 'en',
#    'original_title': 'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#    'overview': 'This time around Edmund and Lucy Pevensie, along with their pesky cousin Eustace Scrubb find themselves swallowed into a painting and on to a fantastic Narnian ship headed for the very edges of the world.',
#    'popularity': 49.328,
#    'poster_path': '/z6LVJXEmY8E6s57uf8cV3RlWvws.jpg',
#    'release_date': '2010-12-02',
#    'title': 'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 5111},
#   {'adult': False,
#    'backdrop_path': '/irpJXGiVr539uuspcQcNdkhS2lq.jpg',
#    'genre_ids': [16, 28, 35, 10751, 878],
#    'id': 38055,
#    'original_language': 'en',
#    'original_title': 'Megamind',
#    'overview': 'After Megamind, a highly intelligent alien supervillain, defeats his long-time nemesis Metro Man, Megamind creates a new hero to fight, but must act to save the city when his "creation" becomes an even worse villain than he was.',
#    'popularity': 42.669,
#    'poster_path': '/uZ9ytt3sPTx62XTfN56ILSuYWRe.jpg',
#    'release_date': '2010-10-28',
#    'title': 'Megamind',
#    'video': False,
#    'vote_average': 7,
#    'vote_count': 6185},
#   {'adult': False,
#    'backdrop_path': '/jGyIsNQBQ17G92ZxuTErrMl6W1e.jpg',
#    'genre_ids': [27, 28, 14],
#    'id': 22894,
#    'original_language': 'en',
#    'original_title': 'Legion',
#    'overview': "When God loses faith in humankind, he sends his legion of angels to bring on the Apocalypse. Humanity's only hope for survival lies in a group of strangers trapped in an out-of-the-way, desert diner with the Archangel Michael.",
#    'popularity': 59.182,
#    'poster_path': '/ykocDqwg5PRUopnBVb1x1DWnEJF.jpg',
#    'release_date': '2010-01-21',
#    'title': 'Legion',
#    'video': False,
#    'vote_average': 5.8,
#    'vote_count': 2345},
#   {'adult': False,
#    'backdrop_path': '/puAUfSiVrQO2DPKOobHFjqVcXPt.jpg',
#    'genre_ids': [53, 28, 12, 35, 80],
#    'id': 34544,
#    'original_language': 'en',
#    'original_title': 'The A-Team',
#    'overview': "A group of Iraq War veterans goes on the run from U.S. military forces while they try to clear their names after being framed for a crime they didn't commit. Along the way, Col. Hannibal Smith, Capt. H.M. ‘Howling Mad’ Murdock , Sgt. Bosco ‘B.A.’ Baracus, and Lt. Templeton ‘Faceman’ Peck help out various people they encounter.",
#    'popularity': 37.539,
#    'poster_path': '/k3mKy2zYfzqGg9o5JeDyzSEPPHO.jpg',
#    'release_date': '2010-06-09',
#    'title': 'The A-Team',
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 4243},
#   {'adult': False,
#    'backdrop_path': '/P4bGyJQF0shAcRku3I2perNUQR.jpg',
#    'genre_ids': [28, 80],
#    'id': 23483,
#    'original_language': 'en',
#    'original_title': 'Kick-Ass',
#    'overview': 'Dave Lizewski is an unnoticed high school student and comic book fan who one day decides to become a super-hero, even though he has no powers, training or meaningful reason to do so.',
#    'popularity': 39.978,
#    'poster_path': '/8citjdBmjddZjlPsAHEyCKwGVvD.jpg',
#    'release_date': '2010-03-22',
#    'title': 'Kick-Ass',
#    'video': False,
#    'vote_average': 7.1,
#    'vote_count': 10844},
#   {'adult': False,
#    'backdrop_path': '/hUUTJPmvBvBKILNLrBu16pRxr6M.jpg',
#    'genre_ids': [12, 14, 28],
#    'id': 18823,
#    'original_language': 'en',
#    'original_title': 'Clash of the Titans',
#    'overview': 'Born of a god but raised as a man, Perseus is helpless to save his family from Hades, vengeful god of the underworld. With nothing to lose, Perseus volunteers to lead a dangerous mission to defeat Hades before he can seize power from Zeus and unleash hell on earth. Battling unholy demons and fearsome beasts, Perseus and his warriors will only survive if Perseus accepts his power as a god, defies fate and creates his own destiny.',
#    'popularity': 55.152,
#    'poster_path': '/6iHYLipwEyZUPNO8MM3l1yHDaFE.jpg',
#    'release_date': '2010-03-31',
#    'title': 'Clash of the Titans',
#    'video': False,
#    'vote_average': 5.9,
#    'vote_count': 5783},
#   {'adult': False,
#    'backdrop_path': '/owAe5rRStnX7ibVAPmza3NCXjCy.jpg',
#    'genre_ids': [80, 18, 53],
#    'id': 23168,
#    'original_language': 'en',
#    'original_title': 'The Town',
#    'overview': 'Doug MacRay is a longtime thief, who, smarter than the rest of his crew, is looking for his chance to exit the game. When a bank job leads to the group kidnapping an attractive branch manager, he takes on the role of monitoring her – but their burgeoning relationship threatens to unveil the identities of Doug and his crew to the FBI Agent who is on their case.',
#    'popularity': 44.325,
#    'poster_path': '/3NIzyXkfylsjflRKSz8Fts3lXzm.jpg',
#    'release_date': '2010-09-15',
#    'title': 'The Town',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 4520},
#   {'adult': False,
#    'backdrop_path': '/wWWXd27yF8sK9bLgAD4zxiGcYJW.jpg',
#    'genre_ids': [10751, 16],
#    'id': 44874,
#    'original_language': 'en',
#    'original_title': 'Barbie: A Fashion Fairytale',
#    'overview': "Join Barbie in a colourful, modern-day fairytale filled with fashion, friends and fun! Barbie and her dog Sequin jet off to visit her Aunt's amazing fashion house in Paris, and much to her surprise it's about to be shut down forever. After she discovers three enchanting Flairies with sparkle-magic powers, Barbie comes up with a brilliant idea to save the business. She even inspires Alice, a shy fashion designer, and together they create a dazzling runway fashion show. Barbie shows that magic happens when you believe in yourself.",
#    'popularity': 44.398,
#    'poster_path': '/bFnf8f8DXdCANQ7Y62djgubhh4P.jpg',
#    'release_date': '2010-09-14',
#    'title': 'Barbie: A Fashion Fairytale',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 682},
#   {'adult': False,
#    'backdrop_path': '/lFNADy1elNHpUxML41Mi7JRstey.jpg',
#    'genre_ids': [16, 10751, 14],
#    'id': 34134,
#    'original_language': 'en',
#    'original_title': 'Barbie in A Mermaid Tale',
#    'overview': "Barbie stars as Merliah, a surfer who learns a shocking secret: she's a mermaid! She and her dolphin friend set out for an undersea adventure to rescue her mother, the queen of Oceana.",
#    'popularity': 42.139,
#    'poster_path': '/jtOlo3AaXVBnqfMeKGFrZUMPFui.jpg',
#    'release_date': '2010-01-25',
#    'title': 'Barbie in A Mermaid Tale',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 665},
#   {'adult': False,
#    'backdrop_path': '/r1qHFpAJ1HZZm5CuFHw5zhgufMB.jpg',
#    'genre_ids': [35, 27],
#    'id': 43593,
#    'original_language': 'en',
#    'original_title': 'Piranha 3D',
#    'overview': "Each year the population of sleepy Lake Victoria, Arizona explodes from 5,000 to 50,000 residents for the annual Spring Break celebration. But then, an earthquake opens an underwater chasm, releasing an enormous swarm of ancient Piranha that have been dormant for thousands of years, now with a taste for human flesh. This year, there's something more to worry about than the usual hangovers and complaints from locals, a new type of terror is about to be cut loose on Lake Victoria.",
#    'popularity': 42.412,
#    'poster_path': '/9651UNV3Mj45IOYCD9vlxFpYiw0.jpg',
#    'release_date': '2010-08-20',
#    'title': 'Piranha 3D',
#    'video': False,
#    'vote_average': 5.4,
#    'vote_count': 1963},
#   {'adult': False,
#    'backdrop_path': '/A3sSawJG5de6VboyKIVg01x3H6E.jpg',
#    'genre_ids': [9648, 14, 35, 12],
#    'id': 47533,
#    'original_language': 'en',
#    'original_title': 'Scooby-Doo! Curse of the Lake Monster',
#    'overview': "Scooby-Doo and the gang are on the case when a mysterious lake monster starts scaring the guests at a summer resort in Erie Point, where Fred, Daphne, Velma and Shaggy have taken on seasonal jobs to pay for a barn they accidentally burned down. But in addition to sneaking suspicions, there's some romance in the air.",
#    'popularity': 36.874,
#    'poster_path': '/4fvCOntbgzZ9crbduTHRhgN8bgq.jpg',
#    'release_date': '2010-10-15',
#    'title': 'Scooby-Doo! Curse of the Lake Monster',
#    'video': False,
#    'vote_average': 6.2,
#    'vote_count': 460},
#   {'adult': False,
#    'backdrop_path': '/pJKqcciCeUFsuYukbEzdOaYyvy9.jpg',
#    'genre_ids': [18, 10770],
#    'id': 896381,
#    'original_language': 'cs',
#    'original_title': 'Rytmus v patách',
#    'overview': '',
#    'popularity': 52.219,
#    'poster_path': '/qtOFLfNbgLU7vq4BgmHDK3SZwMC.jpg',
#    'release_date': '2010-03-14',
#    'title': 'The Sound of Freedom',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': '/5viGnT4PiwF1BTh5ZwOW5VON7Ss.jpg',
#    'genre_ids': [28, 53, 878],
#    'id': 51620,
#    'original_language': 'en',
#    'original_title': 'Death Race 2',
#    'overview': "In the world's most dangerous prison, a new game is born: Death Race. The rules of this adrenaline-fueled blood sport are simple, drive or die. When repentant convict Carl Lucas discovers there's a price on his head, his only hope is to survive a twisted race against an army of hardened criminals and tricked-out cars.",
#    'popularity': 38.554,
#    'poster_path': '/80mBFNVvak2bA9TJN1MD0yM7Lfi.jpg',
#    'release_date': '2010-11-12',
#    'title': 'Death Race 2',
#    'video': False,
#    'vote_average': 5.8,
#    'vote_count': 990},
#   {'adult': False,
#    'backdrop_path': '/dnOrJdHW697UvKvtX4lYVasomBu.jpg',
#    'genre_ids': [12, 14, 28],
#    'id': 9543,
#    'original_language': 'en',
#    'original_title': 'Prince of Persia: The Sands of Time',
#    'overview': 'A rogue prince reluctantly joins forces with a mysterious princess and together, they race against dark forces to safeguard an ancient dagger capable of releasing the Sands of Time – gift from the gods that can reverse time and allow its possessor to rule the world.',
#    'popularity': 36.447,
#    'poster_path': '/34Vbk8VNMtETTOSG3jCHWwlWr1m.jpg',
#    'release_date': '2010-05-19',
#    'title': 'Prince of Persia: The Sands of Time',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 6256}],
#  'total_pages': 735,
#  'total_results': 14698}

# %%
years = np.arange(2020, 2021)
id_movies = []
release_date = []
title = []
for i in years:
    print("year:", i )
    for j in range(1,5): 
        response = requests.get(f'https://api.themoviedb.org/3/discover/movie?api_key={api_key}&page={j}&primary_release_year={i}&sort_by=popularity.desc')
        highest_revenue = response.json()
        print(highest_revenue)
        
        first_results = highest_revenue["results"]
       
        for k in first_results:
                     
            try:                
                release_date.append(k["release_date"])
                title.append(k["title"])
                id_movies.append(k["id"])  
            except:
                release_date.append(np.nan)
                title.append(np.nan)
                id_movies.append(np.nan)
                continue

df_movies_id = pd.DataFrame(id_movies, columns=["id"])
df_movies_id["date"] = release_date
df_movies_id["title"] = title
# Out:
# year: 2020
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/tVIzzMLT9pye5BWNwHovBleruNS.jpg', 'genre_ids': [28], 'id': 662167, 'original_language': 'en', 'original_title': 'Agent Jade Black', 'overview': 'A skilled young female agent is tasked with capturing a rogue former agent before she can unleash a biological weapon starting with the wealthy and powerful purveyors of the international sex trade.', 'popularity': 182.36, 'poster_path': '/wGHaEtBz6AXqGVooaADB1tlyjBp.jpg', 'release_date': '2020-09-29', 'title': 'Agent Jade Black', 'video': False, 'vote_average': 2, 'vote_count': 4}, {'adult': False, 'backdrop_path': '/7dCzb1oa7ACYi66VIrE1wqmftAa.jpg', 'genre_ids': [28], 'id': 660521, 'original_language': 'en', 'original_title': 'The Mercenary', 'overview': 'When a mission in South America goes wrong a mercenary is left for dead, but he is nursed back to health and reborn with a new outlook on life. But his peaceful days are short-lived when mercenaries he used to work with cross his path again and he is forced to revisit and face his own demons.', 'popularity': 147.405, 'poster_path': '/p3wgefagejlefFEDsLRHiXU7NGu.jpg', 'release_date': '2020-01-07', 'title': 'The Mercenary', 'video': False, 'vote_average': 6.3, 'vote_count': 22}, {'adult': False, 'backdrop_path': '/6hgItrYQEG33y0I7yP2SRl2ei4w.jpg', 'genre_ids': [10749, 18], 'id': 613504, 'original_language': 'en', 'original_title': 'After We Collided', 'overview': 'Tessa finds herself struggling with her complicated relationship with Hardin; she faces a dilemma that could change their lives forever.', 'popularity': 104.154, 'poster_path': '/kiX7UYfOpYrMFSAGbI6j1pFkLzQ.jpg', 'release_date': '2020-09-02', 'title': 'After We Collided', 'video': False, 'vote_average': 7.2, 'vote_count': 5118}, {'adult': False, 'backdrop_path': '/ybGEvB6725PkVuUfEo2txLGRwTj.jpg', 'genre_ids': [10751, 16, 35, 14, 12, 10402], 'id': 446893, 'original_language': 'en', 'original_title': 'Trolls World Tour', 'overview': 'Queen Poppy and Branch make a surprising discovery — there are other Troll worlds beyond their own, and their distinct differences create big clashes between these various tribes. When a mysterious threat puts all of the Trolls across the land in danger, Poppy, Branch, and their band of friends must embark on an epic quest to create harmony among the feuding Trolls to unite them against certain doom.', 'popularity': 98.62, 'poster_path': '/7W0G3YECgDAfnuiHG91r8WqgIOe.jpg', 'release_date': '2020-03-11', 'title': 'Trolls World Tour', 'video': False, 'vote_average': 7.3, 'vote_count': 1996}, {'adult': False, 'backdrop_path': '/5lmhjGvg5ddXbTXzeNJfU4qpIeh.jpg', 'genre_ids': [28, 18, 36], 'id': 492008, 'original_language': 'ko', 'original_title': '검객', 'overview': "After being blinded in a coup against the king, Joseon's greatest swordsman goes into hiding, far removed from his city's anguish. But when traffickers kidnap his daughter, he has no choice but to unsheathe his sword once more.", 'popularity': 95.109, 'poster_path': '/r08U3dwiOeStXcjYmfnRyumgKyq.jpg', 'release_date': '2020-09-23', 'title': 'The Swordsman', 'video': False, 'vote_average': 7.5, 'vote_count': 202}, {'adult': False, 'backdrop_path': '/sOXF8IiOx6Rii5RCWnzmYSJoBCx.jpg', 'genre_ids': [27, 878, 35], 'id': 741592, 'original_language': 'en', 'original_title': 'Cyst', 'overview': "In the 1960s, a nurse's last day on her job is ruined when a doctor inadvertently creates a cyst monster that terrorizes the office.", 'popularity': 69.625, 'poster_path': '/5nJwS765eHzCb5M8BTT2sl0lxxv.jpg', 'release_date': '2020-09-24', 'title': 'Cyst', 'video': False, 'vote_average': 4.5, 'vote_count': 40}, {'adult': False, 'backdrop_path': '/vw3zNfzvnVNF7nIjpiEgcdznfeC.jpg', 'genre_ids': [16, 28, 14], 'id': 664767, 'original_language': 'en', 'original_title': "Mortal Kombat Legends: Scorpion's Revenge", 'overview': 'After the vicious slaughter of his family by stone-cold mercenary Sub-Zero, Hanzo Hasashi is exiled to the torturous Netherrealm. T ...
# {'page': 2, 'results': [{'adult': False, 'backdrop_path': '/zMrk2G3XsnfYKiIp1NEfdtvDyBH.jpg', 'genre_ids': [12, 14, 18, 28], 'id': 337401, 'original_language': 'en', 'original_title': 'Mulan', 'overview': 'When the Emperor of China issues a decree that one man per family must serve in the Imperial Chinese Army to defend the country from Huns, Hua Mulan, the eldest daughter of an honored warrior, steps in to take the place of her ailing father. She is spirited, determined and quick on her feet. Disguised as a man by the name of Hua Jun, she is tested every step of the way and must harness her innermost strength and embrace her true potential.', 'popularity': 59.159, 'poster_path': '/aKx1ARwG55zZ0GpRvU2WrGrCG9o.jpg', 'release_date': '2020-09-04', 'title': 'Mulan', 'video': False, 'vote_average': 6.9, 'vote_count': 6351}, {'adult': False, 'backdrop_path': '/aLqtWLA6NQHBwQHvHDq5z4EKUm0.jpg', 'genre_ids': [16, 14, 10749, 18], 'id': 533514, 'original_language': 'ja', 'original_title': '劇場版 ヴァイオレット・エヴァーガーデン', 'overview': 'As the world moves on from the war and technological advances bring changes to her life, Violet still hopes to see her lost commanding officer again.', 'popularity': 50.608, 'poster_path': '/fwSonK8WrAEqWY7sqjvGRCgzIij.jpg', 'release_date': '2020-09-18', 'title': 'Violet Evergarden: The Movie', 'video': False, 'vote_average': 8.3, 'vote_count': 361}, {'adult': False, 'backdrop_path': '/fStC0dSCRQslE9NzXa36EyOom81.jpg', 'genre_ids': [16, 10751, 878], 'id': 728754, 'original_language': 'ja', 'original_title': 'STAND BY ME ドラえもん2', 'overview': 'Nobita travels to the future to show his beloved grandma his bride, but adult Nobita has fled his own wedding.', 'popularity': 64.047, 'poster_path': '/vBv8iOFPLnXmtELUjcFc7OKHsR4.jpg', 'release_date': '2020-11-20', 'title': 'Stand by Me Doraemon 2', 'video': False, 'vote_average': 7.6, 'vote_count': 178}, {'adult': False, 'backdrop_path': '/y6FYAhaeFMj9Lsk8OdF2NeWQkbd.jpg', 'genre_ids': [10751, 28, 14, 35], 'id': 615677, 'original_language': 'en', 'original_title': 'We Can Be Heroes', 'overview': "When alien invaders capture Earth's superheroes, their kids must learn to work together to save their parents - and the planet.", 'popularity': 64.823, 'poster_path': '/1S21HpcKY6uQ9UAw68aICmrJaq6.jpg', 'release_date': '2020-12-25', 'title': 'We Can Be Heroes', 'video': False, 'vote_average': 6.1, 'vote_count': 715}, {'adult': False, 'backdrop_path': '/ww7eC3BqSbFsyE5H5qMde8WkxJ2.jpg', 'genre_ids': [27, 878, 28, 12], 'id': 443791, 'original_language': 'en', 'original_title': 'Underwater', 'overview': 'After an earthquake destroys their underwater station, six researchers must navigate two miles along the dangerous, unknown depths of the ocean floor to make it to safety in a race against time.', 'popularity': 62.169, 'poster_path': '/gzlbb3yeVISpQ3REd3Ga1scWGTU.jpg', 'release_date': '2020-01-08', 'title': 'Underwater', 'video': False, 'vote_average': 6.3, 'vote_count': 2862}, {'adult': False, 'backdrop_path': '/wu1uilmhM4TdluKi2ytfz8gidHf.jpg', 'genre_ids': [10751, 16, 14, 12, 35], 'id': 400160, 'original_language': 'en', 'original_title': 'The SpongeBob Movie: Sponge on the Run', 'overview': 'When his best friend Gary is suddenly snatched away, SpongeBob takes Patrick on a madcap mission far beyond Bikini Bottom to save their pink-shelled pal.', 'popularity': 71.905, 'poster_path': '/jlJ8nDhMhCYJuzOw3f52CP1W8MW.jpg', 'release_date': '2020-08-14', 'title': 'The SpongeBob Movie: Sponge on the Run', 'video': False, 'vote_average': 7.5, 'vote_count': 2736}, {'adult': False, 'backdrop_path': '/xNXKpsY1Rxq9Ncbw8WVs7j4ijZU.jpg', 'genre_ids': [18, 10749], 'id': 716263, 'original_language': 'ko', 'original_title': '시누이의 맛', 'overview': "Ha-ni who was on a honeymoon with her husband, Jae-ho, seems to be uncomfortable with her sister-in-law, Ye-ji. She is a freeloader who lives in her brother's house without any other job. When the close brother and sister's affection was being expressed boldly  ...
# {'page': 3, 'results': [{'adult': False, 'backdrop_path': '/xXBnM6uSTk6qqCf0SRZKXcga9Ba.jpg', 'genre_ids': [10752, 28, 18], 'id': 516486, 'original_language': 'en', 'original_title': 'Greyhound', 'overview': 'A first-time captain leads a convoy of allied ships carrying thousands of soldiers across the treacherous waters of the “Black Pit” to the front lines of WW2. With no air cover protection for 5 days, the captain and his convoy must battle the surrounding enemy Nazi U-boats in order to give the allies a chance to win the war.', 'popularity': 42.346, 'poster_path': '/kjMbDciooTbJPofVXgAoFjfX8Of.jpg', 'release_date': '2020-07-10', 'title': 'Greyhound', 'video': False, 'vote_average': 7.4, 'vote_count': 2621}, {'adult': False, 'backdrop_path': '/tintsaQ0WLzZsTMkTiqtMB3rfc8.jpg', 'genre_ids': [28, 80, 35], 'id': 522627, 'original_language': 'en', 'original_title': 'The Gentlemen', 'overview': 'American expat Mickey Pearson has built a highly profitable marijuana empire in London. When word gets out that he’s looking to cash out of the business forever it triggers plots, schemes, bribery and blackmail in an attempt to steal his domain out from under him.', 'popularity': 50.217, 'poster_path': '/jtrhTYB7xSrJxR1vusu99nvnZ1g.jpg', 'release_date': '2020-01-01', 'title': 'The Gentlemen', 'video': False, 'vote_average': 7.7, 'vote_count': 5206}, {'adult': False, 'backdrop_path': '/tljkeU2y1dCvT51Sv4ciNf0VfmV.jpg', 'genre_ids': [18, 53], 'id': 549514, 'original_language': 'en', 'original_title': 'Fatale', 'overview': "After a one-night stand, a successful married man finds himself entangled and tricked in a female detective's latest investigation murder scheme.", 'popularity': 39.744, 'poster_path': '/tGFXEyESXIuei5tZWXRkSRSFSxi.jpg', 'release_date': '2020-12-18', 'title': 'Fatale', 'video': False, 'vote_average': 6.1, 'vote_count': 295}, {'adult': False, 'backdrop_path': '/75ooojtgiKYm5LcCczbCexioZze.jpg', 'genre_ids': [35], 'id': 660982, 'original_language': 'en', 'original_title': "American Pie Presents: Girls' Rules", 'overview': "It's Senior year at East Great Falls. Annie, Kayla, Michelle, and Stephanie decide to harness their girl power and band together to get what they want their last year of high school.", 'popularity': 54.996, 'poster_path': '/xqvX5A24dbIWaeYsMTxxKX5qOfz.jpg', 'release_date': '2020-10-06', 'title': "American Pie Presents: Girls' Rules", 'video': False, 'vote_average': 6.2, 'vote_count': 558}, {'adult': False, 'backdrop_path': '/lfKVH9aQ9AODkQU5eA8s1Eba5Go.jpg', 'genre_ids': [16, 10751, 14], 'id': 520946, 'original_language': 'en', 'original_title': '100% Wolf', 'overview': "Freddy Lupin, heir to a proud family line of werewolves, is in for a shock when on his 14th birthday his first 'warfing' goes awry, turning him into a ferocious poodle.  The pack elders give Freddy until the next moonrise to prove he has the heart of a wolf, or risk being cast out forever.  With the help of an unlikely ally in a streetwise stray named Batty, Freddy must prove he's 100% Wolf.", 'popularity': 48.41, 'poster_path': '/2VrvxK4yxNCU6KVgo5TADJeBEQu.jpg', 'release_date': '2020-06-26', 'title': '100% Wolf', 'video': False, 'vote_average': 6, 'vote_count': 281}, {'adult': False, 'backdrop_path': '/axPvTxOKwbV70hdJgf3SfI71gDn.jpg', 'genre_ids': [10751, 35, 28], 'id': 726739, 'original_language': 'en', 'original_title': 'Cats & Dogs 3: Paws Unite', 'overview': "It's been ten years since the creation of the Great Truce, an elaborate joint-species surveillance system designed and monitored by cats and dogs to keep the peace when conflicts arise. But when a tech-savvy villain hacks into wireless networks to use frequencies only heard by cats and dogs, he manipulates them into conflict and the worldwide battle between cats and dogs is BACK ON. Now, a team of inexperienced and untested agents will have to use their old-school animal instincts to restore order and peace between cats and dogs everywhere.", 'popularity': 47.382, 'poster_pat ...
# {'page': 4, 'results': [{'adult': False, 'backdrop_path': '/hBOH4PNnhcGPgZbZjBwkx9gnNxI.jpg', 'genre_ids': [18, 36], 'id': 614560, 'original_language': 'en', 'original_title': 'Mank', 'overview': '1930s Hollywood is reevaluated through the eyes of scathing social critic and alcoholic screenwriter Herman J. Mankiewicz as he races to finish the screenplay of Citizen Kane.', 'popularity': 39.554, 'poster_path': '/4yzTcAtvzyZLLto4z04xobUK9el.jpg', 'release_date': '2020-11-13', 'title': 'Mank', 'video': False, 'vote_average': 6.7, 'vote_count': 1482}, {'adult': False, 'backdrop_path': '/lIE7kfdLBRd0KENNtOaIqPPWNqh.jpg', 'genre_ids': [27, 18, 14], 'id': 590995, 'original_language': 'en', 'original_title': 'The Craft: Legacy', 'overview': 'An eclectic foursome of aspiring teenage witches get more than they bargained for as they lean into their newfound powers.', 'popularity': 35.781, 'poster_path': '/lhMIra0pqWNuD6CIXoTmGwZ0EBS.jpg', 'release_date': '2020-10-28', 'title': 'The Craft: Legacy', 'video': False, 'vote_average': 6.2, 'vote_count': 726}, {'adult': False, 'backdrop_path': '/cojOMQvTwcPTSUc0BnRZqfKU34y.jpg', 'genre_ids': [878, 28, 80, 16], 'id': 655431, 'original_language': 'ja', 'original_title': 'PSYCHO-PASS サイコパス 3 FIRST INSPECTOR', 'overview': 'Inspector Kei Mikhail Ignatov finds himself involved with an organization named Bifrost with the possibility of freeing his wife if he betrays Unit One. Koichi Azusawa coordinates an assault on the Public Safety Bureau tower using his hacker Obata, locking down the building and kidnapping Inspector Arata Shindo. Azusawa demands that governor Karina Komiya resign from her position.', 'popularity': 43.72, 'poster_path': '/m2RzGRMbdMUcp8S3PYtlPpHa83g.jpg', 'release_date': '2020-03-27', 'title': 'Psycho-Pass 3: First Inspector', 'video': False, 'vote_average': 7.6, 'vote_count': 82}, {'adult': False, 'backdrop_path': '/fX8e94MEWSuTJExndVYxKsmA4Hw.jpg', 'genre_ids': [35, 53, 28, 12], 'id': 604822, 'original_language': 'zh', 'original_title': '急先锋', 'overview': "Covert security company Vanguard is the last hope of survival for an accountant after he is targeted by the world's deadliest mercenary organization.", 'popularity': 52.478, 'poster_path': '/mKvw1Ic9enfFlCPBNJGiejRPMUO.jpg', 'release_date': '2020-09-30', 'title': 'Vanguard', 'video': False, 'vote_average': 6.3, 'vote_count': 465}, {'adult': False, 'backdrop_path': '/3N316jUSdhvPyYTW29G4v9ebbcS.jpg', 'genre_ids': [53, 28, 80], 'id': 38700, 'original_language': 'en', 'original_title': 'Bad Boys for Life', 'overview': 'Marcus and Mike are forced to confront new threats, career changes, and midlife crises as they join the newly created elite team AMMO of the Miami police department to take down the ruthless Armando Armas, the vicious leader of a Miami drug cartel.', 'popularity': 41.159, 'poster_path': '/y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg', 'release_date': '2020-01-15', 'title': 'Bad Boys for Life', 'video': False, 'vote_average': 7.1, 'vote_count': 7631}, {'adult': False, 'backdrop_path': '/cStOy6KckiZjxZJStHiCCHNRW9t.jpg', 'genre_ids': [28, 80, 53], 'id': 696002, 'original_language': 'en', 'original_title': 'Paydirt', 'overview': 'A parolee teams up with his old crew determined to find a buried bag of cash stolen a decade ago from a DEA bust gone bad, while being tracked by a retired Sheriff.', 'popularity': 46.051, 'poster_path': '/jAGGV80ZO10YcmUJXK7YSBh1yvK.jpg', 'release_date': '2020-08-07', 'title': 'Paydirt', 'video': False, 'vote_average': 5.9, 'vote_count': 63}, {'adult': False, 'backdrop_path': '/21Q8bzu10YF9i4O5amBkJBombYo.jpg', 'genre_ids': [10402, 18, 10749], 'id': 585244, 'original_language': 'en', 'original_title': 'I Still Believe', 'overview': 'The true-life story of Christian music star Jeremy Camp and his journey of love and loss that looks to prove there is always hope.', 'popularity': 37.101, 'poster_path': '/dqA2FCzz4OMmXLitKopzf476RVB.jpg', 'release_date': '2020-03-12', 'title': 'I Still Believe', 'video': False ...

# %%
df_movies_id
# Out:
#         id        date                   title
# 0   662167  2020-09-29        Agent Jade Black
# 1   660521  2020-01-07           The Mercenary
# 2   613504  2020-09-02       After We Collided
# 3   446893  2020-03-11       Trolls World Tour
# 4   492008  2020-09-23           The Swordsman
# ..     ...         ...                     ...
# 75  552269  2020-09-14                Joe Bell
# 76  604578  2020-10-02             Spontaneous
# 77  601844  2020-07-23                   Becky
# 78  526702  2020-11-27            Black Beauty
# 79  546724  2020-08-28  We Summon the Darkness
#
# [80 rows x 3 columns]

# %%
df_movies_id["id"].values
# Out:
# array([662167, 660521, 613504, 446893, 492008, 741592, 664767, 654028,
#        454626, 481848, 508442, 635302, 577922, 545609, 590223, 571265,
#        520172, 464052, 529203, 448119, 337401, 533514, 728754, 615677,
#        443791, 400160, 716263, 508439, 627463, 677638, 556984, 662708,
#        615665, 717634, 553604, 524047, 702936, 592834, 667520, 495764,
#        516486, 522627, 549514, 660982, 520946, 726739, 531219, 458576,
#        595148, 342470, 627725, 675327, 539885, 780080, 738215, 385103,
#        686245, 338762, 508570, 603119, 614560, 590995, 655431, 604822,
#         38700, 696002, 585244, 637202, 662546, 581392, 651610, 447362,
#        449756, 547016, 750209, 552269, 604578, 601844, 526702, 546724],
#       dtype=int64)

# %%
dict_movies = {"title":[], "revenue":[], "budget":[]}
for q in df_movies_id["id"].values[:11]:
    response = requests.get(f'https://api.themoviedb.org/3/movie/{q}?api_key=' +  api_key + "&append_to_response=keywords,credits")
    highest_revenue = response.json()
    try:
        budget = highest_revenue["budget"]
        revenue = highest_revenue["revenue"]
        title = highest_revenue['title']
        dict_movies["title"].append(title)
        dict_movies["revenue"].append(revenue)
        dict_movies["budget"].append(budget)
    except:
        continue
df_movies_2010 = pd.DataFrame(dict_movies)

# %%
df_movies_2010
# Out:
#                                         title    revenue     budget
# 0                            Agent Jade Black          0          0
# 1                               The Mercenary          0          0
# 2                           After We Collided   48000000   14000000
# 3                           Trolls World Tour   49300000   90000000
# 4                               The Swordsman    1516150          0
# 5                                        Cyst          0          0
# 6   Mortal Kombat Legends: Scorpion's Revenge          0          0
# 7          The Christmas Chronicles: Part Two          0          0
# 8                          Sonic the Hedgehog  319700000   85000000
# 9                        The Call of the Wild  111200000  109000000
# 10                                       Soul  121000000  150000000

# %%
df_movies_2010.to_csv("data/df_movies_2010.csv")

# %% [markdown]
# ## Accediendo a datos de Youtube

# %%
# Importamos librerías
from googleapiclient.discovery import build

# %% [markdown]
# ### Información de una Canal de youtube (Primera request)

# %%
#!pip install google-api-python-client

# %%
from googleapiclient.discovery import build

# %%
#   https://cloud.google.com/console
#   https://github.com/googleapis/google-api-python-client
# Ensure that you have enabled the YouTube Data API for your project.

# %%
youtube = build("youtube", "v3", developerKey=api_key_y)


request = youtube.channels().list(
    part="statistics",
    id = "UCy5znSnfMsDwaLlROnZ7Qbg"
)

response = request.execute()

# %%
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'vAM_h5lFBcTVU6SSlq-Pm7oKkGY',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'W1ZvR65tmPo6_Gddm8v_FJSYgq8',
#    'id': 'UCy5znSnfMsDwaLlROnZ7Qbg',
#    'statistics': {'viewCount': '46454404',
#     'subscriberCount': '824000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '200'}}]}

# %% [markdown]
# ### Información videos de acuerdo a una búsqueda (query)

# %%
search_response = youtube.search().list(
    q="Chat gpt",
    part="snippet",
    order="viewCount",
    type="video",
    maxResults=50
).execute()

# %%
search_response["items"][0]["snippet"]
# Out:
# {'publishedAt': '2023-01-21T16:48:41Z',
#  'channelId': 'UCujkLB4kBWRn0YIGVczzEDg',
#  'title': 'Chat GPT A.I. Ki help se banai dish',
#  'description': '',
#  'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/default.jpg',
#    'width': 120,
#    'height': 90},
#   'medium': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/mqdefault.jpg',
#    'width': 320,
#    'height': 180},
#   'high': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/hqdefault.jpg',
#    'width': 480,
#    'height': 360}},
#  'channelTitle': 'Trippy Kitchen',
#  'liveBroadcastContent': 'none',
#  'publishTime': '2023-01-21T16:48:41Z'}

# %%
dict_videos = {"id":[], "channelTitle":[], "publish":[], "description":[], "title_video":[]} # Se crea diccionario con valores de listas vacías

for i in search_response["items"]: # Iterar listas
    dict_videos["id"].append(i["id"]["videoId"]) 
    dict_videos["channelTitle"].append(i["snippet"]["channelTitle"])
    dict_videos["publish"].append(i["snippet"]["publishTime"])
    dict_videos["description"].append(i["snippet"]["description"])
    dict_videos["title_video"].append(i["snippet"]["title"])

df_video_y = pd.DataFrame(dict_videos)
df_video_y
# Out:
#              id                      channelTitle               publish  \
# 0   dPZ8uUvrgZQ                    Trippy Kitchen  2023-01-21T16:48:41Z
# 1   kvTs_nbc8Eg                      Gotham Clips  2023-02-12T09:15:01Z
# 2   vJefOB8kec8                      Dhruv Rathee  2023-07-16T15:05:29Z
# 3   8y7GRYaYYQg                         candlesan  2023-03-23T16:00:08Z
# 4   t0x6WNItdX4                      Agnit Shorts  2023-04-12T04:30:22Z
# 5   vx0_3BIwUwE                     Greenskull AI  2023-12-14T20:45:02Z
# 6   L_Guz73e6fw                       Lex Fridman  2023-03-25T18:03:21Z
# 7   zzPwTJGBLOc                    Kanał Sportowy  2023-04-26T22:19:05Z
# 8   JTxsNm9IdYU                     Adrian Twarog  2022-12-12T10:52:13Z
# 9   zpRM25pUD8w                    Digital Engine  2023-01-22T16:57:44Z
# 10  _5UHsFdHcE8                         QuickBits  2023-02-17T11:56:20Z
# 11  FdZ8LKiJBhQ                      Nate Gentile  2023-03-07T21:24:03Z
# 12  e_HSA1lUd04                    Space Kangaroo  2023-01-02T00:28:42Z
# 13  iZDflpwN5as                       Anik Singal  2023-03-11T22:56:55Z
# 14  pCeYZ7eaeIw                         Steven He  2023-06-08T19:06:06Z
# 15  JsM-bF8AVXU                          FaZe Rug  2023-01-08T20:44:58Z
# 16  N8Wz7LF2QS0                           SSundee  2023-06-11T16:00:17Z
# 17  j02OZRjf2d8           New Media Academy Life   2023-03-07T18:00:08Z
# 18  gtgA4u8V_TQ                       GothamChess  2023-02-12T20:38:00Z
# 19  8I3NTE4cn5s                   Codex Community  2022-12-27T10:29:13Z
# 20  rSCNW1OCk_M                       GothamChess  2023-02-11T20:23:00Z
# 21  kCc8FmEb1nY                   Andrej Karpathy  2023-01-17T16:33:27Z
# 22  K7z0jlE61IM                      Alden Adison  2022-12-22T05:05:43Z
# 23  outcGtbnMuQ                            OpenAI  2023-03-14T20:32:41Z
# 24  sTeoEFzVNSc             Programming with Mosh  2023-01-13T17:00:09Z
# 25  AXn2XVLf7d0                  The AI Advantage  2022-12-08T21:56:41Z
# 26  FRHCjt02YuY                            Amixem  2023-04-02T15:25:00Z
# 27  QGKq8NHbPAY                South Park Studios  2023-03-11T22:29:16Z
# 28  Xw-zxQSEzqo                           Decycle  2021-08-25T00:00:11Z
# 29  JYtZ2zsdE_s                   Kevin Stratvert  2023-01-12T08:00:07Z
# 30  jnnj6Fd2ym0                Sandeep Maheshwari  2023-05-11T06:38:09Z
# 31  iWhlrkfJrCQ                       GothamChess  2023-02-13T16:17:00Z
# 32  ABHz5oZx-WA                        Nick Jones  2023-06-05T20:33:59Z
# 33  kQPUWryXwag                     Leila Gharani  2023-02-06T16:02:30Z
# 34  _ks5nM-ScTE                      DrossRotzank  2023-06-20T00:00:08Z
# 35  J5ArSJfQng0               Caffeinated Blogger  2023-01-22T09:39:24Z
# 36  Gaf_jCnA6mc                     Charlie Chang  2023-04-04T18:09:53Z
# 37  jHv63Uvk5VA                     Santrel Media  2023-02-25T14:46:49Z
# 38  FtIEhrZD_5I                          Alakh GK  2023-06-21T16:22:23Z
# 39  J-1442w0l9g  CA Rahul Malodia: Business Coach  2023-03-04T12:30:10Z
# 40  WizoCwjEKsg                               蘋果妹  2023-01-31T13:30:11Z
# 41  F16b1s5BkoQ                           BATZAIR  2023-03-28T16:00:20Z
# 42  3mIqCO3f96c                               Rye  2023-03-05T22:53:39Z
# 43  RCBZ-Xj2dgQ                           SidTalk  2023-01-09T13:53:02Z
# 44  f-_78a0HXCY                       Ben Shapiro  2022-12-26T17:00:20Z
# 45  nnboHTfYsfk                Sky News Australia  2023-08-29T10:47:35Z
# 46  -fopYsgFdzc                       Hayls World  2023-03-31T15:00:01Z
# 47  U9mJuUkhUzk                            OpenAI  2023-11-06T18:50:05Z
# 48  mYNqikThZvQ                          TradeIQ   2023-03-11T14:43:12Z
# 49  RdAQnkDzGvc                           KARE 11  2023-02-15T13:00:15Z
#
#                                           description  \
# 0
# 1   Learn Chess: https://www.youtube.com/gothamche...
# 2   Join my AI Course: https://academy.dhruvrathee...
# 3   I asked ChatGPT to provide me with instruction...
# 4                        I DEFEATED CHAT GPT #shorts.
# 5   I decided to troll ChatGPT by pushing its butt...
# 6   Sam Altman is the CEO of OpenAI, the company b...
# 7   Audycja przeznaczona dla osób powyżej 16. roku...
# 8   This ChatGPT Tutorial is a Crash Course on Cha...
# 9   AI robots, with Elon Musk, Boston Dynamics. To...
# 10  My college couldn't catch me cheating, they ne...
# 11  REGISTRATE A LA GTC Y ASISTE A UNA SESIÓN PARA...
# 12                                           Its bad.
# 13  FREE Courses from LURN == https://www.Lurn.com...
# 14  skit #asian #parody #comedy #sketch #emotional...
# 15  The future is here. I let AI control my life w...
# 16  We use ChatGPT to win in Modded Among Us ☞ Sub...
# 17  رحلة داخل الذكاء الاصطناعي اللي عارف ومش عارف ...
# 18  ️Get My Chess Courses: https://www.chessly.com...
# 19  Learn how to use AI Art and ChatGPT to Create ...
# 20  Anarchy Chess Post: http://bit.ly/3jLT4JZ ➡️ ️...
# 21  We build a Generatively Pretrained Transformer...
# 22  Don't use ChatGPT until you've watched this vi...
# 23  Join Greg Brockman, President and Co-Founder o...
# 24  Learn how to use ChatGPT to 10x your productiv...
# 25  Looking to get more out of ChatGPT? Get my FRE...
# 26  On a essayé de se faire rire en utilisant des ...
# 27
# 28  Heavily Inspired by Jack Soslow's video "Two A...
# 29  In this step-by-step tutorial, learn how you c...
# 30  Sandeep Maheshwari is a name among millions wh...
# 31  Get My Chess Courses: https://www.chessly.com/...
# 32  I asked an advanced AI system about the end ti...
# 33  Get access to "Quick Wins with ChatGPT" produc...
# 34  Si el video te gusta, valoraría mucho que le d...
# 35  Free Training: How I Make Passive Income Onlin...
# 36  Get my free Top 10 ChatGPT Use Cases PDF here:...
# 37  Stay ahead of the curve with our AI newsletter...
# 38                      ChatGPT #HowToUseChatGPT #AI.
# 39  Jobs that require human intelligence and a hig...
# 40  【必看續集】最新ChatGPT教學影片！完整版https://youtu.be/EM25tJ...
# 41
# 42  Today I Made a Game With ChatGPT. In this unit...
# 43  Hey Guys, In this video i'll explain you what ...
# 44  Ben Shapiro debates AI chatbot, Open AI. Open ...
# 45  Sky News Investigations Reporter Jonathan Lea ...
# 46  Hey guys! Welcome back to Hayls World! Today's...
# 47  Join us for the opening keynote from OpenAI De...
# 48  Live Options Trading (80%+ Win Rate) - https:/...
# 49  As more people discover ChatGPT's artificial i...
#
#                                           title_video
# 0                 Chat GPT A.I. Ki help se banai dish
# 1                                ChatGPT vs Stockfish
# 2   The Truth about Artificial Intelligence and Ch...
# 3          Can AI code Flappy Bird? Watch ChatGPT try
# 4                      I DEFEATED ChatGPT !!! #shorts
# 5                                  TROLLING CHATGPT 4
# 6   Sam Altman: OpenAI CEO on GPT-4, ChatGPT, and ...
# 7   ANDRZEJ DRAGAN, TOMASZ CZAJKA I STANOWSKI. Cha...
# 8   ChatGPT Tutorial - A Crash Course on Chat GPT ...
# 9   Smart, seductive, dangerous AI robots. Beyond ...
# 10   Chat GPT Banned in College? | Use this website !
# 11  ¿Cómo funciona ChatGPT? La revolución de la In...
# 12                     ChatGPT tries to draw a circle
# 13  Why You Don&#39;t Want To Use ChatGPT To Do Yo...
# 14                               If ChatGPT was ASIAN
# 15     Letting Chat GPT Control My Life for 24 Hours!
# 16                          Using ChatGPT in Among Us
# 17                                  Chat GPT | الدحيح
# 18                             ChatGPT Chess DISASTER
# 19  How to use AI Art and ChatGPT to Create a Insa...
# 20                          ChatGPT Just Solved Chess
# 21  Let&#39;s build GPT: from scratch, in code, sp...
# 22  Don&#39;t use ChatGPT until you&#39;ve watched...
# 23                         GPT-4 Developer Livestream
# 24  ChatGPT Tutorial for Developers - 38 Ways to 1...
# 25       How To Use Chat GPT by Open AI For Beginners
# 26  DUEL DE BLAGUES NULLES édition ChatGPT (les ro...
# 27                                      ChatGPT, dude
# 28       Two AIs Have An Existential Crisis (chatgpt)
# 29               10X Your Excel Skills with ChatGPT 🚀
# 30  The Future of Artificial Intelligence By Sande...
# 31                                    ChatGPT cheated
# 32  I Asked AI about the Second Coming of Jesus, a...
# 33  Bring ChatGPT INSIDE Excel to Solve ANY Proble...
# 34         Una experiencia lúgubre con la I.A ChatGPT
# 35  Use ChatGPT to Make $320 Per Day | Make Money ...
# 36  ChatGPT Tutorial: How to Use Chat GPT For Begi...
# 37  Complete ChatGPT Tutorial - [Become A Power Us...
# 38  CHAT GPT और Artificial Intelligence | कैसे GPT...
# 39  ChatGPT Vs Google | Explained In Hindi By Rahu...
# 40                       超簡單！一次上手ChatGPT使用教學 文案 報告 論文
# 41                     Quand Timéo découvre Chat GPT…
# 42                        I Made a Game Using ChatGPT
# 43  ChatGPT Tutorial in HINDI | What is Chat GPT &...
# 44  Ben Shapiro Breaks AI Chatbot (with Facts &amp...
# 45  Sky News Australia interviews &#39;free-thinki...
# 46  10 ChatGPT Life Hacks - THAT’LL CHANGE YOUR LI...
# 47                     OpenAI DevDay: Opening Keynote
# 48  ChatGPT Trading Strategy Made 19527% Profit ( ...
# 49  Testing the limits of ChatGPT and discovering ...

# %%
search_response = youtube.search().list(
  q="Chat gpt",
  part="snippet",
  order="viewCount",
  type="video",
  maxResults=50
).execute()

id_video = []
channelTitle = []
publish_time = []
description = []
title_video = []

for search_result in search_response.get("items", []):
    id_video.append(search_result["id"]["videoId"])
    channelTitle.append(search_result["snippet"]["channelTitle"])
    publish_time.append(search_result["snippet"]["publishTime"])
    description.append(search_result["snippet"]["description"])
    title_video.append(search_result["snippet"]["title"])


duration = []
definition = []
closed_caption = []
license_content = []
madeforkids = []
view_count = []
like_count = []
favorite_count = []
comment_count = []
license = []

for id_video_search in id_video:
    video_info_response = youtube.videos().list(
      part = ["contentDetails", "statistics","status"],
      id = id_video_search
    ).execute()

    duration .append(video_info_response["items"][0]['contentDetails']["duration"])
    definition.append(video_info_response["items"][0]['contentDetails']["definition"])
    closed_caption.append(video_info_response["items"][0]['contentDetails']["caption"])
    license_content.append(video_info_response["items"][0]['contentDetails']["licensedContent"])
    madeforkids.append(video_info_response["items"][0]['status']["madeForKids"])
    license.append(video_info_response["items"][0]['status']["license"])
    view_count.append(video_info_response["items"][0]['statistics']["viewCount"])
    like_count.append(video_info_response["items"][0]['statistics']["likeCount"])
    favorite_count.append(video_info_response["items"][0]['statistics']["favoriteCount"])
    comment_count.append(video_info_response["items"][0]['statistics'].get("commentCount", None))
    

df_youtube = pd.DataFrame({"id_video": id_video,
                           "Channel": channelTitle,
                           "title" : title_video,
                           "description": description,
                           "publish_time": publish_time,
                           "duration":duration,
                           "definiton": definition,
                           "closed_caption":closed_caption,
                           "license_content": license_content,
                           "madeforkids":madeforkids,
                           "license": license,
                           "view_count": view_count,
                           "like_count":like_count,
                           "favorite_count" : favorite_count,
                           "comment_count": comment_count
                           })
df_youtube.head()
# Out:
#       id_video         Channel  \
# 0  dPZ8uUvrgZQ  Trippy Kitchen
# 1  kvTs_nbc8Eg    Gotham Clips
# 2  vJefOB8kec8    Dhruv Rathee
# 3  8y7GRYaYYQg       candlesan
# 4  t0x6WNItdX4    Agnit Shorts
#
#                                                title  \
# 0                Chat GPT A.I. Ki help se banai dish
# 1                               ChatGPT vs Stockfish
# 2  The Truth about Artificial Intelligence and Ch...
# 3         Can AI code Flappy Bird? Watch ChatGPT try
# 4                     I DEFEATED ChatGPT !!! #shorts
#
#                                          description          publish_time  \
# 0                                                     2023-01-21T16:48:41Z
# 1  Learn Chess: https://www.youtube.com/gothamche...  2023-02-12T09:15:01Z
# 2  Join my AI Course: https://academy.dhruvrathee...  2023-07-16T15:05:29Z
# 3  I asked ChatGPT to provide me with instruction...  2023-03-23T16:00:08Z
# 4                       I DEFEATED CHAT GPT #shorts.  2023-04-12T04:30:22Z
#
#    duration definiton closed_caption  license_content  madeforkids  license  \
# 0     PT31S        hd          false             True        False  youtube
# 1     PT58S        hd          false             True        False  youtube
# 2  PT22M37S        hd           true             True        False  youtube
# 3   PT7M26S        hd          false             True        False  youtube
# 4     PT44S        hd          false             True        False  youtube
#
#   view_count like_count favorite_count comment_count
# 0   12800522     686874              0           891
# 1   10103890     591598              0          5893
# 2    8224316     377523              0         26115
# 3    7890616     129808              0          3644
# 4    7730259     625468              0          2843

# %%
search_response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'BVLYptlcU40aD5Y8AL5IZkcG3pk',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'ES',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'MADWAPPCsIUezZxzz5SYnB6jn8g',
#    'id': {'kind': 'youtube#video', 'videoId': 'dPZ8uUvrgZQ'},
#    'snippet': {'publishedAt': '2023-01-21T16:48:41Z',
#     'channelId': 'UCujkLB4kBWRn0YIGVczzEDg',
#     'title': 'Chat GPT A.I. Ki help se banai dish',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Trippy Kitchen',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-21T16:48:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'CPgLEHt9UqApr9dkMmAGlQMreOE',
#    'id': {'kind': 'youtube#video', 'videoId': 'kvTs_nbc8Eg'},
#    'snippet': {'publishedAt': '2023-02-12T09:15:01Z',
#     'channelId': 'UCUV5-V-QKR3tUTkKE1X_QMA',
#     'title': 'ChatGPT vs Stockfish',
#     'description': 'Learn Chess: https://www.youtube.com/gothamchess ➡️ Free Chess Courses: https://www.chessly.com ➡️ Probably Edited ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kvTs_nbc8Eg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kvTs_nbc8Eg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kvTs_nbc8Eg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Gotham Clips',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-12T09:15:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'eD4jLEhpxR8w375WlAQs95wfPRM',
#    'id': {'kind': 'youtube#video', 'videoId': 'vJefOB8kec8'},
#    'snippet': {'publishedAt': '2023-07-16T15:05:29Z',
#     'channelId': 'UC-CSyyi47VX1lD9zyeABW3w',
#     'title': 'The Truth about Artificial Intelligence and ChatGPT | Dhruv Rathee',
#     'description': 'Join my AI Course: https://academy.dhruvrathee.com/chatgpt Learn to harness the power of ChatGPT effectively and transform ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vJefOB8kec8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vJefOB8kec8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vJefOB8kec8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Dhruv Rathee',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-16T15:05:29Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-q4uqlZLlOYr5AWJA3wwfvC89ao',
#    'id': {'kind': 'youtube#video', 'videoId': '8y7GRYaYYQg'},
#    'snippet': {'publishedAt': '2023-03-23T16:00:08Z',
#     'channelId': 'UC2CXLhxGk1pzpzDNYSeNP4Q',
#     'title': 'Can AI code Flappy Bird? Watch ChatGPT try',
#     'description': "I asked ChatGPT to provide me with instructions on how to make Flappy Bird and it also wrote all of the code. I didn't write a single ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8y7GRYaYYQg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8y7GRYaYYQg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8y7GRYaYYQg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'candlesan',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-23T16:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XN_nrH3zUKXyT7YRWc_sFFG4RTA',
#    'id': {'kind': 'youtube#video', 'videoId': 't0x6WNItdX4'},
#    'snippet': {'publishedAt': '2023-04-12T04:30:22Z',
#     'channelId': 'UCu6eDhSb-UJq7_vLgKe4vHw',
#     'title': 'I DEFEATED ChatGPT !!! #shorts',
#     'description': 'I DEFEATED CHAT GPT #shorts.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/t0x6WNItdX4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/t0x6WNItdX4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/t0x6WNItdX4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Agnit Shorts',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-12T04:30:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ig3pPR3rRmXCMA6X_GlehQJtjME',
#    'id': {'kind': 'youtube#video', 'videoId': 'vx0_3BIwUwE'},
#    'snippet': {'publishedAt': '2023-12-14T20:45:02Z',
#     'channelId': 'UCJvBXBYPWE1aIlrM0r1Ilhw',
#     'title': 'TROLLING CHATGPT 4',
#     'description': "I decided to troll ChatGPT by pushing its buttons. Show me a picture of nothing, ChatGPT. It's that simple. In this video I use the AI ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vx0_3BIwUwE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vx0_3BIwUwE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vx0_3BIwUwE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Greenskull AI',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-14T20:45:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qDCnyMD6ADYJhUi5-qerSYJte-o',
#    'id': {'kind': 'youtube#video', 'videoId': 'L_Guz73e6fw'},
#    'snippet': {'publishedAt': '2023-03-25T18:03:21Z',
#     'channelId': 'UCSHZKyawb77ixDdsGog4iWA',
#     'title': 'Sam Altman: OpenAI CEO on GPT-4, ChatGPT, and the Future of AI | Lex Fridman Podcast #367',
#     'description': 'Sam Altman is the CEO of OpenAI, the company behind GPT-4, ChatGPT, DALL-E, Codex, and many other state-of-the-art AI ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L_Guz73e6fw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/L_Guz73e6fw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/L_Guz73e6fw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Lex Fridman',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-25T18:03:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'BkGa9dreiTLCzunbmhWQ7IghC0U',
#    'id': {'kind': 'youtube#video', 'videoId': 'zzPwTJGBLOc'},
#    'snippet': {'publishedAt': '2023-04-26T22:19:05Z',
#     'channelId': 'UCIfI7Yo22SMKp5PraztHM6w',
#     'title': 'ANDRZEJ DRAGAN, TOMASZ CZAJKA I STANOWSKI. ChatGPT, SZTUCZNA INTELIGENCJA. HEJT PARK: JESTEŚMY NA TY',
#     'description': 'Audycja przeznaczona dla osób powyżej 16. roku życia. #HejtPark - Jesteśmy Na Ty - profesor Andrzej #Dragan, fizyk oraz ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zzPwTJGBLOc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zzPwTJGBLOc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zzPwTJGBLOc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kanał Sportowy',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-26T22:19:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Jgpzg5dgM1iLkh6BBzcQkKq2sIg',
#    'id': {'kind': 'youtube#video', 'videoId': 'JTxsNm9IdYU'},
#    'snippet': {'publishedAt': '2022-12-12T10:52:13Z',
#     'channelId': 'UCvM5YYWwfLwpcQgbRr68JLQ',
#     'title': 'ChatGPT Tutorial - A Crash Course on Chat GPT for Beginners',
#     'description': 'This ChatGPT Tutorial is a Crash Course on Chat GPT for Beginners. With the increase in popularity, ChatGPT is still unknown to ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JTxsNm9IdYU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JTxsNm9IdYU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JTxsNm9IdYU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Adrian Twarog',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-12T10:52:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wUlUj8x7bObOjqudCGUAe1-H5CI',
#    'id': {'kind': 'youtube#video', 'videoId': 'zpRM25pUD8w'},
#    'snippet': {'publishedAt': '2023-01-22T16:57:44Z',
#     'channelId': 'UCvCYE-3TrY1GAe2l8K08N-w',
#     'title': 'Smart, seductive, dangerous AI robots. Beyond GPT-4.',
#     'description': "AI robots, with Elon Musk, Boston Dynamics. To learn AI, visit: https://brilliant.org/digitalengine where you'll also find loads of fun ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zpRM25pUD8w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zpRM25pUD8w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zpRM25pUD8w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Digital Engine',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-22T16:57:44Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'sv6GqgT4yIAFhULWg9eSwODzvAU',
#    'id': {'kind': 'youtube#video', 'videoId': '_5UHsFdHcE8'},
#    'snippet': {'publishedAt': '2023-02-17T11:56:20Z',
#     'channelId': 'UC_Z3dYf8OgxJ53SSFb7QGrA',
#     'title': 'Chat GPT Banned in College? | Use this website !',
#     'description': "My college couldn't catch me cheating, they need to up their game! . . #qb #qbreels #qbshorts #quickbits #chatgpt #college ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_5UHsFdHcE8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_5UHsFdHcE8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_5UHsFdHcE8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'QuickBits',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-17T11:56:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wJnMitJ_chSX-24M2QMGljVEEbo',
#    'id': {'kind': 'youtube#video', 'videoId': 'FdZ8LKiJBhQ'},
#    'snippet': {'publishedAt': '2023-03-07T21:24:03Z',
#     'channelId': 'UC36xmz34q02JYaZYKrMwXng',
#     'title': '¿Cómo funciona ChatGPT? La revolución de la Inteligencia Artificial',
#     'description': 'REGISTRATE A LA GTC Y ASISTE A UNA SESIÓN PARA GANAR UNA GPU!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FdZ8LKiJBhQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FdZ8LKiJBhQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FdZ8LKiJBhQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nate Gentile',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-07T21:24:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'IsoABuPlcjNBdAv5E3TmCD3kLYE',
#    'id': {'kind': 'youtube#video', 'videoId': 'e_HSA1lUd04'},
#    'snippet': {'publishedAt': '2023-01-02T00:28:42Z',
#     'channelId': 'UCA_UiEIwdlChul3EMx7Clhg',
#     'title': 'ChatGPT tries to draw a circle',
#     'description': 'Its bad.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/e_HSA1lUd04/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/e_HSA1lUd04/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/e_HSA1lUd04/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Space Kangaroo',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-02T00:28:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'drJuOo1ufJzRtUfzR_X5FtuGsCM',
#    'id': {'kind': 'youtube#video', 'videoId': 'iZDflpwN5as'},
#    'snippet': {'publishedAt': '2023-03-11T22:56:55Z',
#     'channelId': 'UCinyEr-Fly9Yp1zMFx_D0cQ',
#     'title': 'Why You Don&#39;t Want To Use ChatGPT To Do Your Homework',
#     'description': 'FREE Courses from LURN == https://www.Lurn.com/getfreecourses ============================================ Why ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iZDflpwN5as/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/iZDflpwN5as/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/iZDflpwN5as/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Anik Singal',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-11T22:56:55Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'gcZf2lUsRH94l5V7gAILkORwqyo',
#    'id': {'kind': 'youtube#video', 'videoId': 'pCeYZ7eaeIw'},
#    'snippet': {'publishedAt': '2023-06-08T19:06:06Z',
#     'channelId': 'UCP0_k4INXrwPS6HhIyYqsTg',
#     'title': 'If ChatGPT was ASIAN',
#     'description': 'skit #asian #parody #comedy #sketch #emotionaldamage Watch "Ginormo!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pCeYZ7eaeIw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pCeYZ7eaeIw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pCeYZ7eaeIw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Steven He',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-08T19:06:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zEfV8mIaXivj-0e3DYd2al2wakE',
#    'id': {'kind': 'youtube#video', 'videoId': 'JsM-bF8AVXU'},
#    'snippet': {'publishedAt': '2023-01-08T20:44:58Z',
#     'channelId': 'UCilwZiBBfI9X6yiZRzWty8Q',
#     'title': 'Letting Chat GPT Control My Life for 24 Hours!',
#     'description': "The future is here. I let AI control my life with @BrandonWilliamyt for the entire day, and it's terrifying to know this will take over the ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JsM-bF8AVXU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JsM-bF8AVXU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JsM-bF8AVXU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'FaZe Rug',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-08T20:44:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'BDoMh9uot8bdLxUH0pR2HGofcO8',
#    'id': {'kind': 'youtube#video', 'videoId': 'N8Wz7LF2QS0'},
#    'snippet': {'publishedAt': '2023-06-11T16:00:17Z',
#     'channelId': 'UCke6I9N4KfC968-yRcd5YRg',
#     'title': 'Using ChatGPT in Among Us',
#     'description': 'We use ChatGPT to win in Modded Among Us ☞ Subscribe & click the bell Subscribe ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/N8Wz7LF2QS0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/N8Wz7LF2QS0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/N8Wz7LF2QS0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'SSundee',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-11T16:00:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1KH4tDnvU5n6VxHg1XjEIFpPKIY',
#    'id': {'kind': 'youtube#video', 'videoId': 'j02OZRjf2d8'},
#    'snippet': {'publishedAt': '2023-03-07T18:00:08Z',
#     'channelId': 'UCtJmfVv0a52Bu7BnJJtZXKw',
#     'title': 'Chat GPT | الدحيح',
#     'description': 'رحلة داخل الذكاء الاصطناعي اللي عارف ومش عارف كل حاجة. شاهدوا حلقات الدحيح أولاً على منصات ستارز بلاي @STARZPLAY-SVOD ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/j02OZRjf2d8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/j02OZRjf2d8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/j02OZRjf2d8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'New Media Academy Life ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-07T18:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-p9jrfpqvnyI0HdXyfpz9cnn90s',
#    'id': {'kind': 'youtube#video', 'videoId': 'gtgA4u8V_TQ'},
#    'snippet': {'publishedAt': '2023-02-12T20:38:00Z',
#     'channelId': 'UCQHX6ViZmPsWiYSFAyS0a3Q',
#     'title': 'ChatGPT Chess DISASTER',
#     'description': '️Get My Chess Courses: https://www.chessly.com/ ➡️ Get my best-selling chess book: https://geni.us/gothamchess ➡️ My ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gtgA4u8V_TQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gtgA4u8V_TQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gtgA4u8V_TQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'GothamChess',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-12T20:38:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'aXlScfUagWvLPytUJ1mtZc9FZ4o',
#    'id': {'kind': 'youtube#video', 'videoId': '8I3NTE4cn5s'},
#    'snippet': {'publishedAt': '2022-12-27T10:29:13Z',
#     'channelId': 'UCgkx40oeL6X9l93iT0sHxgg',
#     'title': 'How to use AI Art and ChatGPT to Create a Insane Web Designs',
#     'description': 'Learn how to use AI Art and ChatGPT to Create a Website without writing a single line of code! ⭐ New - Teach Me OpenAI Digital ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8I3NTE4cn5s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8I3NTE4cn5s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8I3NTE4cn5s/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Codex Community',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-27T10:29:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wxCjkOpnlHtiSQsa7zjfzsz5qrs',
#    'id': {'kind': 'youtube#video', 'videoId': 'rSCNW1OCk_M'},
#    'snippet': {'publishedAt': '2023-02-11T20:23:00Z',
#     'channelId': 'UCQHX6ViZmPsWiYSFAyS0a3Q',
#     'title': 'ChatGPT Just Solved Chess',
#     'description': 'Anarchy Chess Post: http://bit.ly/3jLT4JZ ➡️ ️Get My Chess Courses: https://www.chessly.com/ ➡️ Get my best-selling chess ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rSCNW1OCk_M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rSCNW1OCk_M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rSCNW1OCk_M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'GothamChess',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-11T20:23:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PLrjRMpVtlSsf8o_4pUBsA1qOIU',
#    'id': {'kind': 'youtube#video', 'videoId': 'kCc8FmEb1nY'},
#    'snippet': {'publishedAt': '2023-01-17T16:33:27Z',
#     'channelId': 'UCXUPKJO5MZQN11PqgIvyuvQ',
#     'title': 'Let&#39;s build GPT: from scratch, in code, spelled out.',
#     'description': 'We build a Generatively Pretrained Transformer (GPT), following the paper "Attention is All You Need" and OpenAI\'s GPT-2 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kCc8FmEb1nY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kCc8FmEb1nY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kCc8FmEb1nY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Andrej Karpathy',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-17T16:33:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KlTjEj3EDNaCA28LiuRWg8No1RQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'K7z0jlE61IM'},
#    'snippet': {'publishedAt': '2022-12-22T05:05:43Z',
#     'channelId': 'UCZ0OUexrcZammbgvSwvGlZg',
#     'title': 'Don&#39;t use ChatGPT until you&#39;ve watched this video!',
#     'description': "Don't use ChatGPT until you've watched this video! This is an important insight for all website and blog owners out there using ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/K7z0jlE61IM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/K7z0jlE61IM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/K7z0jlE61IM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Alden Adison',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-22T05:05:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'eSX-7Lmnu621yhmdDlGkWeBq30A',
#    'id': {'kind': 'youtube#video', 'videoId': 'outcGtbnMuQ'},
#    'snippet': {'publishedAt': '2023-03-14T20:32:41Z',
#     'channelId': 'UCXZCJLdBC09xxGZ6gcdrc6A',
#     'title': 'GPT-4 Developer Livestream',
#     'description': 'Join Greg Brockman, President and Co-Founder of OpenAI, at 1 pm PT for a developer demo showcasing GPT-4 and some of its ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/outcGtbnMuQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/outcGtbnMuQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/outcGtbnMuQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'OpenAI',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-14T20:32:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mIN2F8eBF4w2D6us1DHRDyF1cE8',
#    'id': {'kind': 'youtube#video', 'videoId': 'sTeoEFzVNSc'},
#    'snippet': {'publishedAt': '2023-01-13T17:00:09Z',
#     'channelId': 'UCWv7vMbMWH4-V0ZXdmDpPBA',
#     'title': 'ChatGPT Tutorial for Developers - 38 Ways to 10x Your Productivity',
#     'description': 'Learn how to use ChatGPT to 10x your productivity! 38 examples using Python, JavaScript, HTML, CSS, React, SQL and more!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sTeoEFzVNSc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sTeoEFzVNSc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sTeoEFzVNSc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Programming with Mosh',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-13T17:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '36JScqXEDoPXX0vbANmHwG358oo',
#    'id': {'kind': 'youtube#video', 'videoId': 'AXn2XVLf7d0'},
#    'snippet': {'publishedAt': '2022-12-08T21:56:41Z',
#     'channelId': 'UCHhYXsLBEVVnbvsq57n1MTQ',
#     'title': 'How To Use Chat GPT by Open AI For Beginners',
#     'description': 'Looking to get more out of ChatGPT? Get my FREE Template: https://myaiadvantage.com/newsletter Master ChatGPT with our ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AXn2XVLf7d0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AXn2XVLf7d0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AXn2XVLf7d0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The AI Advantage',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-08T21:56:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'P3xWjGE_Tw8ergxk68oxMTWs0co',
#    'id': {'kind': 'youtube#video', 'videoId': 'FRHCjt02YuY'},
#    'snippet': {'publishedAt': '2023-04-02T15:25:00Z',
#     'channelId': 'UCgvqvBoSHB1ctlyyhoHrGwQ',
#     'title': 'DUEL DE BLAGUES NULLES édition ChatGPT (les robots sont plus drôles que nous)',
#     'description': 'On a essayé de se faire rire en utilisant des intelligences artificielles ! Téléchargez Call of Dragons pour PC ou MOBILE ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FRHCjt02YuY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FRHCjt02YuY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FRHCjt02YuY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Amixem',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-02T15:25:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'C7w0kwiK8BdTzK6pu5ngqVk7CkQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'QGKq8NHbPAY'},
#    'snippet': {'publishedAt': '2023-03-11T22:29:16Z',
#     'channelId': 'UC7R27sAWc_DqOldtI1JcYhQ',
#     'title': 'ChatGPT, dude',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QGKq8NHbPAY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QGKq8NHbPAY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QGKq8NHbPAY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'South Park Studios',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-11T22:29:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lGwhLi2MlPSlR2fegY8N_qPvFdY',
#    'id': {'kind': 'youtube#video', 'videoId': 'Xw-zxQSEzqo'},
#    'snippet': {'publishedAt': '2021-08-25T00:00:11Z',
#     'channelId': 'UCXKVDdbaj7guQGPFAQgT_pg',
#     'title': 'Two AIs Have An Existential Crisis (chatgpt)',
#     'description': 'Heavily Inspired by Jack Soslow\'s video "Two AIs talk about becoming human", https://www.youtube.com/watch?v=jz78fSnBG0s ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Xw-zxQSEzqo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Xw-zxQSEzqo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Xw-zxQSEzqo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Decycle',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-25T00:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2JZmedTw5YJQWvJsmOD-VtVUaC4',
#    'id': {'kind': 'youtube#video', 'videoId': 'JYtZ2zsdE_s'},
#    'snippet': {'publishedAt': '2023-01-12T08:00:07Z',
#     'channelId': 'UCfJT_eYDTmDE-ovKaxVE1ig',
#     'title': '10X Your Excel Skills with ChatGPT 🚀',
#     'description': "In this step-by-step tutorial, learn how you can exponentially improve your Excel skills using OpenAI's ChatGPT artificial ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JYtZ2zsdE_s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JYtZ2zsdE_s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JYtZ2zsdE_s/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kevin Stratvert',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-12T08:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nob70SPokuYPkvoNKZjzpzWdRqo',
#    'id': {'kind': 'youtube#video', 'videoId': 'jnnj6Fd2ym0'},
#    'snippet': {'publishedAt': '2023-05-11T06:38:09Z',
#     'channelId': 'UCBqFKDipsnzvJdt6UT0lMIg',
#     'title': 'The Future of Artificial Intelligence By Sandeep Maheshwari | Will ChatGPT Take Your Job?',
#     'description': 'Sandeep Maheshwari is a name among millions who struggled, failed and surged ahead in search of success, happiness and ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jnnj6Fd2ym0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jnnj6Fd2ym0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jnnj6Fd2ym0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sandeep Maheshwari',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-11T06:38:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4Zuls1Es8PUR4GX0_1sw8WfMR9I',
#    'id': {'kind': 'youtube#video', 'videoId': 'iWhlrkfJrCQ'},
#    'snippet': {'publishedAt': '2023-02-13T16:17:00Z',
#     'channelId': 'UCQHX6ViZmPsWiYSFAyS0a3Q',
#     'title': 'ChatGPT cheated',
#     'description': 'Get My Chess Courses: https://www.chessly.com/ ➡️ Get my best-selling chess book: https://geni.us/gothamchess ➡️ My book ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iWhlrkfJrCQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/iWhlrkfJrCQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/iWhlrkfJrCQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'GothamChess',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-13T16:17:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'P10XMfTzpIRJpft8W5GV8sKhZ4g',
#    'id': {'kind': 'youtube#video', 'videoId': 'ABHz5oZx-WA'},
#    'snippet': {'publishedAt': '2023-06-05T20:33:59Z',
#     'channelId': 'UCwfeFpvbkp8cgmJWaMO9K0g',
#     'title': 'I Asked AI about the Second Coming of Jesus, and its Response Left Me Stunned!',
#     'description': 'I asked an advanced AI system about the end times according to the Bible, and what it revealed left me absolutely stunned!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ABHz5oZx-WA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ABHz5oZx-WA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ABHz5oZx-WA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nick Jones',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-05T20:33:59Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2ZI34ttdrlxNBgFY6Din2GHV_Gg',
#    'id': {'kind': 'youtube#video', 'videoId': 'kQPUWryXwag'},
#    'snippet': {'publishedAt': '2023-02-06T16:02:30Z',
#     'channelId': 'UCJtUOos_MwJa_Ewii-R3cJA',
#     'title': 'Bring ChatGPT INSIDE Excel to Solve ANY Problem Lightning FAST',
#     'description': 'Get access to "Quick Wins with ChatGPT" productivity course: https://link.xelplus.com/yt-chatgpt-course use coupon code ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kQPUWryXwag/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kQPUWryXwag/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kQPUWryXwag/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Leila Gharani',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-06T16:02:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'abFwUm9e0xTMr2R6yaZun6PlukY',
#    'id': {'kind': 'youtube#video', 'videoId': '_ks5nM-ScTE'},
#    'snippet': {'publishedAt': '2023-06-20T00:00:08Z',
#     'channelId': 'UCNYW2vfGrUE6R5mIJYzkRyQ',
#     'title': 'Una experiencia lúgubre con la I.A ChatGPT',
#     'description': 'Si el video te gusta, valoraría mucho que le dieras like y que comentaras algo. ¡Gracias! ❤ | ¡Suscríbete! http://bit.ly/1a1sm3k ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_ks5nM-ScTE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_ks5nM-ScTE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_ks5nM-ScTE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DrossRotzank',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-20T00:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'xo8XsInLbKnWjxi8i6Ubv31NHkU',
#    'id': {'kind': 'youtube#video', 'videoId': 'J5ArSJfQng0'},
#    'snippet': {'publishedAt': '2023-01-22T09:39:24Z',
#     'channelId': 'UCKMDqnJbYx6yv0N-dRvRAgQ',
#     'title': 'Use ChatGPT to Make $320 Per Day | Make Money with AI',
#     'description': 'Free Training: How I Make Passive Income Online: https://ContentDough.com ❤️ Follow Me On Instagram: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/J5ArSJfQng0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/J5ArSJfQng0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/J5ArSJfQng0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Caffeinated Blogger',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-22T09:39:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'icbG1L9q1VZZqPxjhKT9kXGn1tI',
#    'id': {'kind': 'youtube#video', 'videoId': 'Gaf_jCnA6mc'},
#    'snippet': {'publishedAt': '2023-04-04T18:09:53Z',
#     'channelId': 'UCTQuKo8v0PaPCvk5aRxc_Yg',
#     'title': 'ChatGPT Tutorial: How to Use Chat GPT For Beginners 2023',
#     'description': "Get my free Top 10 ChatGPT Use Cases PDF here: https://www.charliechang.com/chatgpt In this video, I'm going to give you a ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Gaf_jCnA6mc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Gaf_jCnA6mc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Gaf_jCnA6mc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Charlie Chang',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-04T18:09:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8hab3ehSpEpR_qh_E6kNYojQZ_0',
#    'id': {'kind': 'youtube#video', 'videoId': 'jHv63Uvk5VA'},
#    'snippet': {'publishedAt': '2023-02-25T14:46:49Z',
#     'channelId': 'UCg60QRUSvLZMF4zHv2ajBqA',
#     'title': 'Complete ChatGPT Tutorial - [Become A Power User in 30 Minutes]',
#     'description': 'Stay ahead of the curve with our AI newsletter: https://neuralfrontier.beehiiv.com/ In this video, I will show you the 10 major types of ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jHv63Uvk5VA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jHv63Uvk5VA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jHv63Uvk5VA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Santrel Media',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-25T14:46:49Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'JawkyvFm7e27Ih1OxB4wWjsZiUs',
#    'id': {'kind': 'youtube#video', 'videoId': 'FtIEhrZD_5I'},
#    'snippet': {'publishedAt': '2023-06-21T16:22:23Z',
#     'channelId': 'UC0ykHu_m9j3q3HXK_ySYr_A',
#     'title': 'CHAT GPT और Artificial Intelligence | कैसे GPT USE करें | ROBOTS V/S HUMANS | JOBS RISK | Alakh GK',
#     'description': 'ChatGPT #HowToUseChatGPT #AI.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FtIEhrZD_5I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FtIEhrZD_5I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FtIEhrZD_5I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Alakh GK',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-21T16:22:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wGhk_eRwPQ2HuxYaWE7nMBQsk_w',
#    'id': {'kind': 'youtube#video', 'videoId': 'J-1442w0l9g'},
#    'snippet': {'publishedAt': '2023-03-04T12:30:10Z',
#     'channelId': 'UCPgfM-dk3XAb4T3DtT6Nwsw',
#     'title': 'ChatGPT Vs Google | Explained In Hindi By Rahul Malodia',
#     'description': 'Jobs that require human intelligence and a high level of education – writing, journalism, translation, education, law, computer ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/J-1442w0l9g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/J-1442w0l9g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/J-1442w0l9g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'CA Rahul Malodia: Business Coach',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-04T12:30:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'SOIweUMPb2yqPFY96gM-k4DGtvg',
#    'id': {'kind': 'youtube#video', 'videoId': 'WizoCwjEKsg'},
#    'snippet': {'publishedAt': '2023-01-31T13:30:11Z',
#     'channelId': 'UCIpZAGl9xHcuzmHW0AAJs7g',
#     'title': '超簡單！一次上手ChatGPT使用教學 文案 報告 論文',
#     'description': '【必看續集】最新ChatGPT教學影片！完整版https://youtu.be/EM25tJ4oHUM 〖訂閱頻道按鈕〗https://bit.ly/applemeisubscribe ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WizoCwjEKsg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/WizoCwjEKsg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/WizoCwjEKsg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '蘋果妹',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-31T13:30:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fJ3BNZcf9V-uh6ZI3Qk_b-GmyrQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'F16b1s5BkoQ'},
#    'snippet': {'publishedAt': '2023-03-28T16:00:20Z',
#     'channelId': 'UCCU2Tvanl8gLaJ7pYDuIYkg',
#     'title': 'Quand Timéo découvre Chat GPT…',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F16b1s5BkoQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/F16b1s5BkoQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/F16b1s5BkoQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BATZAIR',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-28T16:00:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DsPg3xWaj_CI5coqHVHL15UgGEg',
#    'id': {'kind': 'youtube#video', 'videoId': '3mIqCO3f96c'},
#    'snippet': {'publishedAt': '2023-03-05T22:53:39Z',
#     'channelId': 'UCdR_AsuI1Bq4eUFj08St4tw',
#     'title': 'I Made a Game Using ChatGPT',
#     'description': 'Today I Made a Game With ChatGPT. In this unity devlog / indie devlog video I made a game with AI. Can an AI make a good ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3mIqCO3f96c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3mIqCO3f96c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3mIqCO3f96c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Rye',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-05T22:53:39Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'IeSQ9PEgntkTQqrz5NqQQidH7Do',
#    'id': {'kind': 'youtube#video', 'videoId': 'RCBZ-Xj2dgQ'},
#    'snippet': {'publishedAt': '2023-01-09T13:53:02Z',
#     'channelId': 'UCfgZg9Vl5AwedH14BYgLXTQ',
#     'title': 'ChatGPT Tutorial in HINDI | What is Chat GPT &amp; How To Download ChatGPT in Mobile Phone | Live DEMO',
#     'description': "Hey Guys, In this video i'll explain you what is Chat GPT & How to use Chat GPT in Hindi. How to earn money using Chat GPT in ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RCBZ-Xj2dgQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RCBZ-Xj2dgQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RCBZ-Xj2dgQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'SidTalk',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-09T13:53:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LHIyA1i7F-wfUP7K-CDkFWvAFd4',
#    'id': {'kind': 'youtube#video', 'videoId': 'f-_78a0HXCY'},
#    'snippet': {'publishedAt': '2022-12-26T17:00:20Z',
#     'channelId': 'UCnQC_G5Xsjhp9fEJKuIcrSw',
#     'title': 'Ben Shapiro Breaks AI Chatbot (with Facts &amp; Logic)',
#     'description': 'Ben Shapiro debates AI chatbot, Open AI. Open AI is supposed to have objective answers, using extraordinary amounts of ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f-_78a0HXCY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/f-_78a0HXCY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/f-_78a0HXCY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Ben Shapiro',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-26T17:00:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XMS4FsZQOnyoJ4sZUBpnM6rnvao',
#    'id': {'kind': 'youtube#video', 'videoId': 'nnboHTfYsfk'},
#    'snippet': {'publishedAt': '2023-08-29T10:47:35Z',
#     'channelId': 'UCO0akufu9MOzyz3nvGIXAAw',
#     'title': 'Sky News Australia interviews &#39;free-thinking&#39; artificial intelligence',
#     'description': 'Sky News Investigations Reporter Jonathan Lea sits down to talk with a “free-thinking” and “opinionated” artificial intelligence, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nnboHTfYsfk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nnboHTfYsfk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nnboHTfYsfk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sky News Australia',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-29T10:47:35Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zLZODAJHFHQRypNPAJyHEehXl-I',
#    'id': {'kind': 'youtube#video', 'videoId': '-fopYsgFdzc'},
#    'snippet': {'publishedAt': '2023-03-31T15:00:01Z',
#     'channelId': 'UCIxLxlan8q9WA7sjuq6LdTQ',
#     'title': '10 ChatGPT Life Hacks - THAT’LL CHANGE YOUR LIFE !!',
#     'description': 'Hey guys! Welcome back to Hayls World! Today\'s video is all about ChatGPT and how it can change your life! In "10 ChatGPT Life ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-fopYsgFdzc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-fopYsgFdzc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-fopYsgFdzc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Hayls World',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-31T15:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'l7HhdGICxgBkpqwZ0zR1XRdTQxI',
#    'id': {'kind': 'youtube#video', 'videoId': 'U9mJuUkhUzk'},
#    'snippet': {'publishedAt': '2023-11-06T18:50:05Z',
#     'channelId': 'UCXZCJLdBC09xxGZ6gcdrc6A',
#     'title': 'OpenAI DevDay: Opening Keynote',
#     'description': "Join us for the opening keynote from OpenAI DevDay — OpenAI's first developer conference. We're gathering developers from ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U9mJuUkhUzk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U9mJuUkhUzk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U9mJuUkhUzk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'OpenAI',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-06T18:50:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'rpa__0C8KqgYPo_aeGaXiYaaza8',
#    'id': {'kind': 'youtube#video', 'videoId': 'mYNqikThZvQ'},
#    'snippet': {'publishedAt': '2023-03-11T14:43:12Z',
#     'channelId': 'UClZ5L3WaEnQE0eERGMtmhlA',
#     'title': 'ChatGPT Trading Strategy Made 19527% Profit ( FULL TUTORIAL )',
#     'description': 'Live Options Trading (80%+ Win Rate) - https://www.ezoptions.co/?ref=mis My #1 Indicator Recommendation ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mYNqikThZvQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mYNqikThZvQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mYNqikThZvQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'TradeIQ ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-11T14:43:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'etIINO-1vRYywcH-dlAz2-58OyI',
#    'id': {'kind': 'youtube#video', 'videoId': 'RdAQnkDzGvc'},
#    'snippet': {'publishedAt': '2023-02-15T13:00:15Z',
#     'channelId': 'UC1JAwKeDUjN2orv5t7LWODQ',
#     'title': 'Testing the limits of ChatGPT and discovering a dark side',
#     'description': "As more people discover ChatGPT's artificial intelligence, KARE 11's Chris Hrapsky checks out its capabilities and limitations, and ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RdAQnkDzGvc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RdAQnkDzGvc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RdAQnkDzGvc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'KARE 11',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-15T13:00:15Z'}}]}

# %%
df_youtube.to_csv("data/df_youtube_chagpt.csv")
