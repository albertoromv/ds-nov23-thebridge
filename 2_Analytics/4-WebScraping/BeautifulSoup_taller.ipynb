# %% [markdown]
# # Beautiful Soup Tutorial

# %% [markdown]
# Como científico de datos, tarde o temprano llegarás a un punto en el que tendrás que recopilar grandes cantidades de datos. Ya sea un proyecto o por pasatiempo y no siempre podremos contar con las API, pero tranquilo tenemos el web scraping... ¡Y una de las mejores herramientas de web scraping es Beautiful Soup!

# %% [markdown]
# ## ¿Pero.... qué es el web scraping?
#
# En pocas palabras, el web scraping es la recopilación automatizada de datos de sitios web (para ser más precisos, del contenido HTML de los sitios web).
#
# En este Jupyter, aprenderás los conceptos básicos sobre cómo extraer datos de HTML.
#
# Lo harás extrayendo datos de la página en la cual se encuentran alquileres de pisos en Barcelona

# %% [markdown]
# ### Conoce a tus nuevos mejores amigos:

# %% [markdown]
# - Beautiful Soup
# - Requests

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\alexc\appdata\local\programs\python\python39\lib\site-packages (4.12.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\alexc\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4) (2.4)

# %% [markdown]
# Para obtener la experiencia completa de Beautiful Soup, también deberás instalar un parser, dentro de ellos tenemos..
#
# - html.parser
# - lxml
# - html5lib

# %% [markdown]
# Vamos a utilizar el lxml ya que es el mas rápido

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\alexc\appdata\local\programs\python\python39\lib\site-packages (4.9.2)

# %% [markdown]
# Se necesita una cosa más para que podamos comenzar a hacer web scraping, y es la biblioteca de ```requests```. Con ```requests``` podemos solicitar páginas web de sitios web.

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\alexc\appdata\local\programs\python\python39\lib\site-packages (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alexc\appdata\local\programs\python\python39\lib\site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alexc\appdata\local\programs\python\python39\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\alexc\appdata\local\programs\python\python39\lib\site-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexc\appdata\local\programs\python\python39\lib\site-packages (from requests) (2022.12.7)

# %% [markdown]
# Ahora asi manos a la obra..

# %% [markdown]
# ## Mi primer scraping

# %% [markdown]
# Como siempre lo primero es importar las librerías

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# Ahora, estamos listos para solicitar nuestra primera página web. No es nada complicado: guardamos la URL que queremos raspar en la variable URL, luego solicitamos la URL (requests.get (url)) y guardamos la respuesta en la variable de respuesta:

# %%
url = "https://www.yaencontre.com/alquiler/pisos/barcelona"
response = requests.get(url)

# %% [markdown]
# Cómo saber si se guardo correctamente el sitio web?

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Posibles respuestas:
#
# - [Respuestas informativas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#information_responses) (100–199)
# - [Respuestas exitosas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#successful_responses) (200–299)
# - [Mensajes de redirección](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#redirection_messages) (300–399)
# - [Respuestas de error del cliente](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#client_error_responses) (400–499)
# - [Respuestas de error del servidor](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#server_error_responses) (500–599)

# %% [markdown]
# Pero necesitamos el contenido HTML de la página web solicitada, así que como siguiente paso guardamos el contenido de la respuesta a html:

# %%
html = response.content

# %%
type(html)
# Out:
# bytes

# %% [markdown]
# Lo podemos imprimir para ver su estructura

# %%
print(html)
# Out:
# b'<!doctype html>\n    <html lang="es" class="notranslate page-results variantContainer withBreadcrumb" translate="no">\n      <head>\n        \n        <title data-rh="true">Pisos y viviendas en alquiler en Barcelona \xc2\xb7 5.514 pisos y viviendas disponibles - yaencontre</title>\n        <meta data-rh="true" name="title" content="Pisos y viviendas en alquiler en Barcelona \xc2\xb7 5.514 pisos y viviendas disponibles - yaencontre"/><meta data-rh="true" name="description" content="5.514 Pisos y viviendas en alquiler en Barcelona. Anuncios de pisos y viviendas de particulares y agencias inmobiliarias. \xc2\xa1Encontrar\xc3\xa1s lo que est\xc3\xa1s buscando!"/><meta data-rh="true" name="robots" content="index, follow"/><meta data-rh="true" name="language" content="es"/>\n        <meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" /><meta name="theme-color" content="#e5005a" /><meta http-equiv="content-type" content="text/html; charset=UTF-8" /><meta http-equiv="x-ua-compatible" content="IE=EDGE" /><meta name="google-play-app" content="app-id=com.yaencontre.vivienda" /><meta name="twitter:site" content="@yaencontre" /><meta name="apple-mobile-web-app-capable" content="yes" /><meta name="apple-mobile-web-app-title" content="yaencontre" /><meta name="apple-mobile-web-app-status-bar-style" content="default" /><meta name="mobile-web-app-capable" content="yes" /><meta name="application-name" content="yaencontre" /><meta name="og:site_name" content="yaencontre" /><meta name="google" content="notranslate" /><meta name="format-detection" content="telephone=no" />\n        <link rel="dns-prefetch" href="https://media.yaencontre.com" /><link rel="dns-prefetch" href="https://www.googletagmanager.com" /><link rel="dns-prefetch" href="https://assets.adobedtm.com" /><link rel="dns-prefetch" href="https://sdk.privacy-center.org" />\n        <link data-rh="true" rel="canonical" href="https://www.yaencontre.com/alquiler/pisos/barcelona"/><link data-rh="true" rel="next" href="https://www.yaencontre.com/alquiler/pisos/barcelona/pag-2"/><link data-rh="true" rel="alternate" href="https://www.yaencontre.com/alquiler/pisos/barcelona" hreflang="es"/><link data-rh="true" rel="alternate" href="https://ca.yaencontre.com/lloguer/pisos/barcelona" hreflang="ca"/><link data-rh="true" rel="preload" as="image" href="https://media.yaencontre.com/img/photo/w380/29126/29126-45082523-1086007577.jpg" media imagesrcset="https://media.yaencontre.com/img/photo/w630/29126/29126-45082523-1086007577.jpg.webp 2x, https://media.yaencontre.com/img/photo/w380/29126/29126-45082523-1086007577.jpg.webp"/>\n        <link rel="shortcut icon" href="/favicon.ico" /><link rel="apple-touch-icon" href="/rsc/images/icon-60.e01e60.png" /><link rel="apple-touch-icon-precomposed" href="/rsc/images/icon-60.e01e60.png" /><link rel="apple-touch-icon" sizes="76x76" href="/rsc/images/icon-76.3ac59c.png" /><link rel="apple-touch-icon-precomposed" sizes="76x76" href="/rsc/images/icon-76.3ac59c.png" /><link rel="apple-touch-icon" sizes="120x120" href="/rsc/images/icon-120.4696a2.png" /><link rel="apple-touch-icon-precomposed" sizes="120x120" href="/rsc/images/icon-120.4696a2.png" /><link rel="apple-touch-icon" sizes="152x152" href="/rsc/images/icon-152.206459.png" /><link rel="apple-touch-icon-precomposed" sizes="152x152" href="/rsc/images/icon-152.206459.png" /><link rel="preload" as="font" crossorigin="anonymous" type="font/woff2" href="/rsc/fonts/montserrat-regular-webfont.6fd836.woff2" /><link rel="preload" as="font" crossorigin="anonymous" type="font/woff2" href="/rsc/fonts/Nexa_XBold-webfont.72163f.woff2" /><link rel="preload" as="font" crossorigin="anonymous" type="font/woff2" href="/rsc/fonts/yaencontre-icons.0a4859.woff2" /><link rel="preload" as="font" crossorigin="anonymous" type="font/woff2" href="/rsc/fonts/montserrat-semibold-webfont.66fd23.woff2" />\n        <link data-chunk="footer" rel="preload" as="styl ...

# %% [markdown]
# Este es el resultado obtenido en HTML de la página de los libros más vendidos, pero es realmente difícil de leer...

# %% [markdown]
# Pero para eso usamos BeautifulSoup y lxml

# %% [markdown]
# Cómo lo hacemos?..

# %% [markdown]
# Creamos un objeto BeautifulSoup llamado soup con la siguiente línea de código:

# %%
soup = bs(html, "lxml")

# %% [markdown]
# bs?
#
# > from bs4 import BeautifulSoup as bs
#
# El primer parámetro del método bs() es html (que fue la variable en la que guardamos ese contenido HTML difícil de leer de la URL de los alquileres de Barcelona)
#
# El segundo parámetro ('lxml'), es el parser que se usa en html

# %% [markdown]
# Ahora vamos a ver el cambio

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="notranslate page-results variantContainer withBreadcrumb" lang="es" translate="no">
# <head>
# <title data-rh="true">Pisos y viviendas en alquiler en Barcelona · 5.514 pisos y viviendas disponibles - yaencontre</title>
# <meta content="Pisos y viviendas en alquiler en Barcelona · 5.514 pisos y viviendas disponibles - yaencontre" data-rh="true" name="title"/><meta content="5.514 Pisos y viviendas en alquiler en Barcelona. Anuncios de pisos y viviendas de particulares y agencias inmobiliarias. ¡Encontrarás lo que estás buscando!" data-rh="true" name="description"/><meta content="index, follow" data-rh="true" name="robots"/><meta content="es" data-rh="true" name="language"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><meta content="#e5005a" name="theme-color"/><meta content="text/html; charset=utf-8" http-equiv="content-type"/><meta content="IE=EDGE" http-equiv="x-ua-compatible"/><meta content="app-id=com.yaencontre.vivienda" name="google-play-app"/><meta content="@yaencontre" name="twitter:site"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="yaencontre" name="apple-mobile-web-app-title"/><meta content="default" name="apple-mobile-web-app-status-bar-style"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yaencontre" name="application-name"/><meta content="yaencontre" name="og:site_name"/><meta content="notranslate" name="google"/><meta content="telephone=no" name="format-detection"/>
# <link href="https://media.yaencontre.com" rel="dns-prefetch"/><link href="https://www.googletagmanager.com" rel="dns-prefetch"/><link href="https://assets.adobedtm.com" rel="dns-prefetch"/><link href="https://sdk.privacy-center.org" rel="dns-prefetch"/>
# <link data-rh="true" href="https://www.yaencontre.com/alquiler/pisos/barcelona" rel="canonical"/><link data-rh="true" href="https://www.yaencontre.com/alquiler/pisos/barcelona/pag-2" rel="next"/><link data-rh="true" href="https://www.yaencontre.com/alquiler/pisos/barcelona" hreflang="es" rel="alternate"/><link data-rh="true" href="https://ca.yaencontre.com/lloguer/pisos/barcelona" hreflang="ca" rel="alternate"/><link as="image" data-rh="true" href="https://media.yaencontre.com/img/photo/w380/29126/29126-45082523-1086007577.jpg" imagesrcset="https://media.yaencontre.com/img/photo/w630/29126/29126-45082523-1086007577.jpg.webp 2x, https://media.yaencontre.com/img/photo/w380/29126/29126-45082523-1086007577.jpg.webp" media="" rel="preload"/>
# <link href="/favicon.ico" rel="shortcut icon"/><link href="/rsc/images/icon-60.e01e60.png" rel="apple-touch-icon"/><link href="/rsc/images/icon-60.e01e60.png" rel="apple-touch-icon-precomposed"/><link href="/rsc/images/icon-76.3ac59c.png" rel="apple-touch-icon" sizes="76x76"/><link href="/rsc/images/icon-76.3ac59c.png" rel="apple-touch-icon-precomposed" sizes="76x76"/><link href="/rsc/images/icon-120.4696a2.png" rel="apple-touch-icon" sizes="120x120"/><link href="/rsc/images/icon-120.4696a2.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="/rsc/images/icon-152.206459.png" rel="apple-touch-icon" sizes="152x152"/><link href="/rsc/images/icon-152.206459.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link as="font" crossorigin="anonymous" href="/rsc/fonts/montserrat-regular-webfont.6fd836.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/rsc/fonts/Nexa_XBold-webfont.72163f.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/rsc/fonts/yaencontre-icons.0a4859.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/rsc/fonts/montserrat-semibold-webfont.66fd23.woff2" rel="preload" type="font/woff2"/>
# <link as="style" data-chunk="footer" href="/rsc/css/9348.eb6be4.css" rel="preload"/>
# <link as="style" data-chunk="results-low" href="/rsc/css/1775.d28d0a.css" rel="preload"/>
# <link as="style" data-chunk="clickEngine" href="/rsc/css/6485.4d7d34.css" rel="preload"/>
# <link as="style" data-chunk="thinElementsList" href="/rsc/css/9608.004da1.css" rel="preload"/>
# <link as="style" data-chunk="thinElementsList" href="/rsc/css/7537.3562e1.css" rel="preload"/>
# <link as="style" data-chunk="results-options" href="/rsc/css/5581.7875d4.css" rel="preload"/>
# <link as="style" data-chunk="results" href="/rsc/css/18.41c5a2.css" rel="preload"/>
# <link as="style" data-chunk="app" href="/rsc/css/app.148bfc.css" rel="preload"/>
# <link data-chunk="app" href="/rsc/css/app.148bfc.css" rel="stylesheet"/>
# <link data-chunk="results" href="/rsc/css/18.41c5a2.css" rel="stylesheet"/>
# <link data-chunk="results-options" href="/rsc/css/5581.7875d4.css" rel="stylesheet"/>
# <link data-chunk="thinElementsList" href="/rsc/css/7537.3562e1.css" rel="stylesheet"/>
# <link data-chunk="thinElementsList" href="/rsc/css/9608.004da1.css" rel="stylesheet"/>
# <link data-chunk="clickEngine" href="/rsc/css/6485.4d7d34.css" rel="stylesheet"/>
# <link data-chunk="results-low" href="/rsc/css/1775.d28d0a.css" rel="stylesheet"/>
# <link data-chunk="footer" href="/rsc/css/9348.eb6be4.css" rel="stylesheet"/>
# </head>
# <body>
# <div id="app"><nav class="Nav"><div class="container"><a class="icon-logo" href="/"></a><a class="classPublishAdvise text-default-color" href="/poner-anuncio" target="_blank"><span>PUBLICAR</span> anuncio</a><a class="classPublishAdvise text-default-color d-none--tablet" href="https://localgest.yaencontre.com/" rel="nofollow" target="_blank">Profesionales</a><div class="alertFeed-wrapper mr-sm"><div class="alertFeed-button pointer icon-alert"><span class="counter">0</span></div></div><div class="Login icon-user pointer"><span class="d-none--tablet">Accede</span></div></div></nav><div class="Results"><div class="headerNav pt-0"><div class="controlsBox pt-0"><div class="flex align-center"><h1 class="d-ellipsis title-results">5.514 Pisos y viviendas en alquiler en Barcelona</h1></div></div></div><div class="headerBreadcrumb"><div class="controlsBox pt-0"><ul class="newBreadcrumb"><li><a class="d-none--tablet" href="/">yaencontre</a></li><li><a class="link" href="/alquiler/pisos/barcelona-provincia">Barcelona (provincia)</a></li><li><a class="link" href="/alquiler/pisos/barcelones">Barcelonès</a></li><li><div class="breadcrumb-level"><div class="pos-rel"><div class="breadcrumb-level__title last-item icon-arrow-down-after"><p class="d-ellipsis">Barcelona</p></div><div class="breadcrumb__toogle-content d-none"><ul><li class="flex flex-nowrap mb-xs d-none--desktop"><span class="link d-ellipsis">Barcelona (provincia)</span><span class="ml-sm">7.290</span></li><li class="flex flex-nowrap mb-xs d-none--desktop"><span class="link d-ellipsis">Barcelonès</span><span class="ml-sm">5.894</span></li><li class="d-block"><ul class="final-container"><li class="toogle-item"><div class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/badalona">Badalona</a><span class="ml-sm">100</span></div></li><li class="toogle-item"><div class="flex flex-nowrap"><a class="link d-ellipsis toogle-item__title--selected breadcrumb-selected" href="/alquiler/pisos/barcelona">Barcelona</a><span class="ml-sm">5.566</span></div><ul class="inner-items"><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-ciutat-vella">Ciutat Vella</a><span class="ml-sm">1.309</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-eixample">Eixample</a><span class="ml-sm">1.717</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-gracia">Gràcia</a><span class="ml-sm">407</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-horta-guinardo">Horta - Guinardó</a><span class="ml-sm">154</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-les-corts">Les Corts</a><span class="ml-sm">235</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-nou-barris">Nou Barris</a><span class="ml-sm">53</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sant-andreu">Sant Andreu</a><span class="ml-sm">62</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sant-marti">Sant Martí</a><span class="ml-sm">504</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sants-montjuic">Sants - Montjuïc</a><span class="ml-sm">359</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sarria-sant-gervasi">Sarrià - Sant Gervasi</a><span class="ml-sm">766</span></li></ul></li><li class="toogle-item"><div class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/hospitalet-de-llobregat-l">Hospitalet de Llobregat, L´</a><span class="ml-sm">183</span></div></li><li class="toogle-item"><div class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/sant-adr ...
# PERFECTO PARA TRABAJADORES DE EMPRESAS O ESTUDIANTES!
# Alojamiento de alquiler mensual, consultar las condiciones previamente.
# Ideal para estudiantes Erasmus, trabajadores de aeropuerto, cerca del HOSPITAL SANT PAU, MATERNITAT, CLINIC, y ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 88 45</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/finques-reina-real-estate-29126" title="Finques Reina Real Estate"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-29126-96352122" title="Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona">Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.190 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">1 hab.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">80 m²</span></div></div><p class="description">APARTAMENTO DE ALQUILER TEMPORAL.
# PERFECTO PARA TRABAJADORES DE EMPRESAS O ESTUDIANTES!
# Alojamiento de alquiler mensual, consultar las condiciones previamente.
# El apartamento es una planta baja completamente reformada y a estrenar dividida en dos plantas. La p...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 88 45</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-u5832404_18970260" title="Piso en calle Sepulveda, Sant Antoni, Barcelona">Piso en calle Sepulveda, Sant Antoni, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">1.400 €</span><div class="flex price-decrease"><div class="hIcon"><div class="previousPriceIcon icon-arrow-down-round"></div><span class="icon-text previousPriceText">1.550 €</span></div><span class="ml-sm previousPriceLabel d-only-desktop d-none-de-medium-desktop d-none-en-medium-desktop">ha bajado</span></div></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">90 m²</span></div></div><p class="description">Piso en perfectas condiciones AMUEBLADO Y CON BALCON Y ELECTRODOMÉSTICOS  para entrar a vivir y todas las comodidades: cocina totalmente equipada (nevera, vitro, microndas, horno), galería con lavadora y secadora, Aire Acondicionado y Calefacción de Gas. Const...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">Llamar</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><div class="banner-wrapper with-title banner-ad d-none" id="box_sas_91212"><div><div class="publi-text">Publicidad</div><div class="results-roba1" id="sas_91212"></div></div></div><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-60288-99803422" title="Ático en El Gòtic, Barcelona">Ático en El Gòtic, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.200 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">1 hab.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">109 m²</span></div></div><p class="description">Bienvenido a XRP Penthouse, un ático dúplex verdaderamente vibrante y especial con terraza privada en el corazón del Barrio Gótico. El apartamento está ubicado en el sexto piso (con ascensor) y disfruta de una gran cantidad de sol, luz natural y vistas.
#
# En el...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 51 22</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/bcn-advisors-60085" title="Bcn Advisors"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-60085-100265982" title="Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona">Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">5.000 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">2 habs.</span></div><div class="icon-bath"><span class="">3 baños</span></div><div class="icon-meter"><span class="">150 m²</span></div></div><p class="description">Esta vivienda reformada con acabados de lujo se encuentra en una de las calles principales del mítico barrio del Born de Barcelona: una zona con mucho encanto que invita a perderse por sus calles medievales, repletas de comercios, restauración y, a su vez, bie...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 92 14</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-67077-100856122" title="Piso en Sant Gervasi - La Bonanova, Barcelona">Piso en Sant Gervasi - La Bonanova, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">3.341 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">130 m²</span></div></div><p class="description">Estamos disponibles todos los días de la semana. Si lo prefieres, puedes contactarnos directamente por WhatsApp en el
#
# Situado a los pies del Tibidabo, encontramos este fantástico complejo residencial con piscina comunitaria y amplia zona ajardinada con parqu...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 84 87</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><div class="banner-wrapper with-title banner-ad d-none" id="box_sas_91213"><div><div class="publi-text">Publicidad</div><div class="results-roba2" id="sas_91213"></div></div></div><span class="invisible"></span><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-56966-103122788" title="Piso en Sant Gervasi - La Bonanova, Barcelona">Piso en Sant Gervasi - La Bonanova, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">3.394 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">115 m²</span></div></div><p class="description">Increíble piso en la zona alta de Barcelona.
#
# Está ubicado en la zona alta de Barcelona, en una prestigiosa comunidad. La comunidad cuenta con vigilancia 24h y conserjería 24h. También cuenta con piscina exterior, zonas verdes y zona de parque infantil.
# El pis...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 60 98</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/caars-assets-36571" title="C&amp;A’s ASSETS"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-36571-103116110" title="Ático en La Dreta de l'Eixample, Barcelona">Ático en La Dreta de l'Eixample, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">5.500 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">5 habs.</span></div><div class="icon-bath"><span class="">4 baños</span></div><div class="icon-meter"><span class="">290 m²</span></div></div><p class="description">Espectacular ático ubicado en Rambla Catalunya. Este preciosos inmueble ocupa la ultima planta entera de un preciosos edificio catalogado y completamente restaurando en Rambla Catalunya con Consejo de Ciento. Realmente este atico es ideal. Se distribuye en dos...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 67 15</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/ukio-spain-s-l-56196" title="Ukio Spain S.L."><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-56196-102162758" title="Piso en Les Corts, Barcelona">Piso en Les Corts, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">3.100 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">2 habs.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">89 m²</span></div></div><p class="description">*COMPLETAMENTE AMUEBLADO*
# *ALQUILERES MENSUALES DE 1 A 11 MESES*
#
# Espectacular apartamento en la calle Morales, con 2 dormitorios y 1 baño. La cocina está totalmente equipada con electrodomésticos y utensilios de cocina de última generación. Las camas están eq...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 37</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/all-houses-bcn-48873" title="All Houses Bcn"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-48873-103097162" title="Piso en Les Tres Torres, Barcelona">Piso en Les Tres Torres, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">4.950 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">5 habs.</span></div><div class="icon-bath"><span class="">3 baños</span></div><div class="icon-meter"><span class="">220 m²</span></div></div><p class="description">FANTÁSTICO PISO CON PISCINA
#
# En el residencial barrio de Tres Torres encontramos este luminoso piso en bonita finca con piscina comunitaria.
#
# El inmueble se encuentra actualizado y listo para entrar a vivir. Destaca la fantástica terraza de 12 m2 que da a la...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 34 21</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><div class="notification-results listBox"><div class="content-title pt-md"><p class="h3 notification-results__title icon-bell mb-0">¿Quieres que te avisemos de las últimas novedades de pisos y viviendas en alquiler en Barcelona?</p></div><form class="form flex" novalidate=""><div class="content-form"><fieldset class="form-fieldset"><div class="form-group field-email"><input class="form-control" id="notification-last-changes_email" name="email" placeholder="Tu e-mail" required="" type="email" value=""/></div></fieldset></div><div class="content-button"><button class="btn button"><span class="label-button">Recibir alertas</span></button></div></form><div class="content-legal"><div><div class="box-readmore" style="overflow-y:hidden;max-height:85px"><div class="robots-nocontent robots-noindex legalAdvice readMoreText" data-nosnippet="true" style="transform:translateY(-0px);color:transparent;background-image:linear-gradient(
#     #737373 42.5px,
#     #ffffff 85px
#   );-webkit-background-clip:text"><noindex>yaencontre (idealista) te informa que tus datos personales serán utilizados para crear tu Área Personal, dónde podrás gestionar tus avisos y enviarte información de nuestros productos según tus preferencias. Podrás ejercer tus derechos de protección de datos según la siguiente <span class="link">política de privacidad</span>.</noindex></div></div><div class="lower-container"><div class="text-center pointer icon-arrow-down-after d-none--desktop"></div></div></div></div></div><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/aproperties-real-estate-barcelona-60293" title="aProperties Real Estate Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-60293-99813022" title="Piso en La Dreta de l'Eixample, Barcelona">Piso en La Dreta de l'Eixample, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">4.550 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">2 habs.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">63 m²</span></div></div><p class="description">Vivienda de lujo amueblada por estrenar al lado de Paseo de Gracia
#
# A un paso de Paseo de Gracia, en una ubicación privilegiada, nos encontramos con un lujoso y moderno apartamento nuevo por estrenar decorado por el reconocido interiorista Jaime Beriestain.
#
# L...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 40 47</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/selekta-properties-48918" title="Selekta Properties"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-48918-101242262" title="Piso en La Dreta de l'Eixample, Barcelona">Piso en La Dreta de l'Eixample, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">3.000 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">1 hab.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">50 m²</span></div></div><p class="description">El apartamento de 1 dormitorio doble y 1 baño, se encuentra ubicado en la zona de Eixample en Barcelona, una de las zonas más céntricas y populares de la ciudad. La propiedad cuenta con una sala de estar-comedor, equipada con un cómodo sofá para descansar desp...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 80 46</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><span class="invisible"></span><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158804" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.800 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">123 m²</span></div></div><p class="description">Nos encontramos ante un edificio con 44 exclusivas viviendas de obra nueva, a estrenar, de 2 y 3 dormitorios con una magnifica distrib
# ución y amplitud, luz natural, y grandes terrazas, cuidando cada detalle y con acabados de alto standing.
#
# En este caso, un f...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158914" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.850 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">123 m²</span></div></div><p class="description">Fantástico piso de obra nueva de 123 m2, situado en una segunda altura con mucha luz natural, nuevo a estrenar. Al entrar al piso, el recibidor nos d
# a paso a un gran espacio con dos ambientes diferenciados, una cocina americana equipada con horno, microondas ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158609" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.950 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">99 m²</span></div></div><p class="description">Nos encontramos ante un edificio con 44 exclusivas viviendas de obra nueva, a estrenar, de 2 y 3 dormitorios con una magnifica distribución y a
# mplitud, luz natural, y grandes terrazas, cuidando cada detalle y con acabados de alto standing.
# El edificio, de 5 ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158745" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.750 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">119 m²</span></div></div><p class="description">Edificio de 44 exclusivas viviendas de obra nueva, con detalles de alto standing. Pisos de 2 o 3 dormitorios con magnifica distribución,
# muy amplios, con luz natural y una variedad de terrazas, balcones y/o patios.
#
# En este caso, presentamos este fantástico p...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102163439" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.550 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">97 m²</span></div></div><p class="description">Fantástico piso de obra nueva
#  de 97 m2, situado en una tercera altura con mucha luz natural. Al entrar al piso, el recibidor nos da paso a un gran espacio con dos ambientes diferenciados, una cocina office independiente equipada con horno, microondas y placa ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158532" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.650 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">91 m²</span></div></div><p class="description">Fantástico piso de obra nueva de 91m2, situado en una tercera altura con mucha luz natural, nuevo a estrenar. Al entrar al piso, el recibidor nos da paso a un gran espacio con dos ambientes diferenciados, una cocina office independiente equipada con horno,
# mi...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><span class="invisible"></span><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158642" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.500 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">91 m²</span></div></div><p class="description">Fantástico piso de obra nueva de 91m2, situado en una tercera altura con mucha luz natural, nuevo a estrenar. Al entrar al piso, e
# l recibidor nos da paso a un gran espacio con dos ambientes diferenciados, una cocina office independiente equipada con horno, mi...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158851" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.800 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">122 m²</span></div></div><p class="description">Nos encontramos ante un edificio con 44 exclusivas viviendas de obra nueva, a estrenar, de 2 y 3 dormitorios con una magnifica distribución y amplitud, luz natural, y grandes terrazas, cuidando cada detalle y con acabados de alto standi
# ng.
#
# En este caso, un f...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158684" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.950 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">135 m²</span></div></div><p class="description">Edificio de 44 exclusivas viviendas de obra nueva, con detalles de alto standing. Pisos de 2 o 3 dormitorios con magnifica distribu
# ción, muy amplios, con luz natural y una variedad de terrazas, balcones y/o patios.
#
# ...
#
# PISO DE ALQUILER EN SANT PERE
#
# - Se alquila piso de 50m² distribuido en 1 habitación doble, 1 baño con plato de ducha, amplio salón comedor, cocina americana completamente equipada con: encimera eléctrica, horno, microondas, nevera y lavadora. El piso ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 64 03</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><span class="invisible"></span><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-101253540" title="Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">4.000 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">146 m²</span></div></div><p class="description">Esta elegante propiedad de 100 m2 deleita con impresionantes vistas al mar y la ciudad, presentando una deslumbrante terraza de 46 m2 que abraza la fachada y destila sofisticación y estilo en cada rincón.
#
# El apartamento se distingue por su luminoso salón de p...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 30 40</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-99263403" title="Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">5.000 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">1 hab.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">133 m²</span></div></div><p class="description">Ingresa al apartamento y déjate cautivar por las impresionantes vistas al mar y a Barcelona. El apartamento está diseñado con la mejor orientación posible para garantizar luz directa y vistas abiertas durante todo el día. Lo más destacado del apartamento es su...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 30 40</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-94189306" title="Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">7.500 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">3 baños</span></div><div class="icon-meter"><span class="">200 m²</span></div></div><p class="description">Experimenta la vida de penthouse en este impresionante dúplex con varias terrazas que ofrece las vistas impresionantes de la ciudad. (Whatsapp )
#
# Ubicado en Diagonal Mar, esta notable propiedad cuenta con vistas despejadas del reluciente mar por un lado y las ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 30 40</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-95527996" title="Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">6.000 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">153 m²</span></div></div><p class="description">Este impresionante ático es una verdadera joya que ofrece un estilo de vida exclusivo que es difícil de encontrar. En el prestigioso Paseo García Faria, el apartamento cuenta con vistas directas al mar y una amplia terraza que rodea toda la fachada. Al entrar,...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 30 40</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-100763886" title="Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">3.800 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">130 m²</span></div></div><p class="description">Este notable apartamento está situado en el prestigioso complejo Illa de La Llum, diseñado por los renombrados arquitectos LLuís Clotet e Ignacio Paricio, que fue galardonado con el Premio Construmat a la Innovación Tecnológica en la categoría de Edificación e...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 30 40</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button> ...
# <script id="ssr_initialState">
#       window.__INITIAL_STATE__ = JSON.parse("{\"agencyList\":{\"isFetching\":false,\"currentPageItems\":{\"byId\":{},\"sortedItems\":[]}},\"results\":{\"isFetching\":false,\"currentPageItems\":{\"byId\":{\"jht::real-estate::29126-96822843\":{\"item\":{\"images\":[{\"slug\":\"29126/29126-45082523-1086007577.jpg\"},{\"slug\":\"29126/29126-45082523-1086007578.jpg\"},{\"slug\":\"29126/29126-45082523-1086007579.jpg\"},{\"slug\":\"29126/29126-45082523-1086007580.jpg\"},{\"slug\":\"29126/29126-45082523-1086007581.jpg\"},{\"slug\":\"29126/29126-45082523-1086007582.jpg\"},{\"slug\":\"29126/29126-45082523-1086007583.jpg\"},{\"slug\":\"29126/29126-45082523-1086007584.jpg\"},{\"slug\":\"29126/29126-45082523-1086007585.jpg\"},{\"slug\":\"29126/29126-45082523-1086007586.jpg\"},{\"slug\":\"29126/29126-45082523-1086007587.jpg\"},{\"slug\":\"29126/29126-45082523-1086007588.jpg\"},{\"slug\":\"29126/29126-45082523-1086007589.jpg\"},{\"slug\":\"29126/29126-45082523-1086007590.jpg\"},{\"slug\":\"29126/29126-45082523-1086007591.jpg\"},{\"slug\":\"29126/29126-45082523-1086007592.jpg\"},{\"slug\":\"29126/29126-45082523-1086007593.jpg\"},{\"slug\":\"29126/29126-45082523-1086007594.jpg\"},{\"slug\":\"29126/29126-45082523-1086007595.jpg\"},{\"slug\":\"29126/29126-45082523-1086007596.jpg\"},{\"slug\":\"29126/29126-45082523-1086007597.jpg\"},{\"slug\":\"29126/29126-45082523-1086007598.jpg\"},{\"slug\":\"29126/29126-45082523-1086007599.jpg\"},{\"slug\":\"29126/29126-45082523-1086007600.jpg\"},{\"slug\":\"29126/29126-45082523-1086007601.jpg\"},{\"slug\":\"29126/29126-45082523-1086007602.jpg\"},{\"slug\":\"29126/29126-45082523-1086007603.jpg\"},{\"slug\":\"29126/29126-45082523-1086007604.jpg\"}],\"renders\":[],\"videos\":[],\"floorplans\":[],\"tour360\":[],\"tour3d\":[],\"hasRender\":false,\"hasVideo\":false,\"hasFloorplans\":false,\"hasTour360\":false,\"hasTour3d\":false,\"id\":\"jht::real-estate::29126-96822843\",\"reference\":\"29126-96822843\",\"ownerReference\":\"96822843\",\"title\":\"Piso en El Camp de l'Arpa del Clot, Barcelona\",\"description\":\"ALQUILER DE TEMPORADA.\\nPERFECTO PARA TRABAJADORES DE EMPRESAS O ESTUDIANTES!\\nAlojamiento de alquiler mensual, consultar las condiciones previamente.\\nIdeal para estudiantes Erasmus, trabajadores de aeropuerto, cerca del HOSPITAL SANT PAU, MATERNITAT, CLINIC, y ...\",\"operation\":\"RENT\",\"family\":\"FLAT\",\"owner\":{\"type\":\"REAL_ESTATE_AGENCY\",\"commercialId\":29126,\"name\":\"Finques Reina Real Estate\",\"virtualPhoneNumber\":\"+34 936178845\",\"phoneAvailable\":true,\"phoneRequired\":false,\"logo\":{\"slug\":\"logos_visibilidad/29126.gif\"},\"url\":\"/inmobiliarias/finques-reina-real-estate-29126\",\"siteEnabled\":true},\"price\":2560,\"area\":69,\"rooms\":2,\"bathrooms\":1,\"address\":{\"qualifiedName\":\"El Camp de l'Arpa del Clot, Sant Mart\u00ED, Barcelona, Barcelona (provincia)\",\"geoLocation\":{\"lat\":41.4122081,\"lon\":2.1754106},\"addressVisibility\":\"APPROXIMATE\"},\"url\":\"/alquiler/piso/inmueble-29126-96822843\",\"isNewConstruction\":false},\"template\":\"standard\"},\"jht::real-estate::29126-96352122\":{\"item\":{\"images\":[{\"slug\":\"29126/29126-44454340-1085987457.jpg\"},{\"slug\":\"29126/29126-44454340-1071129319.jpg\"},{\"slug\":\"29126/29126-44454340-1071129332.jpg\"},{\"slug\":\"29126/29126-44454340-1071129320.jpg\"},{\"slug\":\"29126/29126-44454340-1071129321.jpg\"},{\"slug\":\"29126/29126-44454340-1071129322.jpg\"},{\"slug\":\"29126/29126-44454340-1071129323.jpg\"},{\"slug\":\"29126/29126-44454340-1085987458.jpg\"},{\"slug\":\"29126/29126-44454340-1071129325.jpg\"},{\"slug\":\"29126/29126-44454340-1071129326.jpg\"},{\"slug\":\"29126/29126-44454340-1071129327.jpg\"},{\"slug\":\"29126/29126-44454340-1071129328.jpg\"},{\"slug\":\"29126/29126-44454340-1071129329.jpg\"},{\"slug\":\"29126/29126-44454340-1071129330.jpg\"},{\"slug\":\"29126/29126-44454340-1085987459.jpg\"},{\"slug\":\"29126/29126-44454340-1071129331.jpg\"},{\"slug\":\"29126/29126-44454340-1071129333.jpg\"},{\ ...
#       window.JHT = JSON.parse(atob('...'));
#     </script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[9647,5649,4158,5954,18,5581,1575,2942,5112,9528,9608,6485,3146]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["results","results-options","thinElementsList","clickEngine","lang-es"]}</script>
# <script async="" data-chunk="app" src="/rsc/js/runtime~app.52c337.js"></script>
# <script async="" data-chunk="app" src="/rsc/js/693.a5d147.js"></script>
# <script async="" data-chunk="app" src="/rsc/js/app.ecfaee.js"></script>
# <script async="" data-chunk="results" src="/rsc/js/9647.cd4865.js"></script>
# <script async="" data-chunk="results" src="/rsc/js/5649.c1b388.js"></script>
# <script async="" data-chunk="results" src="/rsc/js/4158.e8b044.js"></script>
# <script async="" data-chunk="results" src="/rsc/js/5954.611940.js"></script>
# <script async="" data-chunk="results" src="/rsc/js/results.db5012.js"></script>
# <script async="" data-chunk="results-options" src="/rsc/js/results-options.ca80a3.js"></script>
# <script async="" data-chunk="thinElementsList" src="/rsc/js/1575.69ceaf.js"></script>
# <script async="" data-chunk="thinElementsList" src="/rsc/js/2942.36861c.js"></script>
# <script async="" data-chunk="thinElementsList" src="/rsc/js/5112.228d9a.js"></script>
# <script async="" data-chunk="thinElementsList" src="/rsc/js/9528.f35daf.js"></script>
# <script async="" data-chunk="thinElementsList" src="/rsc/js/thinElementsList.aaa169.js"></script>
# <script async="" data-chunk="clickEngine" src="/rsc/js/clickEngine.285929.js"></script>
# <script async="" data-chunk="lang-es" src="/rsc/js/lang-es.9611dd.js"></script>
# </body>
# </html>

# %% [markdown]
# ## Cómo navegar por un objeto de Beautiful Soup

# %% [markdown]
# HTML consta de elementos como enlaces, párrafos, encabezados, bloques, etc. Estos elementos están envueltos entre etiquetas; dentro de la etiqueta de apertura y cierre se puede encontrar el contenido del elemento.

# %% [markdown]
# Los elementos HTML también pueden tener atributos que contienen información adicional sobre el elemento. Los atributos se definen en las etiquetas de apertura con la siguiente sintaxis: nombre del atributo = "valor del atributo".

# %% [markdown]
# Ahora que hemos aprendido algo de HTML básico, finalmente podemos comenzar a extraer datos de soup. Simplemente escriba un nombre de etiqueta después de soup y un punto (como soup.title), y observe cómo se desarrolla la magia:

# %%
soup.title
# Out:
# <title data-rh="true">Pisos y viviendas en alquiler en Barcelona · 5.514 pisos y viviendas disponibles - yaencontre</title>

# %%
soup.h1
# Out:
# <h1 class="d-ellipsis title-results">5.514 Pisos y viviendas en alquiler en Barcelona</h1>

# %% [markdown]
# Eliminamos las etiquetas

# %%
soup.h1.get_text()
# Out:
# '5.514 Pisos y viviendas en alquiler en Barcelona'

# %% [markdown]
# ¿Qué sucede si solo necesita el atributo de un elemento? Tampoco hay problema:

# %%
#Si en inspeccionar, hacemos Ctrl+F y buscamos <a>, encontramos la primera etiqueta a
soup.a['href']
soup.a.get('class')
# Out:
# ['icon-logo']

# %% [markdown]
# También podemos..
# > soup.a.get("href")

# %% [markdown]
# La sintaxis de soup.```cualquier_etiqueta``` devuelve solo el primer elemento con ese nombre de etiqueta. En lugar de soup.```cualquier_etiqueta```, también puedes usar el método .find() y obtendrás exactamente el mismo resultado:

# %%
print("Sin utilizar método .find()")
print(soup.h1)
print("")
print("Utilizando método .find()")
print(soup.find('h1'))
# Out:
# Sin utilizar método .find()
# <h1 class="d-ellipsis title-results">5.514 Pisos y viviendas en alquiler en Barcelona</h1>
#
# Utilizando método .find()
# <h1 class="d-ellipsis title-results">5.514 Pisos y viviendas en alquiler en Barcelona</h1>

# %% [markdown]
# A menudo, no solo necesitas uno, sino todos los elementos (por ejemplo, cada enlace en una página). Para eso es bueno el método .find_all():

# %%
soup.find_all('a')
# Out:
# [<a class="icon-logo" href="/"></a>,
#  <a class="classPublishAdvise text-default-color" href="/poner-anuncio" target="_blank"><span>PUBLICAR</span> anuncio</a>,
#  <a class="classPublishAdvise text-default-color d-none--tablet" href="https://localgest.yaencontre.com/" rel="nofollow" target="_blank">Profesionales</a>,
#  <a class="d-none--tablet" href="/">yaencontre</a>,
#  <a class="link" href="/alquiler/pisos/barcelona-provincia">Barcelona (provincia)</a>,
#  <a class="link" href="/alquiler/pisos/barcelones">Barcelonès</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/badalona">Badalona</a>,
#  <a class="link d-ellipsis toogle-item__title--selected breadcrumb-selected" href="/alquiler/pisos/barcelona">Barcelona</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-ciutat-vella">Ciutat Vella</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-eixample">Eixample</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-gracia">Gràcia</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-horta-guinardo">Horta - Guinardó</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-les-corts">Les Corts</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-nou-barris">Nou Barris</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sant-andreu">Sant Andreu</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sant-marti">Sant Martí</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sants-montjuic">Sants - Montjuïc</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sarria-sant-gervasi">Sarrià - Sant Gervasi</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/hospitalet-de-llobregat-l">Hospitalet de Llobregat, L´</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/sant-adria-de-besos">Sant Adrià de Besos</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/santa-coloma-de-gramanet">Santa Coloma de Gramanet</a>,
#  <a class="link" href="/venta/pisos/barcelona">Comprar</a>,
#  <a class="link" href="/alquiler-vacacional/pisos/barcelona" rel="nofollow">Alquiler vacacional</a>,
#  <a class="link" href="/alquiler/pisos/barcelona/t-apartamentos">Apartamentos</a>,
#  <a class="link" href="/alquiler/pisos/barcelona/t-aticos">Áticos</a>,
#  <a class="link" href="/alquiler/pisos/barcelona/t-estudios">Estudios</a>,
#  <a class="link" href="/alquiler/pisos/barcelona/t-duplex">Dúplexs</a>,
#  <a class="link" href="/alquiler/pisos/barcelona/t-loft">Lofts</a>,
#  <a class="link" href="/alquiler/casas/barcelona">Casas</a>,
#  <a class="link" href="/alquiler/terrenos/barcelona">Terrenos</a>,
#  <a class="link" href="/alquiler/locales/barcelona">Locales</a>,
#  <a class="link" href="/alquiler/garajes/barcelona">Garajes</a>,
#  <a class="link" href="/alquiler/naves/barcelona">Naves</a>,
#  <a class="link" href="/alquiler/negocios/barcelona">Negocios</a>,
#  <a class="link" href="/alquiler/oficinas/barcelona">Oficinas</a>,
#  <a class="link" href="/alquiler/edificios/barcelona">Edificios</a>,
#  <a class="link" href="/alquiler/trasteros/barcelona">Trasteros</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/finques-reina-real-estate-29126" title="Finques Reina Real Estate"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-29126-96822843" title="Piso en El Camp de l'Arpa del Clot, Barcelona">Piso en El Camp de l'Arpa del Clot, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/finques-reina-real-estate-29126" title="Finques Reina Real Estate"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-29126-96352122" title="Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona">Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona</a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-u5832404_18970260" title="Piso en calle Sepulveda, Sant Antoni, Barcelona">Piso en calle Sepulveda, Sant Antoni, Barcelona</a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-60288-99803422" title="Ático en El Gòtic, Barcelona">Ático en El Gòtic, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/bcn-advisors-60085" title="Bcn Advisors"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-60085-100265982" title="Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona">Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona</a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-67077-100856122" title="Piso en Sant Gervasi - La Bonanova, Barcelona">Piso en Sant Gervasi - La Bonanova, Barcelona</a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-56966-103122788" title="Piso en Sant Gervasi - La Bonanova, Barcelona">Piso en Sant Gervasi - La Bonanova, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/caars-assets-36571" title="C&amp;A’s ASSETS"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-36571-103116110" title="Ático en La Dreta de l'Eixample, Barcelona">Ático en La Dreta de l'Eixample, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/ukio-spain-s-l-56196" title="Ukio Spain S.L."><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-56196-102162758" title="Piso en Les Corts, Barcelona">Piso en Les Corts, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/all-houses-bcn-48873" title="All Houses Bcn"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-48873-103097162" title="Piso en Les Tres Torres, Barcelona">Piso en Les Tres Torres, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/aproperties-real-estate-barcelona-60293" title="aProperties Real Estate Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-60293-99813022" title="Piso en La Dreta de l'Eixample, Barcelona">Piso en La Dreta de l'Eixample, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/selekta-properties-48918" title="Selekta Properties"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-48918-101242262" title="Piso en La Dreta de l'Eixample, Barcelona">Piso en La Dreta de l'Eixample, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158804" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158914" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158609" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158745" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102163439" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158532" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158642" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158851" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158684" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-57129-101666372" title="Piso en L'Antiga Esquerra de l'Eixample, Barcelona">Piso en L'Antiga Esquerra de l'Eixample, Barcelona</a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-60789-103076693" title="Piso en El Camp de l'Arpa del Clot, Barcelona">Piso en El Camp de l'Arpa del Clot, Barcelona</a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-55761-102536047" title="Piso en calle De Les Escoles Pies, Sant Gervasi - Galvany, Barcelona">Piso en calle De Les Escoles Pies, Sant Gervasi - Galvany, Barcelona</a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54759-94785288" title="Piso en plaza Mañé i Flaquer, El Putxet i el Farró, Barcelona">Piso en plaza Mañé i Flaquer, El Putxet i el Farró, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/my-space-barcelona-60336" title="My Space Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-60336-102514257" title="Ático en El Putxet i el Farró, Barcelona">Ático en El Putxet i el Farró, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/my-space-barcelona-60336" title="My Space Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-60336-102411028" title="Ático en calle Bertran, El Putxet i el Farró, Barcelona">Ático en calle Bertran, El Putxet i el Farró, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/my-space-barcelona-60336" title="My Space Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-60336-103039474" title="Ático en El Putxet i el Farró, Barcelona">Ático en El Putxet i el Farró, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/my-space-barcelona-60336" title="My Space Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-60336-102859030" title="Ático en El Putxet i el Farró, Barcelona">Ático en El Putxet i el Farró, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/my-space-barcelona-60336" title="My Space Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-60336-102448131" title="Ático en El Putxet i el Farró, Barcelona">Ático en El Putxet i el Farró, Barcelona</a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-60180-37535611" title="Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona">Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/aproperties-real-estate-barcelona-60293" title="aProperties Real Estate Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-60293-103172638" title="Piso en El Raval, Barcelona">Piso en El Raval, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/aproperties-real-estate-barcelona-60293" title="aProperties Real Estate Barcelona"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-60293-102853097" title="Piso en El Poblenou, Barcelona">Piso en El Poblenou, Barcelona</a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-55055-90634863" title="Piso en La Dreta de l'Eixample, Barcelona">Piso en La Dreta de l'Eixample, Barcelona</a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-67020-102668709" title="Piso en calle Avenir, Sant Gervasi - Galvany, Barcelona">Piso en calle Avenir, Sant Gervasi - Galvany, Barcelona</a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-32232-83447779" title="Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona">Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-101253540" title="Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-99263403" title="Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-94189306" title="Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-95527996" title="Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-100763886" title="Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a>,
#  <a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a>,
#  <a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-102240883" title="Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/shbarcelona-46589" title="ShBarcelona">ShBarcelona</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/ukio-spain-s-l-56196" title="Ukio Spain S.L.">Ukio Spain S.L.</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/engel-a-volkers-barcelona-51945" title="Engel &amp; Völkers Barcelona">Engel &amp; Völkers Barcelona</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/homelike-60247" title="Homelike">Homelike</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/aproperties-real-estate-barcelona-60293" title="aProperties Real Estate Barcelona">aProperties Real Estate Barcelona</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/atemporal-55533" title="aTemporal">aTemporal</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/roomless-60515" title="roomless">roomless</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/uniplaces-69125" title="Uniplaces">Uniplaces</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/blueground-barcelona-62292" title="BLUEGROUND BARCELONA">BLUEGROUND BARCELONA</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/my-space-barcelona-60336" title="My Space Barcelona">My Space Barcelona</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/area-casa-50899" title="Area Casa">Area Casa</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/all4flat-51565" title="ALL4FLAT">ALL4FLAT</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/casamona-international-real-estate-49875" title="Casamona (International Real Estate)">Casamona (International Real Estate)</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/caterina-house-55974" title="Caterina House">Caterina House</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/oak-properties-36164" title="Oak Properties">Oak Properties</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/real-estate-property-53917" title="Real Estate Property">Real Estate Property</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/rs-group-real-estate-32232" title="RS GROUP REAL ESTATE">RS GROUP REAL ESTATE</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/home-club-39095" title="Home Club">Home Club</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/beres-rent-59409" title="Beres Rent">Beres Rent</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/atipika-lifestyle-properties-59979" title="ATIPIKA Lifestyle Properties">ATIPIKA Lifestyle Properties</a>,
#  <a href="/inmobiliarias/barcelona">Ver todas las inmobiliarias en Barcelona</a>,
#  <a class="d-none--small-mobile" href="/alquiler/pisos/barcelona/pag-2">2</a>,
#  <a class="d-none--small-mobile" href="/alquiler/pisos/barcelona/pag-3">3</a>,
#  <a class="d-none--small-mobile" href="/alquiler/pisos/barcelona/pag-4">4</a>,
#  <a class="d-none--small-mobile" href="/alquiler/pisos/barcelona/pag-5">5</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/e-baratos">Pisos baratos de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/e-de-bancos">Pisos de bancos de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/e-lujo">Pisos de lujo de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/e-particulares">Pisos de particulares de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-terraza">Pisos con terraza de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-piscina">Pisos con piscina de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-garaje">Pisos con garaje de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-jardin">Pisos con jardín de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-amueblado">Pisos amueblados de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-balcon">Pisos con balcón de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-aire-acondicionado">Pisos con aire acondicionado de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-calefaccion">Pisos con calefacción de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/e-obra-nueva">Pisos de obra nueva de alquiler</a>,
#  <a href="https://www.yaencontre.com/inmuebles/venta/pisos/e-de-bancos">Pisos de bancos</a>,
#  <a href="/alquiler/pisos">Alquiler de pisos</a>,
#  <a href="/alquiler/casas">casas</a>,
#  <a href="/venta/pisos">Compra de pisos</a>,
#  <a href="/venta/casas">casas</a>,
#  <a class="icon-facebook" href="https://www.facebook.com/yaencontre.comvivienda/" rel="noopener noreferrer" target="_blank" title="Síguenos en Facebook"><span>Síguenos en Facebook</span></a>,
#  <a class="icon-instagram" href="https://www.instagram.com/yaencontre/" rel="noopener noreferrer" target="_blank" title="Síguenos en Instagram"><span>Síguenos en Instagram</span></a>,
#  <a class="icon-twitter" href="https://twitter.com/yaencontre" rel="noopener noreferrer" target="_blank" title="Noticias inmobiliarias en X"><span>Noticias inmobiliarias en X</span></a>,
#  <a class="icon-youtube-round" href="https://www.youtube.com/user/yaencontre/" rel="noopener noreferrer" target="_blank" title="Noticias inmobiliarias en Youtube"><span>Noticias inmobiliarias en Youtube</span></a>,
#  <a class="icon-linkedin" href="https://es.linkedin.com/company/grupo-yaencontre-com" rel="noopener noreferrer" target="_blank" title="Síguenos en Linkedin"><span>Síguenos en Linkedin</span></a>,
#  <a class="icon-tiktok" href="https://www.tiktok.com/@yaencontre.com" rel="noopener noreferrer" target="_blank" title="Síguenos en TikTok"><span>Síguenos en TikTok</span></a>,
#  <a href="https://www.yaencontre.com/vender-piso" target="_blank">Particulares</a>,
#  <a href="https://localgest.yaencontre.com/" rel="nofollow" target="_blank">Profesionales</a>,
#  <a href="https://www.yaencontre.com/grupo/contacta" target="_blank">Contactar</a>]

# %% [markdown]
# Si nos fijamos podemos ver que lo que nos devuelve es una lista..

# %% [markdown]
# Qué podemos hacer con una lista?..

# %%
all_a = soup.find_all('a')
for a in all_a[:5]:
    print(a)
    print(type(a))
# Out:
# <a class="icon-logo" href="/"></a>
# <class 'bs4.element.Tag'>
# <a class="classPublishAdvise text-default-color" href="/poner-anuncio" target="_blank"><span>PUBLICAR</span> anuncio</a>
# <class 'bs4.element.Tag'>
# <a class="classPublishAdvise text-default-color d-none--tablet" href="https://localgest.yaencontre.com/" rel="nofollow" target="_blank">Profesionales</a>
# <class 'bs4.element.Tag'>
# <a class="d-none--tablet" href="/">yaencontre</a>
# <class 'bs4.element.Tag'>
# <a class="link" href="/alquiler/pisos/barcelona-provincia">Barcelona (provincia)</a>
# <class 'bs4.element.Tag'>

# %% [markdown]
# Ok.. Pero como extraigo la data con BeautifilSoup?..

# %% [markdown]
# La página contiene 42 pisos con información relacionada con ellos. De los datos disponibles extraeremos los siguientes:
#
# - Títulos
# - Url
# - habitaciones
# - prices

# %% [markdown]
# Mientras trabajamos con BeautifulSoup, el flujo general de extracción de datos será un enfoque de dos pasos:
#
# * Inspeccionar en el navegador los elementos HTML que queremos extraer
# * Luego encontrar los elementos HTML con BeautifulSoup.

# %%
soup.find_all('a', attrs={'rel': "noopener noreferrer"})
# Out:
# [<a class="icon-facebook" href="https://www.facebook.com/yaencontre.comvivienda/" rel="noopener noreferrer" target="_blank" title="Síguenos en Facebook"><span>Síguenos en Facebook</span></a>,
#  <a class="icon-instagram" href="https://www.instagram.com/yaencontre/" rel="noopener noreferrer" target="_blank" title="Síguenos en Instagram"><span>Síguenos en Instagram</span></a>,
#  <a class="icon-twitter" href="https://twitter.com/yaencontre" rel="noopener noreferrer" target="_blank" title="Noticias inmobiliarias en X"><span>Noticias inmobiliarias en X</span></a>,
#  <a class="icon-youtube-round" href="https://www.youtube.com/user/yaencontre/" rel="noopener noreferrer" target="_blank" title="Noticias inmobiliarias en Youtube"><span>Noticias inmobiliarias en Youtube</span></a>,
#  <a class="icon-linkedin" href="https://es.linkedin.com/company/grupo-yaencontre-com" rel="noopener noreferrer" target="_blank" title="Síguenos en Linkedin"><span>Síguenos en Linkedin</span></a>,
#  <a class="icon-tiktok" href="https://www.tiktok.com/@yaencontre.com" rel="noopener noreferrer" target="_blank" title="Síguenos en TikTok"><span>Síguenos en TikTok</span></a>]

# %% [markdown]
# ## Suficiente información...

# %% [markdown]
# Manos a la obra

# %% [markdown]
# ## Obtener los títulos de los pisos (find_all + get_text)

# %% [markdown]
# Para ello vamos a inspeccionar en el navegador (click derecho sobre un titulo de un piso y elegimos inspeccionar)

# %%
all_h3 = soup.find_all('h3')
for h3 in all_h3[:5]:
    print(h3)
    print('Es un objeto',type(h3), ', por tanto, tiene métodos de beautiful soup (find, find_all, get_text)')
    print()
    print('Todo el texto del h3')
    print(h3.get_text())
    print('--------------------------------------------------')
# Out:
# <h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-29126-96822843" title="Piso en El Camp de l'Arpa del Clot, Barcelona">Piso en El Camp de l'Arpa del Clot, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.560 €</span></div></h3>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del h3
# Piso en El Camp de l'Arpa del Clot, Barcelona2.560 €
# --------------------------------------------------
# <h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-29126-96352122" title="Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona">Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.190 €</span></div></h3>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del h3
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona2.190 €
# --------------------------------------------------
# <h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-u8178150_37224251" title="Piso en calle Formatgeria, El Gòtic, Barcelona">Piso en calle Formatgeria, El Gòtic, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">825 €</span></div></h3>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del h3
# Piso en calle Formatgeria, El Gòtic, Barcelona825 €
# --------------------------------------------------
# <h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-60288-99803422" title="Ático en El Gòtic, Barcelona">Ático en El Gòtic, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.200 €</span></div></h3>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del h3
# Ático en El Gòtic, Barcelona2.200 €
# --------------------------------------------------
# <h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-60085-100265982" title="Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona">Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">5.000 €</span></div></h3>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del h3
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona5.000 €
# --------------------------------------------------

# %% [markdown]
# Si queremos obtener solo los títulos

# %%
all_h3 = soup.find_all('h3', class_='title')
for h3 in all_h3:
    print('Solo el título')
    print(h3.a.get_text(strip = True))
    print('Es un objeto',type(h3.a), ', por tanto, tiene métodos de beautiful soup (find, find_all, get_text)')
    print('---------------------------------------------------------------------')
# Out:
# Solo el título
# Piso en El Camp de l'Arpa del Clot, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en calle Sepulveda, Sant Antoni, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en El Gòtic, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - La Bonanova, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - La Bonanova, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Les Corts, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Les Tres Torres, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en L'Antiga Esquerra de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en El Camp de l'Arpa del Clot, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en calle De Les Escoles Pies, Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en plaza Mañé i Flaquer, El Putxet i el Farró, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en El Putxet i el Farró, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en calle Bertran, El Putxet i el Farró, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en El Putxet i el Farró, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en El Putxet i el Farró, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en El Putxet i el Farró, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en El Raval, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en El Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en calle Avenir, Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------

# %%
all_h3 = soup.find_all('h3', attrs = {'class': 'title'})
for h3 in all_h3:
    print('Solo el título')
    print(h3.a.get_text(strip = True))
    print('Es un objeto',type(h3.a), ', por tanto, tiene métodos de beautiful soup (find, find_all, get_text)')
    print('---------------------------------------------------------------------')
# Out:
# Solo el título
# Piso en El Camp de l'Arpa del Clot, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en calle Sepulveda, Sant Antoni, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en El Gòtic, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - La Bonanova, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - La Bonanova, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Les Corts, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Les Tres Torres, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en L'Antiga Esquerra de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en El Camp de l'Arpa del Clot, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en calle De Les Escoles Pies, Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en plaza Mañé i Flaquer, El Putxet i el Farró, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en El Putxet i el Farró, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en calle Bertran, El Putxet i el Farró, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en El Putxet i el Farró, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en El Putxet i el Farró, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en El Putxet i el Farró, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en El Raval, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en El Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en calle Avenir, Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------

# %% [markdown]
# ### Los añadimos a una lista

# %%
lista_titulos = []

all_h3 = soup.find_all('h3', class_='title')
for h3 in all_h3:
    lista_titulos.append(h3.a.get_text(strip = True))

lista_titulos
# Out:
# ["Piso en El Camp de l'Arpa del Clot, Barcelona",
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en calle Sepulveda, Sant Antoni, Barcelona',
#  'Ático en El Gòtic, Barcelona',
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en Sant Gervasi - La Bonanova, Barcelona',
#  'Piso en Sant Gervasi - La Bonanova, Barcelona',
#  "Ático en La Dreta de l'Eixample, Barcelona",
#  'Piso en Les Corts, Barcelona',
#  'Piso en Les Tres Torres, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  "Piso en L'Antiga Esquerra de l'Eixample, Barcelona",
#  "Piso en El Camp de l'Arpa del Clot, Barcelona",
#  'Piso en calle De Les Escoles Pies, Sant Gervasi - Galvany, Barcelona',
#  'Piso en plaza Mañé i Flaquer, El Putxet i el Farró, Barcelona',
#  'Ático en El Putxet i el Farró, Barcelona',
#  'Ático en calle Bertran, El Putxet i el Farró, Barcelona',
#  'Ático en El Putxet i el Farró, Barcelona',
#  'Ático en El Putxet i el Farró, Barcelona',
#  'Ático en El Putxet i el Farró, Barcelona',
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en El Raval, Barcelona',
#  'Piso en El Poblenou, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en calle Avenir, Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona']

# %%
lista_titulos = []

all_h3 = soup.find_all('h3', attrs={'class':'title'})
for h3 in all_h3:
    lista_titulos.append(h3.a.get_text(strip = True))

lista_titulos
# Out:
# ["Piso en El Camp de l'Arpa del Clot, Barcelona",
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en calle Formatgeria, El Gòtic, Barcelona',
#  'Ático en El Gòtic, Barcelona',
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en Sant Gervasi - La Bonanova, Barcelona',
#  'Piso en Sant Gervasi - La Bonanova, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  "Piso en El Camp de l'Arpa del Clot, Barcelona",
#  'Ático en El Gòtic, Barcelona',
#  "Piso en L'Antiga Esquerra de l'Eixample, Barcelona",
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en Sants, Barcelona',
#  'Piso en calle De Balboa, La Barceloneta, Barcelona',
#  'Piso en calle De Les Escoles Pies, Sant Gervasi - Galvany, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  "Piso en L'Antiga Esquerra de l'Eixample, Barcelona",
#  'Piso en calle Avenir, Sant Gervasi - Galvany, Barcelona',
#  'Piso en calle De Viladomat, Sant Antoni, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en paseo De Garcia Fària, Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona']

# %% [markdown]
# ##### Otra forma de hacerlo

# %%
lista_titulos = [h3.a.get_text(strip=True) for h3 in soup.find_all('h3', class_='title')]
lista_titulos
# Out:
# ["Piso en El Camp de l'Arpa del Clot, Barcelona",
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en calle Sepulveda, Sant Antoni, Barcelona',
#  'Ático en El Gòtic, Barcelona',
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en Sant Gervasi - La Bonanova, Barcelona',
#  'Piso en Sant Gervasi - La Bonanova, Barcelona',
#  "Ático en La Dreta de l'Eixample, Barcelona",
#  'Piso en Les Corts, Barcelona',
#  'Piso en Les Tres Torres, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  "Piso en L'Antiga Esquerra de l'Eixample, Barcelona",
#  "Piso en El Camp de l'Arpa del Clot, Barcelona",
#  'Piso en calle De Les Escoles Pies, Sant Gervasi - Galvany, Barcelona',
#  'Piso en plaza Mañé i Flaquer, El Putxet i el Farró, Barcelona',
#  'Ático en El Putxet i el Farró, Barcelona',
#  'Ático en calle Bertran, El Putxet i el Farró, Barcelona',
#  'Ático en El Putxet i el Farró, Barcelona',
#  'Ático en El Putxet i el Farró, Barcelona',
#  'Ático en El Putxet i el Farró, Barcelona',
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en El Raval, Barcelona',
#  'Piso en El Poblenou, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en calle Avenir, Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona']

# %% [markdown]
# ## Tips importantes

# %% [markdown]
# soup.find_all(“h3”) encuentra cada elemento h3 en la página web; con class_=”title” especificamos que buscamos específicamente etiquetas h3 que contengan el atributo class_=”title” (nota importante: el “_” en **class__=”title”** no es un error tipográfico, se requiere en Beautiful Soup cuando seleccionando atributos de clase).

# %% [markdown]
# Guardamos los elementos h3 en all_h3, que se comporta como una lista, por lo que podemos recorrerlos con un bucle for. En cada iteración extraemos solo el texto del elemento h3 con .get_text(), y con el parámetro strip=True nos aseguramos de eliminar cualquier espacio en blanco innecesario.

# %% [markdown]
# ## Obtener los METROS CUADRADOS

# %%
lista_m2 = []
m2 = soup.find_all('div', class_ = 'icon-meter')
for i in m2:
    lista_m2.append(i.get_text(strip=True))
lista_m2
# Out:
# ['69 m²',
#  '80 m²',
#  '90 m²',
#  '109 m²',
#  '150 m²',
#  '130 m²',
#  '115 m²',
#  '290 m²',
#  '89 m²',
#  '220 m²',
#  '63 m²',
#  '50 m²',
#  '123 m²',
#  '123 m²',
#  '99 m²',
#  '119 m²',
#  '97 m²',
#  '91 m²',
#  '91 m²',
#  '122 m²',
#  '135 m²',
#  '115 m²',
#  '85 m²',
#  '226 m²',
#  '80 m²',
#  '60 m²',
#  '50 m²',
#  '65 m²',
#  '60 m²',
#  '55 m²',
#  '92 m²',
#  '101 m²',
#  '102 m²',
#  '107 m²',
#  '52 m²',
#  '53 m²',
#  '146 m²',
#  '133 m²',
#  '200 m²',
#  '153 m²',
#  '130 m²',
#  '315 m²']

# %% [markdown]
# Otra forma de hacerlo

# %%
lista_m2 = [i.get_text(strip=True) for i in soup.find_all('div', class_='icon-meter')]
lista_m2
# Out:
# ['69 m²',
#  '80 m²',
#  '90 m²',
#  '109 m²',
#  '150 m²',
#  '130 m²',
#  '115 m²',
#  '290 m²',
#  '89 m²',
#  '220 m²',
#  '63 m²',
#  '50 m²',
#  '123 m²',
#  '123 m²',
#  '99 m²',
#  '119 m²',
#  '97 m²',
#  '91 m²',
#  '91 m²',
#  '122 m²',
#  '135 m²',
#  '115 m²',
#  '85 m²',
#  '226 m²',
#  '80 m²',
#  '60 m²',
#  '50 m²',
#  '65 m²',
#  '60 m²',
#  '55 m²',
#  '92 m²',
#  '101 m²',
#  '102 m²',
#  '107 m²',
#  '52 m²',
#  '53 m²',
#  '146 m²',
#  '133 m²',
#  '200 m²',
#  '153 m²',
#  '130 m²',
#  '315 m²']

# %% [markdown]
# #### Las dos listas contienen el mismo número de valores. Lo comprobamos

# %%
print(len(lista_titulos))
print(len(lista_m2))
# Out:
# 42
# 42

# %% [markdown]
# #### Entonces, ya podríamos crear un DataFrame con títulos y metros cuadrados. Vamos a hacerlo

# %% [markdown]
# #### Primera forma de hacerlo

# %%
df = pd.DataFrame()
df['Títulos'] = lista_titulos
df['M2'] = lista_m2
df
# Out:
#                                               Títulos      M2
# 0       Piso en El Camp de l'Arpa del Clot, Barcelona   69 m²
# 1   Piso en Sant Pere, Santa Caterina i la Ribera,...   80 m²
# 2     Piso en calle Sepulveda, Sant Antoni, Barcelona   90 m²
# 3                        Ático en El Gòtic, Barcelona  109 m²
# 4   Piso en Sant Pere, Santa Caterina i la Ribera,...  150 m²
# 5       Piso en Sant Gervasi - La Bonanova, Barcelona  130 m²
# 6       Piso en Sant Gervasi - La Bonanova, Barcelona  115 m²
# 7          Ático en La Dreta de l'Eixample, Barcelona  290 m²
# 8                        Piso en Les Corts, Barcelona   89 m²
# 9                  Piso en Les Tres Torres, Barcelona  220 m²
# 10          Piso en La Dreta de l'Eixample, Barcelona   63 m²
# 11          Piso en La Dreta de l'Eixample, Barcelona   50 m²
# 12          Piso en Sant Gervasi - Galvany, Barcelona  123 m²
# 13          Piso en Sant Gervasi - Galvany, Barcelona  123 m²
# 14          Piso en Sant Gervasi - Galvany, Barcelona   99 m²
# 15          Piso en Sant Gervasi - Galvany, Barcelona  119 m²
# 16          Piso en Sant Gervasi - Galvany, Barcelona   97 m²
# 17          Piso en Sant Gervasi - Galvany, Barcelona   91 m²
# 18          Piso en Sant Gervasi - Galvany, Barcelona   91 m²
# 19          Piso en Sant Gervasi - Galvany, Barcelona  122 m²
# 20          Piso en Sant Gervasi - Galvany, Barcelona  135 m²
# 21  Piso en L'Antiga Esquerra de l'Eixample, Barce...  115 m²
# 22      Piso en El Camp de l'Arpa del Clot, Barcelona   85 m²
# 23  Piso en calle De Les Escoles Pies, Sant Gervas...  226 m²
# 24  Piso en plaza Mañé i Flaquer, El Putxet i el F...   80 m²
# 25           Ático en El Putxet i el Farró, Barcelona   60 m²
# 26  Ático en calle Bertran, El Putxet i el Farró, ...   50 m²
# 27           Ático en El Putxet i el Farró, Barcelona   65 m²
# 28           Ático en El Putxet i el Farró, Barcelona   60 m²
# 29           Ático en El Putxet i el Farró, Barcelona   55 m²
# 30  Piso en Sant Pere, Santa Caterina i la Ribera,...   92 m²
# 31                        Piso en El Raval, Barcelona  101 m²
# 32                     Piso en El Poblenou, Barcelona  102 m²
# 33          Piso en La Dreta de l'Eixample, Barcelona  107 m²
# 34  Piso en calle Avenir, Sant Gervasi - Galvany, ...   52 m²
# 35  Piso en Sant Pere, Santa Caterina i la Ribera,...   53 m²
# 36  Piso en Diagonal Mar i el Front Marítim del Po...  146 m²
# 37  Piso en Diagonal Mar i el Front Marítim del Po...  133 m²
# 38  Ático en Diagonal Mar i el Front Marítim del P...  200 m²
# 39  Ático en Diagonal Mar i el Front Marítim del P...  153 m²
# 40  Piso en Diagonal Mar i el Front Marítim del Po...  130 m²
# 41  Piso en Diagonal Mar i el Front Marítim del Po...  315 m²

# %% [markdown]
# #### Segunda forma

# %%
lista_df = []

for i in range(len(lista_titulos)):
    data = {'Título': lista_titulos[i],
            'Metros cuadrados': lista_m2[i]}
    lista_df.append(data)

df = pd.DataFrame(lista_df)
df
# Out:
#                                                Título Metros cuadrados
# 0       Piso en El Camp de l'Arpa del Clot, Barcelona            69 m²
# 1   Piso en Sant Pere, Santa Caterina i la Ribera,...            80 m²
# 2     Piso en calle Sepulveda, Sant Antoni, Barcelona            90 m²
# 3                        Ático en El Gòtic, Barcelona           109 m²
# 4   Piso en Sant Pere, Santa Caterina i la Ribera,...           150 m²
# 5       Piso en Sant Gervasi - La Bonanova, Barcelona           130 m²
# 6       Piso en Sant Gervasi - La Bonanova, Barcelona           115 m²
# 7          Ático en La Dreta de l'Eixample, Barcelona           290 m²
# 8                        Piso en Les Corts, Barcelona            89 m²
# 9                  Piso en Les Tres Torres, Barcelona           220 m²
# 10          Piso en La Dreta de l'Eixample, Barcelona            63 m²
# 11          Piso en La Dreta de l'Eixample, Barcelona            50 m²
# 12          Piso en Sant Gervasi - Galvany, Barcelona           123 m²
# 13          Piso en Sant Gervasi - Galvany, Barcelona           123 m²
# 14          Piso en Sant Gervasi - Galvany, Barcelona            99 m²
# 15          Piso en Sant Gervasi - Galvany, Barcelona           119 m²
# 16          Piso en Sant Gervasi - Galvany, Barcelona            97 m²
# 17          Piso en Sant Gervasi - Galvany, Barcelona            91 m²
# 18          Piso en Sant Gervasi - Galvany, Barcelona            91 m²
# 19          Piso en Sant Gervasi - Galvany, Barcelona           122 m²
# 20          Piso en Sant Gervasi - Galvany, Barcelona           135 m²
# 21  Piso en L'Antiga Esquerra de l'Eixample, Barce...           115 m²
# 22      Piso en El Camp de l'Arpa del Clot, Barcelona            85 m²
# 23  Piso en calle De Les Escoles Pies, Sant Gervas...           226 m²
# 24  Piso en plaza Mañé i Flaquer, El Putxet i el F...            80 m²
# 25           Ático en El Putxet i el Farró, Barcelona            60 m²
# 26  Ático en calle Bertran, El Putxet i el Farró, ...            50 m²
# 27           Ático en El Putxet i el Farró, Barcelona            65 m²
# 28           Ático en El Putxet i el Farró, Barcelona            60 m²
# 29           Ático en El Putxet i el Farró, Barcelona            55 m²
# 30  Piso en Sant Pere, Santa Caterina i la Ribera,...            92 m²
# 31                        Piso en El Raval, Barcelona           101 m²
# 32                     Piso en El Poblenou, Barcelona           102 m²
# 33          Piso en La Dreta de l'Eixample, Barcelona           107 m²
# 34  Piso en calle Avenir, Sant Gervasi - Galvany, ...            52 m²
# 35  Piso en Sant Pere, Santa Caterina i la Ribera,...            53 m²
# 36  Piso en Diagonal Mar i el Front Marítim del Po...           146 m²
# 37  Piso en Diagonal Mar i el Front Marítim del Po...           133 m²
# 38  Ático en Diagonal Mar i el Front Marítim del P...           200 m²
# 39  Ático en Diagonal Mar i el Front Marítim del P...           153 m²
# 40  Piso en Diagonal Mar i el Front Marítim del Po...           130 m²
# 41  Piso en Diagonal Mar i el Front Marítim del Po...           315 m²

# %% [markdown]
# ## Obtener el número de habitaciones de cada inmueble

# %%
soup.find_all('div', class_='icon-room')

len(soup.find_all('div', class_='icon-room'))
# Out:
# 42

# %% [markdown]
# ### Puede darse el caso de que un alojamiento no muestre el número de habitaciones. Las longitudes de las listas de títulos y habitaciones no encajarían...¿Cómo solventamos el problema?

# %% [markdown]
# Primera forma

# %%
contenedor = soup.find_all('div', class_='iconGroup')
for i in contenedor:
    if i.find('div', class_='icon-room'):
        print(i.find('div', class_='icon-room').get_text())
    else:
        print('No veo habitaciones')
# Out:
# 2 habs.
# 1 hab.
# 3 habs.
# 1 hab.
# 2 habs.
# 3 habs.
# 3 habs.
# 5 habs.
# 2 habs.
# 5 habs.
# 2 habs.
# 1 hab.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.
# 4 habs.
# 2 habs.
# 4 habs.
# 2 habs.
# 1 hab.
# 1 hab.
# 1 hab.
# 1 hab.
# 1 hab.
# 1 hab.
# 3 habs.
# 2 habs.
# 3 habs.
# 1 hab.
# 1 hab.
# 3 habs.
# 1 hab.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.

# %% [markdown]
# Segunda forma

# %%
contenedor = soup.find_all('div', class_='iconGroup')
for i in contenedor:
    try:
        print(i.find('div', class_='icon-room').get_text(strip=True))
    except:
        print('No hay habitaciones')
# Out:
# 2 habs.
# 1 hab.
# 3 habs.
# 1 hab.
# 2 habs.
# 3 habs.
# 3 habs.
# 5 habs.
# 2 habs.
# 5 habs.
# 2 habs.
# 1 hab.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.
# 4 habs.
# 2 habs.
# 4 habs.
# 2 habs.
# 1 hab.
# 1 hab.
# 1 hab.
# 1 hab.
# 1 hab.
# 1 hab.
# 3 habs.
# 2 habs.
# 3 habs.
# 1 hab.
# 1 hab.
# 3 habs.
# 1 hab.
# 3 habs.
# 3 habs.
# 3 habs.
# 3 habs.

# %% [markdown]
# ### Los añadimos a una lista

# %%
lista_habitaciones = []

contenedor = soup.find_all('div', class_='iconGroup')
for i in contenedor:
    try:
        lista_habitaciones.append(i.find('div', class_='icon-room').get_text(strip=True))
    except:
        lista_habitaciones.append('No hay habitaciones')

print(len(lista_habitaciones))
lista_habitaciones
# Out:
# 42
# ['2 habs.',
#  '1 hab.',
#  '3 habs.',
#  '1 hab.',
#  '2 habs.',
#  '3 habs.',
#  '3 habs.',
#  '5 habs.',
#  '2 habs.',
#  '5 habs.',
#  '2 habs.',
#  '1 hab.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '4 habs.',
#  '2 habs.',
#  '4 habs.',
#  '2 habs.',
#  '1 hab.',
#  '1 hab.',
#  '1 hab.',
#  '1 hab.',
#  '1 hab.',
#  '1 hab.',
#  '3 habs.',
#  '2 habs.',
#  '3 habs.',
#  '1 hab.',
#  '1 hab.',
#  '3 habs.',
#  '1 hab.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.']

# %% [markdown]
# ## Encontrar elementos por su selector CSS

# %%
rooms = soup.select('div.iconGroup div.icon-room span')
#Esto corresponde al selector CSS

# %%
rooms = soup.select('div.iconGroup div.icon-room span')
# for i in rooms:
#     print(type(i))
#     print(i.get_text())

rooms_series = pd.Series(rooms)
rooms_series_df = pd.DataFrame(rooms)
rooms_series.value_counts()
# Out:
# [3 habs.]    19
# [1 hab.]     12
# [2 habs.]     7
# [5 habs.]     2
# [4 habs.]     2
# dtype: int64

# %%
rooms
# Out:
# [<span class="">2 habs.</span>,
#  <span class="">1 hab.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">1 hab.</span>,
#  <span class="">2 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">5 habs.</span>,
#  <span class="">2 habs.</span>,
#  <span class="">5 habs.</span>,
#  <span class="">2 habs.</span>,
#  <span class="">1 hab.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">4 habs.</span>,
#  <span class="">2 habs.</span>,
#  <span class="">4 habs.</span>,
#  <span class="">2 habs.</span>,
#  <span class="">1 hab.</span>,
#  <span class="">1 hab.</span>,
#  <span class="">1 hab.</span>,
#  <span class="">1 hab.</span>,
#  <span class="">1 hab.</span>,
#  <span class="">1 hab.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">2 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">1 hab.</span>,
#  <span class="">1 hab.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">1 hab.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">3 habs.</span>,
#  <span class="">3 habs.</span>]

# %% [markdown]
# ## Obtener los precios (find_all + get_text)

# %%
precios = soup.find_all('span', class_='price')

for precio in precios:
    print(precio.get_text(strip=True))
# Out:
# 2.560 €
# 2.190 €
# 1.400 €
# 2.200 €
# 5.000 €
# 3.341 €
# 3.394 €
# 5.500 €
# 3.100 €
# 4.950 €
# 4.550 €
# 3.000 €
# 2.800 €
# 2.850 €
# 2.950 €
# 2.750 €
# 2.550 €
# 2.650 €
# 2.500 €
# 2.800 €
# 2.950 €
# 2.300 €
# 2.250 €
# 4.500 €
# 1.200 €
# 1.800 €
# 1.800 €
# 1.800 €
# 1.800 €
# 1.800 €
# 2.100 €
# 2.300 €
# 3.250 €
# 3.100 €
# 2.500 €
# 1.120 €
# 4.000 €
# 5.000 €
# 7.500 €
# 6.000 €
# 3.800 €
# 8.000 €

# %% [markdown]
# ### Pero, en un DataFrame, te interesa tener el precio comprendido como un número int o float, para poder jugar con él. ¿Cómo lo haríamos?

# %%
precios = soup.find_all('span', class_='price')

for precio in precios:
    print(type(precio.get_text()))
    print(precio.get_text(strip=True).replace('.',''))
    print(precio.get_text(strip=True).replace('.','').split())
    print(precio.get_text(strip=True).replace('.','').split()[0])
    print('De momento es un string, así que lo pasamos a float')
    print(float(precio.get_text(strip=True).replace('.','').split()[0]))

    print('---------------------------------------------------------------')
# Out:
# <class 'str'>
# 2560 €
# ['2560', '€']
# 2560
# De momento es un string, así que lo pasamos a float
# 2560.0
# ---------------------------------------------------------------
# <class 'str'>
# 2190 €
# ['2190', '€']
# 2190
# De momento es un string, así que lo pasamos a float
# 2190.0
# ---------------------------------------------------------------
# <class 'str'>
# 1400 €
# ['1400', '€']
# 1400
# De momento es un string, así que lo pasamos a float
# 1400.0
# ---------------------------------------------------------------
# <class 'str'>
# 2200 €
# ['2200', '€']
# 2200
# De momento es un string, así que lo pasamos a float
# 2200.0
# ---------------------------------------------------------------
# <class 'str'>
# 5000 €
# ['5000', '€']
# 5000
# De momento es un string, así que lo pasamos a float
# 5000.0
# ---------------------------------------------------------------
# <class 'str'>
# 3341 €
# ['3341', '€']
# 3341
# De momento es un string, así que lo pasamos a float
# 3341.0
# ---------------------------------------------------------------
# <class 'str'>
# 3394 €
# ['3394', '€']
# 3394
# De momento es un string, así que lo pasamos a float
# 3394.0
# ---------------------------------------------------------------
# <class 'str'>
# 5500 €
# ['5500', '€']
# 5500
# De momento es un string, así que lo pasamos a float
# 5500.0
# ---------------------------------------------------------------
# <class 'str'>
# 3100 €
# ['3100', '€']
# 3100
# De momento es un string, así que lo pasamos a float
# 3100.0
# ---------------------------------------------------------------
# <class 'str'>
# 4950 €
# ['4950', '€']
# 4950
# De momento es un string, así que lo pasamos a float
# 4950.0
# ---------------------------------------------------------------
# <class 'str'>
# 4550 €
# ['4550', '€']
# 4550
# De momento es un string, así que lo pasamos a float
# 4550.0
# ---------------------------------------------------------------
# <class 'str'>
# 3000 €
# ['3000', '€']
# 3000
# De momento es un string, así que lo pasamos a float
# 3000.0
# ---------------------------------------------------------------
# <class 'str'>
# 2800 €
# ['2800', '€']
# 2800
# De momento es un string, así que lo pasamos a float
# 2800.0
# ---------------------------------------------------------------
# <class 'str'>
# 2850 €
# ['2850', '€']
# 2850
# De momento es un string, así que lo pasamos a float
# 2850.0
# ---------------------------------------------------------------
# <class 'str'>
# 2950 €
# ['2950', '€']
# 2950
# De momento es un string, así que lo pasamos a float
# 2950.0
# ---------------------------------------------------------------
# <class 'str'>
# 2750 €
# ['2750', '€']
# 2750
# De momento es un string, así que lo pasamos a float
# 2750.0
# ---------------------------------------------------------------
# <class 'str'>
# 2550 €
# ['2550', '€']
# 2550
# De momento es un string, así que lo pasamos a float
# 2550.0
# ---------------------------------------------------------------
# <class 'str'>
# 2650 €
# ['2650', '€']
# 2650
# De momento es un string, así que lo pasamos a float
# 2650.0
# ---------------------------------------------------------------
# <class 'str'>
# 2500 €
# ['2500', '€']
# 2500
# De momento es un string, así que lo pasamos a float
# 2500.0
# ---------------------------------------------------------------
# <class 'str'>
# 2800 €
# ['2800', '€']
# 2800
# De momento es un string, así que lo pasamos a float
# 2800.0
# ---------------------------------------------------------------
# <class 'str'>
# 2950 €
# ['2950', '€']
# 2950
# De momento es un string, así que lo pasamos a float
# 2950.0
# ---------------------------------------------------------------
# <class 'str'>
# 2300 €
# ['2300', '€']
# 2300
# De momento es un string, así que lo pasamos a float
# 2300.0
# ---------------------------------------------------------------
# <class 'str'>
# 2250 €
# ['2250', '€']
# 2250
# De momento es un string, así que lo pasamos a float
# 2250.0
# ---------------------------------------------------------------
# <class 'str'>
# 4500 €
# ['4500', '€']
# 4500
# De momento es un string, así que lo pasamos a float
# 4500.0
# ---------------------------------------------------------------
# <class 'str'>
# 1200 €
# ['1200', '€']
# 1200
# De momento es un string, así que lo pasamos a float
# 1200.0
# ---------------------------------------------------------------
# <class 'str'>
# 1800 €
# ['1800', '€']
# 1800
# De momento es un string, así que lo pasamos a float
# 1800.0
# ---------------------------------------------------------------
# <class 'str'>
# 1800 €
# ['1800', '€']
# 1800
# De momento es un string, así que lo pasamos a float
# 1800.0
# ---------------------------------------------------------------
# <class 'str'>
# 1800 €
# ['1800', '€']
# 1800
# De momento es un string, así que lo pasamos a float
# 1800.0
# ---------------------------------------------------------------
# <class 'str'>
# 1800 €
# ['1800', '€']
# 1800
# De momento es un string, así que lo pasamos a float
# 1800.0
# ---------------------------------------------------------------
# <class 'str'>
# 1800 €
# ['1800', '€']
# 1800
# De momento es un string, así que lo pasamos a float
# 1800.0
# ---------------------------------------------------------------
# <class 'str'>
# 2100 €
# ['2100', '€']
# 2100
# De momento es un string, así que lo pasamos a float
# 2100.0
# ---------------------------------------------------------------
# <class 'str'>
# 2300 €
# ['2300', '€']
# 2300
# De momento es un string, así que lo pasamos a float
# 2300.0
# ---------------------------------------------------------------
# <class 'str'>
# 3250 €
# ['3250', '€']
# 3250
# De momento es un string, así que lo pasamos a float
# 3250.0
# ---------------------------------------------------------------
# <class 'str'>
# 3100 €
# ['3100', '€']
# 3100
# De momento es un string, así que lo pasamos a float
# 3100.0
# ---------------------------------------------------------------
# <class 'str'>
# 2500 €
# ['2500', '€']
# 2500
# De momento es un string, así que lo pasamos a float
# 2500.0
# ---------------------------------------------------------------
# <class 'str'>
# 1120 €
# ['1120', '€']
# 1120
# De momento es un string, así que lo pasamos a float
# 1120.0
# ---------------------------------------------------------------
# <class 'str'>
# 4000 €
# ['4000', '€']
# 4000
# De momento es un string, así que lo pasamos a float
# 4000.0
# ---------------------------------------------------------------
# <class 'str'>
# 5000 €
# ['5000', '€']
# 5000
# De momento es un string, así que lo pasamos a float
# 5000.0
# ---------------------------------------------------------------
# <class 'str'>
# 7500 €
# ['7500', '€']
# 7500
# De momento es un string, así que lo pasamos a float
# 7500.0
# ---------------------------------------------------------------
# <class 'str'>
# 6000 €
# ['6000', '€']
# 6000
# De momento es un string, así que lo pasamos a float
# 6000.0
# ---------------------------------------------------------------
# <class 'str'>
# 3800 €
# ['3800', '€']
# 3800
# De momento es un string, así que lo pasamos a float
# 3800.0
# ---------------------------------------------------------------
# <class 'str'>
# 8000 €
# ['8000', '€']
# 8000
# De momento es un string, así que lo pasamos a float
# 8000.0
# ---------------------------------------------------------------

# %% [markdown]
# #### Los añadimos a una lista

# %%
lista_precios = []

precios = soup.find_all('span', class_='price')

for precio in precios:
    lista_precios.append(float(precio.get_text(strip=True).replace('.','').split()[0]))

lista_precios
# Out:
# [2560.0,
#  2190.0,
#  1400.0,
#  2200.0,
#  5000.0,
#  3341.0,
#  3394.0,
#  5500.0,
#  3100.0,
#  4950.0,
#  4550.0,
#  3000.0,
#  2800.0,
#  2850.0,
#  2950.0,
#  2750.0,
#  2550.0,
#  2650.0,
#  2500.0,
#  2800.0,
#  2950.0,
#  2300.0,
#  2250.0,
#  4500.0,
#  1200.0,
#  1800.0,
#  1800.0,
#  1800.0,
#  1800.0,
#  1800.0,
#  2100.0,
#  2300.0,
#  3250.0,
#  3100.0,
#  2500.0,
#  1120.0,
#  4000.0,
#  5000.0,
#  7500.0,
#  6000.0,
#  3800.0,
#  8000.0]

# %% [markdown]
# ### Forma un poco más pro de hacerlo: list comprehension

# %%
lista_precios = [float(precio.get_text(strip=True).replace('.','').split()[0]) for precio in precios]

# %% [markdown]
# ### Podéis también meterlo en una serie o en un dataframe

# %%
print(len(lista_precios))
# Out:
# 42

# %% [markdown]
# ### Podéis también meterlo en una serie o en un dataframe

# %%
lista_df = []

for i in range(len(lista_titulos)):
    data = {'Título': lista_titulos[i],
            'Metros cuadrados': lista_m2[i],
            'Habitaciones': lista_habitaciones[i],
            'Precios': lista_precios[i]}
    lista_df.append(data)

df = pd.DataFrame(lista_df)
df
# Out:
#                                                Título Metros cuadrados  \
# 0       Piso en El Camp de l'Arpa del Clot, Barcelona            69 m²
# 1   Piso en Sant Pere, Santa Caterina i la Ribera,...            80 m²
# 2     Piso en calle Sepulveda, Sant Antoni, Barcelona            90 m²
# 3                        Ático en El Gòtic, Barcelona           109 m²
# 4   Piso en Sant Pere, Santa Caterina i la Ribera,...           150 m²
# 5       Piso en Sant Gervasi - La Bonanova, Barcelona           130 m²
# 6       Piso en Sant Gervasi - La Bonanova, Barcelona           115 m²
# 7          Ático en La Dreta de l'Eixample, Barcelona           290 m²
# 8                        Piso en Les Corts, Barcelona            89 m²
# 9                  Piso en Les Tres Torres, Barcelona           220 m²
# 10          Piso en La Dreta de l'Eixample, Barcelona            63 m²
# 11          Piso en La Dreta de l'Eixample, Barcelona            50 m²
# 12          Piso en Sant Gervasi - Galvany, Barcelona           123 m²
# 13          Piso en Sant Gervasi - Galvany, Barcelona           123 m²
# 14          Piso en Sant Gervasi - Galvany, Barcelona            99 m²
# 15          Piso en Sant Gervasi - Galvany, Barcelona           119 m²
# 16          Piso en Sant Gervasi - Galvany, Barcelona            97 m²
# 17          Piso en Sant Gervasi - Galvany, Barcelona            91 m²
# 18          Piso en Sant Gervasi - Galvany, Barcelona            91 m²
# 19          Piso en Sant Gervasi - Galvany, Barcelona           122 m²
# 20          Piso en Sant Gervasi - Galvany, Barcelona           135 m²
# 21  Piso en L'Antiga Esquerra de l'Eixample, Barce...           115 m²
# 22      Piso en El Camp de l'Arpa del Clot, Barcelona            85 m²
# 23  Piso en calle De Les Escoles Pies, Sant Gervas...           226 m²
# 24  Piso en plaza Mañé i Flaquer, El Putxet i el F...            80 m²
# 25           Ático en El Putxet i el Farró, Barcelona            60 m²
# 26  Ático en calle Bertran, El Putxet i el Farró, ...            50 m²
# 27           Ático en El Putxet i el Farró, Barcelona            65 m²
# 28           Ático en El Putxet i el Farró, Barcelona            60 m²
# 29           Ático en El Putxet i el Farró, Barcelona            55 m²
# 30  Piso en Sant Pere, Santa Caterina i la Ribera,...            92 m²
# 31                        Piso en El Raval, Barcelona           101 m²
# 32                     Piso en El Poblenou, Barcelona           102 m²
# 33          Piso en La Dreta de l'Eixample, Barcelona           107 m²
# 34  Piso en calle Avenir, Sant Gervasi - Galvany, ...            52 m²
# 35  Piso en Sant Pere, Santa Caterina i la Ribera,...            53 m²
# 36  Piso en Diagonal Mar i el Front Marítim del Po...           146 m²
# 37  Piso en Diagonal Mar i el Front Marítim del Po...           133 m²
# 38  Ático en Diagonal Mar i el Front Marítim del P...           200 m²
# 39  Ático en Diagonal Mar i el Front Marítim del P...           153 m²
# 40  Piso en Diagonal Mar i el Front Marítim del Po...           130 m²
# 41  Piso en Diagonal Mar i el Front Marítim del Po...           315 m²
#
#    Habitaciones  Precios
# 0       2 habs.   2560.0
# 1        1 hab.   2190.0
# 2       3 habs.   1400.0
# 3        1 hab.   2200.0
# 4       2 habs.   5000.0
# 5       3 habs.   3341.0
# 6       3 habs.   3394.0
# 7       5 habs.   5500.0
# 8       2 habs.   3100.0
# 9       5 habs.   4950.0
# 10      2 habs.   4550.0
# 11       1 hab.   3000.0
# 12      3 habs.   2800.0
# 13      3 habs.   2850.0
# 14      3 habs.   2950.0
# 15      3 habs.   2750.0
# 16      3 habs.   2550.0
# 17      3 habs.   2650.0
# 18      3 habs.   2500.0
# 19      3 habs.   2800.0
# 20      3 habs.   2950.0
# 21      4 habs.   2300.0
# 22      2 habs.   2250.0
# 23      4 habs.   4500.0
# 24      2 habs.   1200.0
# 25       1 hab.   1800.0
# 26       1 hab.   1800.0
# 27       1 hab.   1800.0
# 28       1 hab.   1800.0
# 29       1 hab.   1800.0
# 30       1 hab.   2100.0
# 31      3 habs.   2300.0
# 32      2 habs.   3250.0
# 33      3 habs.   3100.0
# 34       1 hab.   2500.0
# 35       1 hab.   1120.0
# 36      3 habs.   4000.0
# 37       1 hab.   5000.0
# 38      3 habs.   7500.0
# 39      3 habs.   6000.0
# 40      3 habs.   3800.0
# 41      3 habs.   8000.0

# %%
df[df['Precios']>2500]
# Out:
#                                                Título Metros cuadrados  \
# 0       Piso en El Camp de l'Arpa del Clot, Barcelona            69 m²
# 4   Piso en Sant Pere, Santa Caterina i la Ribera,...           150 m²
# 5       Piso en Sant Gervasi - La Bonanova, Barcelona           130 m²
# 6       Piso en Sant Gervasi - La Bonanova, Barcelona           102 m²
# 7           Piso en La Dreta de l'Eixample, Barcelona           221 m²
# 12          Piso en La Dreta de l'Eixample, Barcelona            63 m²
# 13          Piso en La Dreta de l'Eixample, Barcelona            50 m²
# 14          Piso en Sant Gervasi - Galvany, Barcelona           123 m²
# 15          Piso en Sant Gervasi - Galvany, Barcelona           123 m²
# 16          Piso en Sant Gervasi - Galvany, Barcelona            91 m²
# 18          Piso en Sant Gervasi - Galvany, Barcelona           122 m²
# 19          Piso en Sant Gervasi - Galvany, Barcelona           119 m²
# 20          Piso en Sant Gervasi - Galvany, Barcelona            99 m²
# 21          Piso en Sant Gervasi - Galvany, Barcelona            97 m²
# 22          Piso en Sant Gervasi - Galvany, Barcelona           135 m²
# 27  Piso en calle De Les Escoles Pies, Sant Gervas...           226 m²
# 28          Piso en La Dreta de l'Eixample, Barcelona           258 m²
# 29  Piso en L'Antiga Esquerra de l'Eixample, Barce...           102 m²
# 32          Piso en La Dreta de l'Eixample, Barcelona           146 m²
# 33  Piso en Diagonal Mar i el Front Marítim del Po...           146 m²
# 34  Ático en Diagonal Mar i el Front Marítim del P...           200 m²
# 35  Ático en paseo De Garcia Fària, Diagonal Mar i...           200 m²
# 36  Ático en Diagonal Mar i el Front Marítim del P...           210 m²
# 37  Piso en Diagonal Mar i el Front Marítim del Po...           130 m²
# 38  Piso en Diagonal Mar i el Front Marítim del Po...           315 m²
# 39  Piso en Diagonal Mar i el Front Marítim del Po...           133 m²
# 40  Ático en Diagonal Mar i el Front Marítim del P...           153 m²
# 41  Ático en Diagonal Mar i el Front Marítim del P...           157 m²
#
#    Habitaciones  Precios
# 0       2 habs.   2560.0
# 4       2 habs.   5000.0
# 5       3 habs.   3341.0
# 6       2 habs.   2763.0
# 7       3 habs.   7500.0
# 12      2 habs.   4550.0
# 13       1 hab.   3000.0
# 14      3 habs.   2800.0
# 15      3 habs.   2850.0
# 16      3 habs.   2650.0
# 18      3 habs.   2800.0
# 19      3 habs.   2750.0
# 20      3 habs.   2950.0
# 21      3 habs.   2550.0
# 22      3 habs.   2950.0
# 27      4 habs.   4500.0
# 28      5 habs.  13000.0
# 29      3 habs.   2950.0
# 32      3 habs.   4490.0
# 33      3 habs.   4000.0
# 34      3 habs.   7500.0
# 35      3 habs.  10000.0
# 36      3 habs.   7000.0
# 37      3 habs.   3800.0
# 38      3 habs.   8000.0
# 39       1 hab.   5000.0
# 40      3 habs.   6000.0
# 41      3 habs.   6000.0

# %% [markdown]
# ### Conseguir los teléfonos de las inmobiliarias

# %%
lista_telefonos = []
telefonos = soup.find_all('div', class_='icon-phone-2')

for i in telefonos:
    print(i.span.get_text(strip=True))
    lista_telefonos.append(i.span.get_text(strip=True))

len(lista_telefonos)
# Out:
# 93 617 88 45
# 93 617 88 45
# Llamar
# 93 617 51 22
# 93 617 92 14
# 93 617 84 87
# 93 617 60 98
# 93 617 24 95
# 93 617 50 82
# 93 617 03 36
# 93 617 62 41
# 93 617 60 20
# 93 617 40 47
# 93 617 80 46
# 93 617 97 93
# 93 617 97 93
# 93 617 97 93
# 93 617 97 93
# 93 617 97 93
# 93 617 97 93
# 93 617 97 93
# 93 617 97 93
# 93 617 97 93
# 93 617 54 59
# 93 617 54 59
# 93 617 49 64
# 93 617 76 25
# 93 617 86 09
# 93 617 99 31
# 93 617 76 25
# 93 617 99 14
# 93 617 35 81
# 93 617 97 37
# 93 617 30 40
# 93 617 30 40
# 93 617 30 40
# 93 617 30 40
# 93 617 30 40
# 93 617 30 40
# 93 617 30 40
# 93 617 30 40
# 93 617 30 40
# 42

# %% [markdown]
# ## Obtener URLs de alojamientos

# %%
url_principal = 'https://www.yaencontre.com'

lista_pisos = []

pisos = soup.find_all('h3', class_='title')
for piso in pisos:
    lista_pisos.append(url_principal + piso.a['href'])

# %% [markdown]
# Entramos en cada url

# %%
for url in lista_pisos:
    response = requests.get(url)
    soup_piso = bs(response.content, 'lxml')
    print(response)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %% [markdown]
# #### De cada alojamiento obtener:
# * Ubicación
# * Si tiene o no tiene Aire acondicionado
# * Si está amueblado o no.

# %% [markdown]
# ### Ubicación

# %%
for url in lista_pisos:
    response = requests.get(url)
    soup_piso = bs(response.content, 'lxml')
    
    try:
        print(soup_piso.find('div', class_='details-address').get_text())
    except:
        print('No sale ubicación')
# Out:
# El Camp de l'Arpa del Clot, Sant Martí, Barcelona
# Sant Pere, Santa Caterina i la Ribera, Ciutat Vella, Barcelona
# Sant Antoni, Eixample, Barcelona
# El Gòtic, Ciutat Vella, Barcelona
# Sant Pere, Santa Caterina i la Ribera, Ciutat Vella, Barcelona
# Sant Gervasi - La Bonanova, Sarrià - Sant Gervasi, Barcelona
# Sant Gervasi - La Bonanova, Sarrià - Sant Gervasi, Barcelona
# La Dreta de l'Eixample, Eixample, Barcelona
# Les Corts, Les Corts, Barcelona
# Les Tres Torres, Sarrià - Sant Gervasi, Barcelona
# No sale ubicación
# La Dreta de l'Eixample, Eixample, Barcelona
# Sant Gervasi - Galvany, Sarrià - Sant Gervasi, Barcelona
# No sale ubicación
# No sale ubicación
# No sale ubicación
# No sale ubicación
# No sale ubicación
# No sale ubicación
# No sale ubicación
# No sale ubicación
# No sale ubicación
# El Camp de l'Arpa del Clot, Sant Martí, Barcelona
# Sant Gervasi - Galvany, Sarrià - Sant Gervasi, Barcelona
# El Putxet i el Farró, Sarrià - Sant Gervasi, Barcelona
# No sale ubicación
# El Putxet i el Farró, Sarrià - Sant Gervasi, Barcelona
# El Putxet i el Farró, Sarrià - Sant Gervasi, Barcelona
# No sale ubicación
# No sale ubicación
# No sale ubicación
# No sale ubicación
# No sale ubicación
# No sale ubicación
# No sale ubicación
# No sale ubicación
# No sale ubicación
# Diagonal Mar i el Front Marítim del Poblenou, Sant Martí, Barcelona
# Diagonal Mar i el Front Marítim del Poblenou, Sant Martí, Barcelona
# No sale ubicación
# Diagonal Mar i el Front Marítim del Poblenou, Sant Martí, Barcelona
# Diagonal Mar i el Front Marítim del Poblenou, Sant Martí, Barcelona

# %% [markdown]
# ### Aire acondicionado

# %%
for url in lista_pisos:
    response = requests.get(url)
    soup_piso = bs(response.content, 'lxml')
    
    try:
        if soup_piso.find('div', class_='icon-airConditioning').get_text(strip=True) == '':
            print('Sí tiene aire acondicionado')
        else:
            print('No tiene')
    except:
        print('No tiene')
# Out:
# No tiene
# No tiene
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# No tiene
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# No tiene
# No tiene
# No tiene
# No tiene
# No tiene
# No tiene
# No tiene
# No tiene
# No tiene
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# No tiene
# No tiene
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# No tiene
# No tiene
# No tiene
# No tiene
# No tiene
# No tiene
# No tiene
# No tiene
# No tiene
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# No tiene
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado

# %% [markdown]
# ### Amueblado

# %%
for url in lista_pisos:
    response = requests.get(url)
    soup_piso = bs(response.content, 'lxml')    
    
    try:
        if soup_piso.find('div', class_='icon-furnished').get_text(strip=True) == '':
            print('Sí')
        else:
            print('No')
    except:
        print('No')
# Out:
# Sí
# Sí
# No
# No
# Sí
# No
# No
# No
# Sí
# No
# No
# Sí
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Sí
# No
# Sí
# No
# Sí
# Sí
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Sí
# Sí
# No
# Sí
# Sí

# %% [markdown]
# ---

# %% [markdown]
# ## Ahora vamos a scrapear todos los pisos, yendo de página en página

# %%
url = "https://www.yaencontre.com/alquiler/pisos/barcelona"

for pagina in range(1,20):
    #Contador de páginas
    print('Página '+str(pagina))
    response = requests.get(url+'/pag-'+str(pagina))
    print(url+'/pag-'+str(pagina))
    soup_pagina = bs(response.content, 'lxml')

    if pagina == 5:
        break
    
    for i in soup_pagina.find_all('div', class_='content'):
        print(i.h3.a['href'])
# Out:
# Página 1
# https://www.yaencontre.com/alquiler/pisos/barcelona/pag-1
# Página 2
# https://www.yaencontre.com/alquiler/pisos/barcelona/pag-2
# Página 3
# https://www.yaencontre.com/alquiler/pisos/barcelona/pag-3
# Página 4
# https://www.yaencontre.com/alquiler/pisos/barcelona/pag-4
# Página 5
# https://www.yaencontre.com/alquiler/pisos/barcelona/pag-5

# %%
lista_urls = []

for pagina in range(1,20):
    try:
        print('Página '+str(pagina))
        response = requests.get(url+'/pag-'+str(pagina))
        soup_pagina = bs(response.content, 'lxml')

        for i in soup_pagina.find_all('div', class_='content'):
            lista_urls.append('https://www.yaencontre.com'+str(i.h3.a['href']))

    except:
        break
# Out:
# Página 1
# Página 2
# Página 3
# Página 4
# Página 5
# Página 6
# Página 7
# Página 8
# Página 9
# Página 10
# Página 11
# Página 12
# Página 13
# Página 14
# Página 15
# Página 16
# Página 17
# Página 18
# Página 19

# %%
lista_urls
# Out:
# []

# %%
contador = 1

lista_titulos = []
lista_ubicaciones = []
lista_precios = []
lista_precios_antes = []
lista_habitaciones = []
lista_bathrooms = []
lista_m2 = [] 
lista_aire = [] #aire acondicionado
lista_amueblado =[] #si lo está o no
lista_armarios_empotrados = [] #sí o no
lista_ascensor = []
lista_balcon = []
lista_calefaccion =[]
lista_terraza = []
lista_caracteristicas = []
lista_descripcion = []

for url_alquiler in lista_urls:
    response = requests.get(url_alquiler)
    soup_url = bs(response.content, 'lxml')

    try:
        lista_titulos.append(soup_url.find('h1', class_='details-title').get_text(strip=True))
    except:
        lista_titulos.append('No veo el título')

    try:
        lista_ubicaciones.append(soup_url.find('div',class_= 'details-address').get_text(strip=True))
    except:
        lista_ubicaciones.append('No encuentro la ubicación')

    try:
        lista_precios.append(soup_url.find('span',class_='price').get_text(strip=True))
    except:
        lista_precios.append('No veo el precio')

    try:
        lista_precios_antes.append(soup_url.find('span', class_='icon-text previousPriceText').get_text(strip=True))
    except:
        try:
            lista_precios_antes.append(soup_url.find('span',class_='price').get_text(strip=True))
        except:
            lista_precios_antes.append('No veo el precio')
    
    try:
        lista_habitaciones.append(soup_url.find('div',class_='icon-room').get_text(strip=True))
    except:
        lista_habitaciones.append('No veo las habitaciones')

    try:
        lista_bathrooms.append(soup_url.find('div', class_='icon-bath').get_text(strip=True))
    except:
        lista_bathrooms.append('No encuentro los baños')
    
    try:
        lista_m2.append(soup_url.find('div', class_='icon-meter').get_text(strip=True))
    except:
        lista_m2.append('No encuentro los baños')
    
    try:
        if soup_url.find('div', class_='icon-airConditioning').get_text(strip=True) == '':
            lista_aire.append('Sí')
        else:
            lista_aire.append('No')
    except:
        lista_aire.append('No')
    
    try:
        if soup_url.find('div', class_='icon-furnished').get_text(strip=True) == '':
            lista_amueblado.append('Sí')
        else:
            lista_amueblado.append('No')
    except:
        lista_amueblado.append('No')

    try:
        if soup_url.find('div', class_='icon-builtInWardrobes').get_text(strip=True) == '':
            lista_armarios_empotrados.append('Sí')
        else:
            lista_armarios_empotrados.append('No')
    except:
        lista_armarios_empotrados.append('No')
    
    try:
        if soup_url.find('div', class_='icon-lift').get_text(strip=True) == '':
            lista_ascensor.append('Sí')
        else:
            lista_ascensor.append('No')
    except:
        lista_ascensor.append('No')

    try:
        if soup_url.find('div', class_='icon-balcony').get_text(strip=True) == '':
            lista_balcon.append('Sí')
        else:
            lista_balcon.append('No')
    except:
        lista_balcon.append('No')

    try:
        if soup_url.find('div', class_='icon-centralHeating').get_text(strip=True) == '':
            lista_calefaccion.append('Sí')
        else:
            lista_calefaccion.append('No')
    except:
        lista_calefaccion.append('No')

    try:
        if soup_url.find('div', class_='icon-terrace').get_text(strip=True) == '':
            lista_terraza.append('Sí')
        else:
            lista_terraza.append('No')
    except:
        lista_terraza.append('No')

    try:
        lista_caracteristicas.append([i.get_text(strip=True) for i in soup_url.find_all('li', class_='feature')])
    except:
        lista_caracteristicas.append('No veo más características')

    try:
        lista_descripcion.append(soup_url.find('div', class_='description').get_text(strip=True))
    except:
        lista_descripcion.append('No veo la descripción')

    print('Url: '+str(contador))

    contador +=1

# %% [markdown]
# ### Creamos el DataFrame

# %%
lista_df = []

for i in range(len(lista_precios)):
    data = {'Url': lista_urls[i],
            'Título': lista_titulos[i],
            'Ubicación': lista_ubicaciones[i],
            'Precio': lista_precios[i],
            'Precio Antes': lista_precios_antes[i],
            'Habitaciones': lista_habitaciones[i],
            'Baños':lista_bathrooms[i],
            'Metros cuadrados': lista_m2[i],
            'Aire acondicionado': lista_aire[i],
            'Amueblado': lista_amueblado[i],
            'Armarios empotrados': lista_armarios_empotrados[i],
            'Ascensor': lista_ascensor[i],
            'Balcón': lista_balcon[i],
            'Calefacción': lista_calefaccion[i],
            'Terraza': lista_terraza[i],
            'Características': lista_caracteristicas[i],
            'Descripción': lista_descripcion[i]
            }
    
    lista_df.append(data)

df = pd.DataFrame(lista_df)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
