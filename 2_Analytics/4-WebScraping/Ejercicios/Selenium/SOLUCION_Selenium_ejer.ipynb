# %% [markdown]
# # Web Scraping con Selenium
#
# ##### Ejercicio en grupos

# %% [markdown]
# ##### En parejas, vamos a buscar las cuatro primeras películas en cartelera. De ellas vamos a extraer la siguiente información:
# - ##### Fecha de estreno
# - ##### URL
# - ##### Datos principales, como hemos hecho al principio
# - ##### Nota media
# - ##### Cantidad de votos
# - ##### Críticas profesionales buenas, regulares y malas
# - ##### Cinco primeras críticas

# %%
#%pip install selenium

# %%
#%pip install webdriver-manager

# %% [markdown]
# Importación de las librerías

# %%
#Para la manipulación de datos
import pandas as pd

#Servicio y driver de Chrome de Selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

#Las opciones que vamos a tener para buscar elementos
from selenium.webdriver.common.by import By

#Para esperar a que carguen las páginas
import time

# %% [markdown]
# Creamos el driver para controlar el navegador

# %%
service=Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# %% [markdown]
# RECUERDA:
#
# ##### Beginner Selenium Cheatsheet:
# Sacar un elemento:
# - element = driver.find_element(by, value)
#
# Sacar varios elementos:
# - element = driver.find_elements(by, value)
#
# Sacar atributos:
# - attribute = element.--el atributo--
# - attribute = element.get_attribute(--el atributo--)
#
# Hacer click:
# - element.click()
#
# Teclear:
# - element.send_keys()
#
# Gestión de pestañas:
# - driver.switch_to.window(driver.window_handles[-1])
# - driver.get(url)
# - driver.close()

# %% [markdown]
# Accedemos a la página principal

# %%
driver.get("https://www.filmaffinity.com/")

# %% [markdown]
# Aceptamos el pop-up de ser necesario

# %%
#Seleccionamos el botón
accept = driver.find_element(by=By.CLASS_NAME, value='css-v43ltw')

#Hacemos click
accept.click()

# %% [markdown]
# Hacemos una función que devuelva en un diccionario todos los datos de las películas, salvo la fecha de estreno y la url
#
# Parámetros: url y fecha de estreno
# Salida: Diccionario con todos los datos

# %%
def get_datos_pelicula(driver, url, estreno):

    #Creamos el diccionario
    movie_dict = dict()

    #Añadimos al diccionario los parámetros que nos vienen dados
    movie_dict['fecha_estreno'] = estreno
    movie_dict['url'] = url

    #Accedemos a la url
    driver.get(url)
    time.sleep(2)

    #Sacamos los datos principales
    principales = driver.find_element(by=By.CLASS_NAME, value='movie-info')

    dts = principales.find_elements(by=By.TAG_NAME, value='dt')
    dds = principales.find_elements(by=By.TAG_NAME, value='dd')

    i = 0
    while i < len(dts):
        movie_dict[dts[i].text] = dds[i].text
        i += 1

    #Sacamos la nota media
    nota_media = driver.find_elements(by=By.ID, value="movie-rat-avg")
    if len(nota_media) > 0:
        movie_dict['nota_media'] = nota_media[0].text

    #Sacamos la cantidad de votos
    cantidad_votos = driver.find_elements(by=By.CSS_SELECTOR, value="#movie-count-rat span")
    if len(cantidad_votos) > 0:
        movie_dict['cantidad_votos'] = cantidad_votos[0].text

    #Críticas profesionales
    n_criticas = driver.find_elements(by=By.CSS_SELECTOR, value='#right-column > a > div > div.body > div > div.legend-wrapper .leg')

    if len(n_criticas) > 0:
        #Criticas profesionales positivas
        positivas = n_criticas[0].text
        movie_dict['positivas'] = positivas

        #Criticas profesionales regulares
        regulares = n_criticas[1].text
        movie_dict['regulares'] = regulares

        #Criticas profesionales negativas
        negativas = n_criticas[2].text
        movie_dict['negativas'] = negativas

    #Cinco primeras criticas
    criticas = driver.find_elements(by=By.CSS_SELECTOR, value="ul#pro-reviews li")

    i = 0

    while i < 5 and i < len(criticas):
        critica = criticas[i].find_element(by=By.CSS_SELECTOR, value='div div').text
        movie_dict['critica_'+str(i)] = critica

        i += 1


    return movie_dict

# %% [markdown]
# Probamos la función que hemos hecho. Aquí tienes un enlace de prueba: https://www.filmaffinity.com/es/film599984.html

# %%
prueba = get_datos_pelicula(driver, "https://www.filmaffinity.com/es/film618375.html", "fecha")
prueba
# Out:
# {'fecha_estreno': 'fecha',
#  'url': 'https://www.filmaffinity.com/es/film618375.html',
#  'Título original': 'Oblivion',
#  'Año': '2013',
#  'Duración': '126 min.',
#  'País': ' Estados Unidos',
#  'Dirección': 'Joseph Kosinski',
#  'Guion': 'Joseph Kosinski, Michael Arndt, Karl Gajdusek. Cómic: Joseph Kosinski, Arvid Nelson',
#  'Reparto': 'Tom Cruise\nAndrea Riseborough\nOlga Kurylenko\nMorgan Freeman\nNikolaj Coster-Waldau\nZoe Bell',
#  'Música': 'Anthony Gonzalez, M83, Joseph Trapanese',
#  'Fotografía': 'Claudio Miranda',
#  'Compañías': 'Universal Pictures, Chernin Entertainment, Relativity Studios, Monolith Pictures, Radical Studios',
#  'Género': 'Ciencia ficción. Intriga | Futuro postapocalíptico. Distopía. Cómic',
#  'Sinopsis': 'Año 2073. Hace más de 60 años la Tierra fue atacada; se ganó la guerra, pero la mitad del planeta quedó destruido, y todos los seres humanos fueron evacuados. Jack Harper (Tom Cruise), un antiguo marine, es uno de los últimos hombres que la habitan. Es un ingeniero de Drones que participa en una operación para extraer los recursos vitales del planeta. Su misión consiste en patrullar diariamente los cielos. Un día, rescata a una desconocida de una nave espacial y, entonces, se ve obligado a replantearse sus convicciones más profundas. (FILMAFFINITY)',
#  'nota_media': '5,8',
#  'cantidad_votos': '46.979',
#  'positivas': '5',
#  'regulares': '13',
#  'negativas': '5',
#  'critica_0': '"Un nuevo ejercicio de artillería pesada para arrasar taquillas, sin renunciar a una cierta mirada adulta y a una cierta ambición creativa. (...) La marca Cruise da lo que uno espera -es entretenimiento sólido y generoso-, pero ni un aliciente más" \nJordi Costa: Diario El País',
#  'critica_1': '"Un pastiche cuya única virtud corre a cuenta del departamento de los efectos visuales. (...) una historia incapaz de tomar la suficiente distancia con lo narrado para resultar inteligente" \nLuis Martínez: Diario El Mundo',
#  'critica_2': '"No se queda sólo en una peripecia llena de aventura, acción y entretenido espejismo (...), sino que engarza entre todo ello una idea, una fábula, entre la realidad y su manipulación (...) Puntuación: ★★★ (sobre 5)" \nOti Rodríguez Marchante: Diario ABC',
#  'critica_3': '"El «patchwork» de diseño que combina ideas visuales de «2001» y «Alien» es fantástico, espectacular (...) También es moroso, tedioso, lacónico. (...) a la película le cuesta aceptar su dimensión existencialista: su mensaje es demasiado benévolo" \nSergi Sánchez: Diario La Razón',
#  'critica_4': '"Kosinski se limita a intentar vendernos una historia trascendente que acaba siendo confusa y sin atisbo de emotividad. No es una película despreciable, pero su exceso de ambición ha podido con ella. (...) Puntuación: ★★ (sobre 4)" \nJordi Batlle Caminal: Diario La Vanguardia'}

# %% [markdown]
# Entramos en el link de las películas en cartelera

# %%
driver.find_elements(By.PARTIAL_LINK_TEXT, value="Películas en cartelera")[0].click()

# %% [markdown]
# Sacamos todas las películas y llamamos a la función con cada película

# %%
#Creamos una lista vacia
links = []

#Sacamos el elemento raíz
filas = driver.find_elements(by=By.CSS_SELECTOR, value='#wrapper-cat div.row')

for fila in filas:

    peliculas = fila.find_elements(by=By.CLASS_NAME, value='movie-poster')

    for pelicula in peliculas:
        url = pelicula.find_element(By.TAG_NAME, value='a').get_attribute('href')
        estreno = pelicula.find_element(By.CSS_SELECTOR, value='a div.release-text').text.replace('\n', ' ')

        link_pelicula = {
            'url': url,
            'estreno': estreno
        }

        links.append(link_pelicula)

# %% [markdown]
# Ahora usamos los links para llamar a la funcion y sacar los datos

# %%
#Reservamos la variable para el dataframe
df = None

for link in links:
    datos_pelicula = get_datos_pelicula(driver, link['url'], link['estreno'])

    #Si no está creado lo creamos
    if df is None:
        df = pd.DataFrame(columns=datos_pelicula.keys())

    #Metemos los datos de la película
    #df = df.append(datos_pelicula, ignore_index=True)
    df = pd.concat([df, pd.DataFrame(datos_pelicula, index = [0])], ignore_index=True)
    print(f"Añadida {datos_pelicula['Título original']}")
# Out:
# Añadida Wonkaaka
# Añadida Robot Dreams
# Añadida Anatomie d'une chute
# Añadida The Piper
# Añadida Maestro
# Añadida Momonsters: La película
# Añadida La terra delle donne
# Añadida Chicken Run: Dawn of the Nugget
# Añadida Brother
# Añadida NCT NATION: To The World in Cinemas
# Añadida Ocho apellidos marroquísaka
# Añadida La Navidad en sus manos
# Añadida Silent Night
# Añadida Digimon Adventure 02: The Beginning
# Añadida Chlopiaka
# Añadida She Came to Me
# Añadida Sobre todo de noche
# Añadida Una noche con Adelaaka
# Añadida Callas - Paris, 1958aka
# Añadida Los delincuentes
# Añadida Cristina García Rodero: La mirada oculta
# Añadida Folk og røvere i Kardemomme byaka
# Añadida La mesita del comedor
# Añadida Quest
# Añadida Napoleon
# Añadida Wish
# Añadida Teresa
# Añadida El amor de Andrea
# Añadida Scrapper
# Añadida The Hunger Games: The Ballad of Songbirds and Snakes
# Añadida Thanksgiving
# Añadida La ermita
# Añadida Que nadie duerma
# Añadida The Old Oak
# Añadida The Marvels
# Añadida El favor
# Añadida Un amor
# Añadida Eiga Doraemon: Nobita no shin kyôryûaka
# Añadida El mestre que va prometre el maraka
# Añadida Saben aquell
# Añadida Five Nights at Freddy's
# Añadida Past Lives
# Añadida Trolls Band Togetheraka
# Añadida Alimañas
# Añadida Hypnotic
# Añadida Kimitachi wa dô ikiru kaaka
# Añadida La contadora de películasaka
# 44  Ben Affleck\nAlice Braga\nWilliam Fichtner\nHa...  ...        4,7
# 45                                          Animación  ...        7,2
# 46  Bérénice Bejo\nAntonio de la Torre\nDaniel Brü...  ...        6,3
# 47                                         C. Tangana  ...        7,0
# 48  Leonardo DiCaprio\nRobert De Niro\nLily Gladst...  ...        7,2
# 49  Kristen Bell\nJames Marsden\nFinn Lee-Epp\nLux...  ...        5,1
# 50  Jim Caviezel\nBill Camp\nMira Sorvino\nKurt Fu...  ...        6,6
# 51  Leslie Odom Jr.\nAnn Dowd\nJennifer Nettles\nN...  ...        4,5
# 52  Daniela Shiman Yang\nXinyi Ye\nElla Qiu\nPablo...  ...        6,8
# 53  Tobin Bell\nMichael Beach\nSynnøve Macody Lund...  ...        6,0
# 54  Lou de Laâge\nNiels Schneider\nValerie Lemerci...  ...        6,5
#
#    cantidad_votos positivas regulares negativas  \
# 0           1.364        34         7         1
# 1             830        21         1         1
# 2           2.001        36         4         0
# 3              50       NaN       NaN       NaN
# 4              97        28         8         5
# 5             NaN       NaN       NaN       NaN
# 6             NaN       NaN       NaN       NaN
# 7             NaN         5         5         3
# 8             NaN       NaN       NaN       NaN
# 9             NaN       NaN       NaN       NaN
# 10            785         1         1         4
# 11            140         2         3         0
# 12            288        10         8         9
# 13            116       NaN       NaN       NaN
# 14            160         7         2         3
# 15             65         7         5        14
# 16            235        13         0         0
# 17             72       NaN       NaN       NaN
# 18            NaN       NaN       NaN       NaN
# 19            117        32         4         0
# 20             22       NaN       NaN       NaN
# 21            NaN       NaN       NaN       NaN
# 22            195         7         0         0
# 23             22       NaN       NaN       NaN
# 24          7.435        20        24         8
# 25            856         9        15        11
# 26            394         3         3         0
# 27            185         7         0         0
# 28            214        19         5         1
# 29          2.428        16        13        12
# 30            945        19         6         4
# 31            291       NaN       NaN       NaN
# 32            424         6         2         0
# 33            784        12         9         6
# 34          2.030        18        18        19
# 35            221       NaN       NaN       NaN
# 36          1.772         6         8         2
# 37             59       NaN       NaN       NaN
# 38          1.072         3         4         0
# 39          1.630         7         0         0
# 40          1.817         6        15        19
# 41          4.141        37         1         0
# 42            434        10         4         3
# 43            368       NaN       NaN       NaN
# 44            714         7        13        17
# 45          3.806        31         3         0
# 46            342         6         3         0
# 47            603       NaN       NaN       NaN
# 48         11.014        56         6         0
# 49            433        11         6         4
# 50          2.784         6         8        17
# 51          1.813         4        11        24
# 52            915         2         4         0
# 53          2.766        12        14         6
# 54          3.074        20         5         2
#
#                                             critica_0  \
# 0   "Es la merienda perfecta (...) Sin llegar a la...
# 1   "Muda, tierna, sabia, adulta e infantil. Dicho...
# 2   "La directora disecciona de forma bastante aso...
# 3                                                 NaN
# 4   "Cooper luce irreconocible. Y su actuación, ju...
# 5                                                 NaN
# 6   "Película contradictoria y sugerente a la vez....
# 7   "Aunque la aventura mantiene nuestra atención,...
# 8                                                 NaN
# 9                                                 NaN
# 10  "Ahogada en buena medida por su evidente obses...
# 11  "Os imaginéis lo que os imaginéis que puede se...
# 12  "No hay ni un instante de paz, ni para sus per...
# 13  "Lo más destacado (...) es la calidad de anima...
# 14  "Mediante técnicas de animación y la utilizaci...
# 15  "Una floja comedia romántica (...) juguetea co...
# 16  "Valiente relato (...) Las actuaciones, la ban...
# 17  "No es una película para disfrutar, aunque hay...
# 18                                                NaN
# 19  "Sosegada y lúdica película (...) Moreno la ha...
# 20  "Una estimulante sorpresa camuflada bajo la ap...
# 21                                                NaN
# 22  "Casas confecciona la película de terror del a...
# 23  "Una propuesta austera, visualmente contenida,...
# 24  "Scott recrea -o inventa- de forma espectacula...
# 25  "Magnífico auto-homenaje el de Disney para su ...
# 26  "Intensa (...) Entre imágenes alegóricas, Orti...
# 27  "Martín Cuenca afronta el abandono emocional c...
# 28  "Rodada con ternura y empatía hacia los perded...
# 29  "La distopía es no volver a ver a Jennifer Law...
# 30  "Eli Roth nos regala con 'Black Friday' un sla...
# 31  "Se va desinflando con el paso del metraje e i...
# 32  "El absurdo cotidiano de Juan José Millás le s...
# 33  "Loach acierta una vez más a recomponer cada p...
# 34  "La última entrega de la casa Marvel se salda ...
# 35  "Existe, por suerte, una categoría de comedias...
# 36  "La directora reconfigura el ideario de la rep...
# 37  "La mejor versión de la historia creada por Fu...
# 38  "Pese a ser una película demasiado melosa y co...
# 39  "Cine creíble, triste y bonito. David Trueba n...
# 40  "Es una interesante pieza de terror a lo Steph...
# 41  "La directora debutante se corona con una prec...
# 42  "Es imposible no rendirse a la locura de 'Trol...
# 43  "Una comedia efectiva, resultona, pero que arr...
# 44  "El problema de “Hypnotic” no es ni su incompr...
# 45  "Miyazaki se despide con un milagro al margen ...
# 46  "De todo un poco. Resultado, a medias. No me o...
# 47  "C. Tangana se desnuda en el espectacular docu...
# 48  "Un torrencial Martin Scorsese ajusta cuentas ...
# 49  "Aunque no es tan subversiva como su predeceso...
# 50  "La elegancia visual de Monteverde es manosead...
# 51  "El prólogo (...) posee un atractivo tono docu...
# 52  "Un drama tintado de comedia tan emocionante y...
# 53  "Esta décima entrega es como un nuevo principi...
# 54  "Demuestra que el veterano autor aún tiene muc...
#
#                                             critica_1  \
# 0   "Deliciosa, divertida y exagerada fábula con u...
# 1   "Una propuesta tan clásica como revolucionaria...
# 2   "Una pieza estudiadísima de cine procedimental...
# 3                                                 NaN
# 4   "Magistral biopic (...) un film que consolida ...
# 5                                                 NaN
# 6                                                 NaN
# 7   "Un delicioso regreso a las raíces de stop-mot...
# 8                                                 NaN
# 9                                                 NaN
# 10  "¿Dónde está la gracia? (...) Resulta imposibl...
# 11  "Es una película creada para que la audiencia ...
# 12  "Un relato absolutamente gestual (...) De este...
# 13  "Pese al admirable esfuerzo por ofrecer algo d...
# 14  "Hay que entrar en este filme como el que entr...
# 15  "Fallida comedia (...) nunca sabe encontrar su...
# 16  "Sorprende por su calculada, dura y enigmática...
# 17  "El debut de Hugo Ruiz es una película de veng...
# 18                                                NaN
# 19  "Sorprendente, extraordinaria (...) Puntuación...
# 20                                                NaN
# 21                                                NaN
# 22  "Es una película sencilla (...), pero muy efic...
# 23                                                NaN
# 24  "Deslumbra el poderío visual del director (......
# 25  "Disney celebra 100 años con una de sus pelícu...
# 26  "Estamos ante una experiencia visual fascinant...
# 27  "Preciso y detallista guion (...) una película...
# 28  "Alegra el ánimo. (...) Elegante, sobria fábul...
# 29  "Lo que no proporciona es una historia sustanc...
# 30  "Con una primera secuencia brillante y una pre...
# 31  "Hay varias cosas (...) que confirman a Pereda...
# 32  "Sin duda, la película más agresivamente única...
# 33  "Loach vuelve a demostrar a sus 86 años que su...
# 34  "Es divertida, y, a veces, hasta disparatada (...
# 35  "El conjunto se gana nuestro corazoncito graci...
# 36  "Si no fuera por su desastrosa secuencia final...
# 37                                                NaN
# 38  "La historia del maestro (...) es triste, herm...
# 39  "Cine sencillo, bien situado en su época (...)...
# 40  "Tiene muchos problemas de base. El primero, s...
# 41  "Tiene todos los ingredientes para parecer la ...
# 42  "Aun siendo la más flojita (...) mantiene el t...
# 43  "La trama destaca por su originalidad, el trab...
# 44  "Es un buen filme, o un filme sin demasiadas p...
# 45  "Por ahora, solo se puede calificar de maravil...
# 46  "El recuerdo del buen cine como placebo de la ...
# 47  "La apuesta consigue desligarse de otros docum...
# 48  "Monumental (...) La película se impone a sí m...
# 49  "Era más divertido cuando no tenían superpoder...
# 50  "La película cuenta una historia, no del todo ...
# 51  "Una película que no tiene ni un ápice del des...
# 52  "Lo fundamental de la historia (...) es que ba...
# 53  "Esta saga se halla demasiado cómoda buscando ...
# 54  "Allen convierte su película 50 en una muy tur...
#
#                                             critica_2  \
# 0   "Es el mejor “mundo de fantasía” hasta la fech...
# 1   "Asombrosa (...) conmovedora delicia, que, des...
# 2   "Gracias a una sucesión de interrogatorios y d...
# 3                                                 NaN
# 4   "Se esfuerza por concentrar nuestra atención (...
# 5                                                 NaN
# 6                                                 NaN
# 7   "Roza la fórmula y da la sensación de haber si...
# 8                                                 NaN
# 9                                                 NaN
# 10  "Quizá el guion (...) y el talento (...) de Fe...
# 11  "Cumple por la mínima, pero cumple (...) Santi...
# 12  "¿Qué falla en 'Noche de paz'? (...) la trama ...
# 13                                                NaN
# 14  "Un drama dinámico y envolvente que da vida a ...
# 15  "Es una película que quiere mucho pero puede m...
# 16  "Víctor Iriarte aplica a su película un extrañ...
# 17                                                NaN
# 18                                                NaN
# 19  "Es un relato lleno de relatos, o un relato qu...
# 20                                                NaN
# 21                                                NaN
# 22  "Este retrato de un matrimonio desbordado no e...
# 23                                                NaN
# 24  "Una versión tan espectacular como inane del p...
# 25  "La película se homenajea a sí misma homenajea...
# 26  "Blanca Portillo hace fácil lo difícil. (...) ...
# 27  "Sin (...) Mateo Barredo (...) resultaría dist...
# 28  "Algunos de los métodos cómicos que maneja res...
# 29  "Francis Lawrence vuelve con una precuela muy ...
# 30  "Un banquete sangriento de ejecuciones, decapi...
# 31  "Un dramón cuyo interés va decayendo según aum...
# 32  "Uno está erizado mientras dura la historia, q...
# 33  "Película (...) lúcida, recomendable y provech...
# 34  "Más que la aventura de rock duro, propia de l...
# 35                                                NaN
# 36  "Pese a ser una adaptación fiel (...), Coixet ...
# 37                                                NaN
# 38  "Auquer hace un trabajo de una delicadeza y de...
# 39  "Un buen y ecuánime retrato (...) Trueba repro...
# 40  "Los 'Terminator' más adorables del cine en un...
# 41  "Dentro de las películas sencillas, románticas...
# 42  "Excepto la magnífica textura de la animación,...
# 43  "Esta irregular pero estimulante película no e...
# 44  "Un insensato pero francamente disfrutable cóc...
# 45  "Una de las obras más audaces del director a n...
# 46  "Lo mejor (...) es la frescura de la chilena S...
# 47  "Dos horas y cuarto lo suficientemente llenas ...
# 48  "El director se toma su tiempo pero no hay nad...
# 49  "Tiene momentos agradables que gustarán a niño...
# 50  "Es sólida en su narrativa, y elegante en su p...
# 51  "En ningún momento tiene uno la sensación de q...
# 52  "Filme, valioso por acercarse a una realidad m...
# 53  "Una película desigual: el casting es estupend...
# 54  "Tiene esa rara armonía de las cosas de Allen,...
#
#                                             critica_3  \
# 0   "La maníaca atención al detalle de la direcció...
# 1   "Una maravilla para alumbrar a la infancia y d...
# 2   "Hay mucha eficacia narrativa, mucha anatomía,...
# 3                                                 NaN
# 4   "Bradley Cooper convierte el 'biopic' del músi...
# 5                                                 NaN
# 6                                                 NaN
# 7   "Una emocionante secuela llena de humor que se...
# 8                                                 NaN
# 9                                                 NaN
# 10  "Es una farsa casposa, ordinaria, que se ríe, ...
# 11  "Sigue confirmando que la comedia comercial es...
# 12  "La apuesta por un thriller de venganza en el ...
# 13                                                NaN
# 14  "Una sensual y envolvente adaptación de la nov...
# 15  "Aunque incluye un Romeo y Julieta centenial, ...
# 16  "Una de las grandes virtudes de “Sobre todo de...
# 17                                                NaN
# 18                                                NaN
# 19  "Rodrigo Moreno salta sinuosamente de un géner...
# 20                                                NaN
# 21                                                NaN
# 22  "Una comedia negra insoportablemente cruel (.....
# 23                                                NaN
# 24  "Es interesante (...) por insólita y obstinada...
# 25  "Lo viejo y lo nuevo se dan la mano en una pel...
# 26  "Un gran trabajo de fineza cinematográfica. (....
# 27  "Puede disuadir por (...) el temor a otro toch...
# 28  "Atractiva y muy imaginativa es esta ópera pri...
# 29  "Mastodóntica en ciertos niveles pero irregula...
# 30  "Diabólicamente divertida (...) Sangrienta, en...
# 31                                                NaN
# 32  "Tiende un puente insólito entre el drama cost...
# 33  "Es una mala película (...) que juega con este...
# 34  "Puede que la 33ª película del Universo Cinema...
# 35                                                NaN
# 36  "Una realización cuidadosa y aseada por parte ...
# 37                                                NaN
# 38  "Si bien la historia real del maestro (...) es...
# 39  "Tres logros incontestables. Uno es la direcci...
# 40  "Cumple como entretenimiento liviano pasajero ...
# 41  "Extraordinaria ópera prima (...) es una pelíc...
# 42  "Posiblemente es la entrega más alocada de la ...
# 43  "Una película más que disfrutable (...) [pero]...
# 44  "Thriller tosco que presume de lo que carece (...
# 45  "De una belleza arrebatadora (...) despliega u...
# 46  "Tiene vida propia. (...) Un cuento de cine en...
# 47  "La concentración (el saber qué se quiere cont...
# 48  "Es un western a la contra: explicado el plano...
# 49  "Hay algunos chistes que hacen reír (...) pero...
# 50  "Muchas intenciones, escaso resultado (...) Se...
# 51  "El relato se mueve entre lo intercambiable y ...
# 52  "Como exploradora de extrarradio [Echevarria] ...
# 53  "Ya no se trata solamente de poner en imágenes...
# 54  "Posee frescura, ironía, situaciones complejas...
#
#                                             critica_4
# 0   "Brilla tanto el diseño de producción como las...
# 1   "Una película tierna, llena de imaginación. Un...
# 2   "Retorcida, ambigua y aceptable intriga. Sigo ...
# 3                                                 NaN
# 4   "Hay tantísimo esfuerzo, tantas ganas de proba...
# 5                                                 NaN
# 6                                                 NaN
# 7   "Hay muchísima innovación en lo visual pero ap...
# 8                                                 NaN
# 9                                                 NaN
# 10  "Funciona (...) demuestra que para hacer una n...
# 11  "Santiago Segura y Ernesto Sevilla salvan las ...
# 12  "Atraído por la llamada de un público que busc...
# 13                                                NaN
# 14  "Un fracaso, visualmente impresionante pero dr...
# 15  "Los pocos felices que sepamos disfrutar de su...
# 16  "Es una película magnífica, cargada de simboli...
# 17                                                NaN
# 18                                                NaN
# 19  "Constantemente se reinventa y triunfa a la ho...
# 20                                                NaN
# 21                                                NaN
# 22  "Definitivamente, merece la pena verla (...) E...
# 23                                                NaN
# 24  "El Napoleón del apabullante, irregular, trasq...
# 25  "Una película de celebración emocional que (.....
# 26  "La palabra recitada, el montaje (...) sirven ...
# 27  "La película más 'bressoniana' de Manuel Martí...
# 28  "Rebosa humor, emoción y alegría (...) Puntuac...
# 29  "Una precuela que mantiene las virtudes del or...
# 30  "Puede que sepa bien para uno o dos bocados, p...
# 31                                                NaN
# 32  "Hay en la película una suerte de documento de...
# 33  "No existe ningún momento en el que me sienta ...
# 34  "Una secuela de 'Capitana Marvel' que cumple c...
# 35                                                NaN
# 36  "Coixet, más clásica, más convencional [que Sa...
# 37                                                NaN
# 38  "Una gran historia verídica (...) y un discurs...
# 39  "Una de las mejores películas españolas del añ...
# 40  "Simpática adaptación (...) Cumple, entretiene...
# 41  "Se construye en tres actos, que no llegan a p...
# 42  "Esta aventura musical cubierta de lentejuelas...
# 43                                                NaN
# 44  "Déjennos, que disfrutemos con un Ben Affleck ...
# 45  "Gigantesco tapiz de imágenes de excelsa belle...
# 46  "Un relato humanista y cinéfilo (...) es una c...
# 47                                                NaN
# 48  "Al verla no consulto el reloj. La sabiduría q...
# 49  "No es una buena película pero debería gustar ...
# 50  "Jim Caviezel potencia un thriller sólido e in...
# 51  "Película entretenida, con jumpscares efectivo...
# 52  "Echevarría sigue la estela de ‘Carmen y Lola’...
# 53  "Tanto si eres nuevo en la franquicia como un ...
# 54  "Retoma un tema que “Match Point” desarrolló d...
#
# [55 rows x 26 columns]
